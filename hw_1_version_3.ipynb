# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSlowakiewicz/Deep-Neural-Network/blob/master/hw_1_version_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project: Multitask Learning for Geometric Shape Classification and Counting**
#
# ## 1. Overview
#
# In this project, you will design, implement, and evaluate a **multitask neural network** that performs **two tasks simultaneously**:
#
# 1. **Classification** – identify which pair of geometric shape types appears in a 28×28 binary image (135 possible configurations).
# 2. **Regression** – predict how many shapes of each type are present (6 regression targets).
#
# This project focuses on **multi-task learning**, i.e., using one shared model to learn several related tasks at once. You will compare how adding an auxiliary task affects performance and training dynamics.
#
# ---
#
# ## 2. Dataset
#
# You will use the **Geometric Shape Numbers (GSN)** dataset:
#
# ```bash
# !wget https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# !unzip data_gsn.zip &> /dev/null
# !rm data_gsn.zip
# ```
#
# This will create a directory `data/` containing:
#
# * **10,000 images** (28×28x1, grayscale)
# * **labels.csv** – counts of each of six shape types per image
#
# Each image contains exactly **two types** of geometric figures (out of six) and **10 shapes total**.
#
# **Shape classes:**
#
# | Index | Shape type     |
# | ----: | -------------- |
# |     0 | square         |
# |     1 | circle         |
# |     2 | triangle up    |
# |     3 | triangle right |
# |     4 | triangle down  |
# |     5 | triangle left  |
#
# Example row from `labels.csv`:
#
# ```
# name,squares,circles,up,right,down,left
# img_00000.png,0,0,0,4,0,6
# ```
#
# Here, the image contains **4 right-pointing triangles** and **6 left-pointing triangles**.
#
# **Split:**
#
# * Training: first 9,000 samples
# * Validation: last 1,000 samples
#
# Examples:
# ![example.png](data:image/png;base64,...)
#
# ---
#
# ## 3. Tasks and objectives
#
# You must design a **multitask deep learning system** that:
#
# 1. **Classifies** each image into one of **135 possible configurations**, representing:
#
#    * which **two shape classes** appear, and
#    * how their counts (1–9) sum to 10.
#
#    → Example: "3 circles + 7 squares" is one configuration class.
#
# 2. **Regresses** the number of shapes of each type (a 6-dimensional real-valued output).
#
# 3. Combines both objectives in a **joint loss** function (Hint: losses are implemented in PyTorch):
#
#
# $$ Loss = \text{NLLLoss(classification)} + \lambda_{\text{cnt}} \cdot \text{SmoothL1Loss(regression)}
# $$
#
# ---
#
# ## 4. Model requirements
#
# ### Architecture constraints
#
# You must use **exactly this feature extractor (backbone)**:
#
# ```python
# nn.Sequential(
#     nn.Conv2d(1, 8, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(8, 16, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(16, 32, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(32, 64, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Flatten(start_dim=1),
#     nn.Linear(64 * 28 * 28, 256), nn.ReLU()
# )
# ```
#
# Then add **two separate heads**:
#
# * `head_cls`: outputs log-probabilities for 135 classes
# * `head_cnt`: outputs 6 regression values (counts)
#
# The model must return two outputs: `(log_probs, counts)`.
#
# You may add dropout or batch normalization inside the heads, **but you must not modify the backbone**.
#
# ---
#
# ## 5. Training setup
#
# * Optimizer: **Adam**, learning rate = 1e-3
# * Epochs: up to **100** (use **early stopping**)
# * Batch sizes: **64** (train), **1000** (validation)
# * Device: GPU allowed for Notebook, but your **final code must run on GPU within ~30 minutes**
# * Random seed: set `torch.manual_seed(1)` for reproducibility
# * Split: **exactly 9,000 train / 1,000 validation**
#
#
# ---
#
# ## 6. Data preprocessing and augmentation
#
# You must implement a **PyTorch `Dataset` class** that:
#
# * Reads `labels.csv`
# * Loads the corresponding image (from `data/`)
# * Returns both:
#   * the image (as a tensor)
#   * the labels (counts for 6 shapes)
# * Optionally applies transformations
#
# ### Required augmentations
#
# You must implement **at least three** of the following:
#
# 1. Random horizontal flip
# 2. Random vertical flip
# 3. Random 90° rotation (must correctly rotate orientation labels: up → right → down → left)
# 4. Random brightness/contrast (mild)
# 5. Gaussian noise
# 6. Random erasing (small areas only)
#
#
# ---
#
# ## 7. Evaluation metrics
#
# Implement and report the following metrics on the validation set:
#
# ### (a) **Classification (135-way)**
#
# * Top-1 accuracy
# * Macro F1-score
# * Per-pair accuracy (aggregate by unordered shape pair, e.g. {circle, up})
#
# ### (b) **Regression (6-D counts)**
#
# * RMSE per class and overall
# * MAE per class and overall
#
# Also plot:
#
# * Training and validation losses
# * Validation accuracy and RMSE over epochs
#
# **Important**: This task is not about finding the best architecture; we expect at least 50% accuracy, but achieving results higher than that will not affect the grade for the assignment**.
#
#
# ---
#
# ## 8. Experiments and analysis
#
# You must train and compare **three model settings**:
#
# | Setting | Description                                      |
# | :------ | :----------------------------------------------- |
# | 1       | **Classification-only:** λ_cnt = 0               |
# | 2       | **Regression-only:** classification loss ignored |
# | 3       | **Multitask:** λ_cnt = with your choose          |
#
# For each experiment:
#
# * Train until early stopping
# * Record loss, accuracy, RMSE, and runtime
# * Compare results and explain how λ influences learning
# * Discuss whether multitask learning improves the main tasks
#
#
# ---
#
# ## 9. Final deliverables
#
# You must submit .zip project with:
#
# 1. **Code** (`.ipynb` or `.py`) that:
#
#    * Downloads and extracts the dataset
#    * Defines dataset, dataloaders, model, loss, training loop, evaluation, and plotting
#    * Can run start-to-end without interaction, and finishes within 30 minutes on Colab T4 GPUs
#    * Includes three experiment configurations
#
# 2. **Report (2–4 pages, PDF)** including:
#    * Section on (EDA) Exploratory Data Analysis in your report: no more than 3 graphs or tables describing the data set.
#    * Model architecture
#    * Description and justification of augmentations
#    * Results table (loss, accuracy, RMSE for all runs)
#    * Learning curves
#    * Discussion on multitask effects
#
# 3. **README.md**:
#
#    * Link to Colab version of task for fast replication.
#    * Approximate runtime and resource requirements
#
# ---
#
# ## 10. Grading rubric
#
# Component	Description	Points
# 1. Implementation correctness	Correct use of the fixed backbone, two-headed model, and proper training loop (classification + regression).	30%
# 2. Data & augmentations	Proper dataset loading, preprocessing, and at least three augmentations with brief justification.	20%
# 3. Evaluation & experiments	Correct computation of metrics (accuracy, F1, RMSE) and completion of all three λ configurations (λ=0, regression-only, your choice λ).	30%
# 4. Report & analysis
# A clear separation of concerns (e.g. headers in notebooks, modules in code) and concise 2–4 page report with results tables, learning curves, confusion matrix, and short discussion on multitask effects and error examples.
# 20%
#
# ###### Readability and modularity will be considered within each grading component. Clear structure (headers in notebooks, docstrings, modular code) significantly improves evaluation speed. Emphasize using clear headers to help reviewers navigate efficiently.
# ---

# %% [markdown]
# # **Project: Multitask Learning for Geometric Shape Classification and Counting**
# ---
# ### **Introduction**
# This project focused on constructing a single **Multitask neural network** capable of both recognizing and counting shapes on 28x28 binary images. The main objective is to compare the performance and training progression of a **Multitask** approach against **Classification-only** and **Regression-only** models.
#
# ---
# **Author:** Michał Słowakiewicz, 448827

# %% [markdown]
# ## **1. Environment setup**
# ---
# This section is responsible for downloading the dataset with 28x28 binary images, importing all the necessary libraries (PyTorch, Pandas, Numpy etc.) and seeting random seed for reproductability of the code.

# %%
# !wget  https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# !unzip data_gsn.zip &> /dev/null
# !rm data_gsn.zip
# Out:
# --2025-11-23 13:46:46--  https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/marcin119a/data/refs/heads/main/data_gsn.zip [following]
# --2025-11-23 13:46:47--  https://raw.githubusercontent.com/marcin119a/data/refs/heads/main/data_gsn.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5544261 (5.3M) [application/zip]
# Saving to: ‘data_gsn.zip’
#
# data_gsn.zip        100%[===================>]   5.29M  --.-KB/s    in 0.08s
#
# 2025-11-23 13:46:47 (68.2 MB/s) - ‘data_gsn.zip’ saved [5544261/5544261]

# %%
# torch imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch import Tensor
import torch.nn.functional as F

# the rest of imports
import pandas as pd
import numpy as np
import os
from PIL import Image
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setting seed
torch.manual_seed(1)

# %%
# choosing device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
data_folder = "data"
csv_file_path = os.path.join(data_folder, "labels.csv")
batch_size = 64

# %% [markdown]
# ## **2. Data preparation**
# ---
# In this section there is an implementation of the *GeometricShapesDataset* class, which is fundamental for this project.
#
# The neural network developed in this project had a huge potential for overfitting, therefore it was essential to introduce potential augumentations of dataset in this class. We implemented three following augumentations:
# 1. **Random horizontal flip**: flips image horizontally and switches Left/Right labels.
# 2. **Random vertical flip**: flips image vertically and switches Down/Up labels.
# 3. **Random gaussian noise**: adds gaussion noise (with mean equal to 0 and standard deviation equal to 0.1) to image.
#
# Moreover, after implementation of this class, it was tested to see whether it returns desired outputs.

# %%
# implementing Dataset class in PyTorch

class GeometricShapesDataset(Dataset):

  def __init__(self, csv_file_path, root_directory, mode = "train", transform = False):
    """
    Parameters:
      csv_file_path - path to file labels.csv containig labels for the dataset
      root_directory - path to folder containing images
      mode - parameter responsible for determining whether we use training mode (first 9000 images; = "train") or we use validation mode (last 1000 images; = "validation")
      transform (True or False) - parameter responsible for decision whether to use chosen augumentations
    """
    self.root_directory = root_directory
    self.transform = transform

    labels = pd.read_csv(csv_file_path)

    if mode == "train":
      self.labels_df = labels[:9000]
    elif mode == "validation":
      self.labels_df = labels[-1000:]
    else:
      raise ValueError("Parameter 'mode' should be equal to 'train' or 'validation'.")

    # self.len = len(self.labels_df) # replaced by __len__ method

  def __len__(self):
     return len(self.labels_df)

  def __getitem__(self, index):
    """
    Method introduced to get data from labels_df.
    """
    #row = self.labels_df[index] # resulted in error
    row = self.labels_df.iloc[index]

    # obtaining image
    image_name = row["name"]
    image_path = os.path.join(self.root_directory, image_name)
    image = Image.open(image_path).convert("L") # without ".convert("L")" the image wouldn't be converted to grayscale and the numbers of channels wouldn't match on training, resulting in an error

    # coverting row to pytorch tensor
    counts_tensor = torch.tensor(row[1:].values.astype(np.float32))

    ### Addressing the augumentations
    if self.transform == True:
      # only some random part of images will be chaneged
      # each augumentation will have 50% chances of being introduced for each image

      # horizontal flip augumentation
      if torch.rand(1) < 0.5:
        image = image.transpose(Image.FLIP_LEFT_RIGHT)

        # now only 'triangle left' and 'triangle right' labels require switching
        right_count = counts_tensor[3].item()
        left_count = counts_tensor[5].item()

        counts_tensor[3] = left_count
        counts_tensor[5] = right_count

      # vertical flip augumentation
      if torch.rand(1) < 0.5:
        image = image.transpose(Image.FLIP_TOP_BOTTOM)

        # now only 'triangle up' and 'triangle down' labels require switching
        up_count = counts_tensor[2].item()
        down_count = counts_tensor[4].item()

        counts_tensor[2] = down_count
        counts_tensor[4] = up_count

      # transforming image into tensor
      image = transforms.ToTensor()(image)

      # gaussian noise augumentation
      if torch.rand(1) < 0.5:
        gaussian_noise = torch.randn_like(image) * 0.1

        # adding noise to image
        image = image + gaussian_noise

        # clamping values to interval (0, 1)
        image = torch.clamp(image, 0, 1)

    else:
      # transforming image into tensor
      image = transforms.ToTensor()(image)

    # assigning counts tensor to correct class; to do it we use _map_counts_to_class_label method that is defined later
    class_label = self._map_counts_to_class_label(counts_tensor)

    return image, counts_tensor, class_label

  def _map_counts_to_class_label(self, counts_tensor):
    """
    Function responsible for mapping 'counts_tensor' to one of the 135 classification classes.
    """

    index_1 = (torch.where(counts_tensor > 0)[0][0]).item()
    index_2 = (torch.where(counts_tensor > 0)[0][1]).item()
    count_1 = counts_tensor[index_1].item()
    count_2 = counts_tensor[index_2].item()

    # defining the 135 classes

    # first introduce part responsible for encoding what 2 classes of shapes are taken
    pairs = sorted([(i, j) for i in range(6) for j in range(i+1, 6)]) # 15 distinct pairs
    current_pair = tuple(sorted((index_1, index_2)))
    pair_class = pairs.index(current_pair)

    # now we define the part responsible for encoding what is the distribution of count_1 and count_2
    # let us introduce mapping: (1, 9) -> class 0, (2, 8) -> class 1, ..., (9, 1) -> class 8; 9 classes in total
    # therefore we may use formula
    distribution_class = int(counts_tensor[current_pair[0]].item()) - 1

    # final label
    label = (pair_class * 9) + distribution_class # 15*9 = 135 distinct classes

    return torch.tensor(label, dtype = torch.int64)

# %%
# Testing part for class GeometricShapesDataset(Dataset)

# Test 1
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train")
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation")

print("Test 1")
print(f"Size of training dataset: {len(train_dataset)}")
print(f"Size of training dataset: {len(validation_dataset)}")


# now we'll test with paramater 'transfrom' using placeholder

placeholder_transform = transforms.ToTensor()

# Test 2
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train", transform = placeholder_transform)
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation", transform = placeholder_transform)

print("Test 2")
print(f"Size of training dataset: {len(train_dataset)}")
print(f"Size of training dataset: {len(validation_dataset)}")


# Test 3
# create DataLoader
train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size = 1000, shuffle=False)


for images, counts, labels in train_dataloader:
    print("Test 3")
    # Verfification of shapes and types of images, count, labels in one batch
    print(f"Image batch: shape={images.shape}, type={images.dtype}")
    print(f"Counts batch: shape={counts.shape}, type={counts.dtype}")
    print(f"Labels batch: shape={labels.shape}, type={labels.dtype}")

    print("Example")
    print(f"Counts: {counts[0]}")
    print(f"Label:  {labels[0]}")

    break
# Out:
# Test 1
# Size of training dataset: 9000
# Size of training dataset: 1000
# Test 2
# Size of training dataset: 9000
# Size of training dataset: 1000
# Test 3
# Image batch: shape=torch.Size([64, 1, 28, 28]), type=torch.float32
# Counts batch: shape=torch.Size([64, 6]), type=torch.float32
# Labels batch: shape=torch.Size([64]), type=torch.int64
# Example
# Counts: tensor([0., 6., 0., 0., 4., 0.])
# Label:  68

# %% [markdown]
# ## **3. Explanatory Data Analysis**
# ---
# Before training, explanatory data analysis was conducted in order to understand class distribution, learn about dataset and look for potential imbalances in dataset. We generated the plot representing distribution of shapes and classes  and vizualized what classes are missing in dataset.

# %%
# Explanatory Data Analysis
labels = pd.read_csv(csv_file_path)

labels_train = labels[:9000]

# counting shape types
shapes_columns = ["squares", "circles", "up", "right", "down", "left"]
shapes_df = labels_train[shapes_columns]
shapes_counts = shapes_df.sum()
print("Shapes counts: ")
print(shapes_counts)

# Plot 1 showing distribution of shapes
plt.figure(figsize=(10,6))
bars = plt.bar(shapes_counts.index, shapes_counts.values)
plt.bar_label(bars)
plt.title("Distribution of shapes in traininng dataset")
plt.xlabel("Shape")
plt.ylabel("Counts")
plt.grid(axis = "y", linestyle="--", alpha = 0.5)
plt.savefig("EDA_plot_1.jpg")
plt.show()

# mapping rows to one of the 135 classses (similiar logic to the one used to GeometricShapesDataset)
pairs = sorted([(i, j) for i in range(6) for j in range(i + 1, 6)])

def map_row_to_class(row):
    vector_counts = row[shapes_columns]
    index_1 = np.where(vector_counts > 0)[0][0]
    index_2 = np.where(vector_counts > 0)[0][1]

    current_pair = tuple(sorted((index_1, index_2)))
    pair_class = pairs.index(current_pair)

    count_for_first_index = vector_counts.iloc[current_pair[0]]
    distribution_class = int(count_for_first_index) - 1

    label = (pair_class * 9) + distribution_class
    return label

# creating new column representing one of 135 classes
labels_train["class_135"] = labels_train.apply(map_row_to_class, axis = 1)

# counting appearences of each class
class_counts = labels_train["class_135"].value_counts()

# print some information
print("Metrics:")
print(class_counts.describe())
print("Most common classes:")
print(class_counts.head(5))
print("Rarest classes:")
print(class_counts.tail(5))

# Plot 2
plt.figure(figsize=(10,6))
plt.bar(class_counts.index, class_counts.values,  edgecolor='black', alpha=0.5)
plt.title("Distribution of 135 classes among training dataset")
plt.xlabel("Class")
plt.ylabel("Counts")
plt.grid(axis = "y", linestyle="--", alpha = 0.5)
plt.savefig("EDA_plot_2.jpg")
plt.show()


# Presence matrix - showing exactly wihich classes are present in dataset
presence_matrix = np.zeros((15, 9))

# 1 if class is present within datset, 0 otherwise
present_classes = labels_train['class_135'].unique()
for class_id in present_classes:
  index_1 = class_id // 9
  index_2 = class_id % 9
  presence_matrix[index_1, index_2] = 1

# preparing labels
shape_names = ['squre', 'circle', 'up', 'right', 'down', 'left']
pair_labels = [f"{shape_names[p[0]]}+{shape_names[p[1]]}" for p in pairs]
number_labels = [f"{i+1}:{9-i}" for i in range(9)]

# Plot 3
plt.figure(figsize=(10,6))
sns.heatmap(presence_matrix, annot=False, cmap="Greens", cbar=False, linecolor='lightgray', linewidths=1, xticklabels=number_labels, yticklabels=pair_labels)
nb_missing_classes = 135 - len(present_classes)
plt.title((f"Presence Matrix - {nb_missing_classes}/135 missing classes"))
plt.xlabel("Distribution")
plt.ylabel("Shape")
plt.savefig("EDA_plot_3.jpg")
plt.show()
# Out:
# Shapes counts:
# squares    14923
# circles    15490
# up         14811
# right      15069
# down       15226
# left       14481
# dtype: int64
# /tmp/ipython-input-1038869596.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labels_train["class_135"] = labels_train.apply(map_row_to_class, axis = 1)
# Metrics:
# count    105.000000
# mean      85.714286
# std        8.627677
# min       56.000000
# 25%       80.000000
# 50%       86.000000
# 75%       92.000000
# max      105.000000
# Name: count, dtype: float64
# Most common classes:
# class_135
# 88    105
# 59    104
# 92    101
# 97     99
# 23     98
# Name: count, dtype: int64
# Rarest classes:
# class_135
# 24     70
# 48     69
# 103    68
# 10     65
# 37     56
# Name: count, dtype: int64

# %% [markdown]
# ## **4. Model Architecture**
# ---
# In this section the model architecture was constructed. We used the required **backbone** and two heads for classification and regression tasks:
# 1. **Backbone:** a convolutional solution designed to extract information from 28x28 images with various shapes (4 convolutional layers, Flatten, 1 Linear layer).
# 2. **Classification Head:** head responsible for predicting affiliation to 135 classes (2 linear layers, Dropout)
# 3. **Regression Head:** head responsible for predicting counts values (2 linear layers).
#
#
# Since the neural network had huge tendencies towards overfitting, Dropout was introduced in classification head to prevent that.

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()

    # backbone
    self.backbone = nn.Sequential(
      nn.Conv2d(1, 8, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(8, 16, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(16, 32, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(32, 64, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Flatten(start_dim=1),
      nn.Linear(64 * 28 * 28, 256),
      nn.ReLU()
    )

    # head_cls and head_cnt

    # initial form of heads - it didn't perform well (maximum accuracy it achieved was about 25%)
    #self.head_cls = nn.Linear(256, 135)
    #self.head_cnt = nn.Linear(256, 6)

    # new form for heads - we try deeper approach with dropout to prevent overfitting
    self.head_cls = nn.Sequential(
        nn.Linear(256, 128),
        nn.ReLU(),
        nn.Dropout(p=0.5),
        nn.Linear(128, 135)
    )

    self.head_cnt = nn.Sequential(
        nn.Linear(256, 32),
        nn.ReLU(),
        nn.Linear(32, 6)
    )

  def forward(self, x: Tensor) -> Tensor:
    x = self.backbone(x) # (batch_size, 256)
    logits_cls = self.head_cls(x)
    counts_cnt = self.head_cnt(x)
    log_probs_cls = F.log_softmax(logits_cls, dim=1)

    return log_probs_cls, counts_cnt

# %% [markdown]
# ## **5. Traning Loop**
# ---
# Here the function *run_training* was defined, which will be widely used during experimentation. The function has all necessary functionalities and handles:
#
#
# * **Modes:** Multitask, Classification-only and Regression-only. Each of this modes operates using different loss function.
# * **Metrics calculation:** Function keeps track of training loss, accuracy, F1-score, per-pair accuracy, RMSE and MAE. Function returns metrics history, enabling the user to analyze training progression.
# * **Early stopping:** Parameters *patience* and *desired_accuracy* are responsible for defining early stopping conditions enabling finishing training before reaching maximum number of epochs.
# * **Saving:** When the training is finished, functions saves model parameters to *.pth* file.
#
# The function consists of training part, in which training is done, and validation part, where metrics are calculated.

# %%
# To run final experiments, we define function, which will be reposnsible for training
def run_training(lambda_cnt, mode, n_epochs=100, lr=1e-3, patience=10, desired_accuracy=0.45):

  # inicializing model
  model = Model().to(device)
  optimizer = optim.Adam(model.parameters(), lr=lr)

  # parameters for early stopping mechanism
  epochs_without_improvement = 0
  best_validation_loss = float('inf')

  # defining loss functions
  loss_cls = nn.NLLLoss()
  loss_cnt = nn.SmoothL1Loss()

  # creating lists that will be responsible for storing data that will enable us to create plots about learnig curves and metrics
  history = {
    'avg_train_loss': [], 'total_train_loss': [],
    'avg_validation_loss': [], 'total_validation_loss': [],
    'validation_accuracy': [], 'validation_f1_score': [],
    'validation_per_pair_accuracy': [],
    'validation_rmse': [], 'validation_mae': [],
    'validation_rmse_per_class': [], 'validation_mae_per_class': []
  }

  # setting training mode
  model.train()

  # training loop
  for i in range(n_epochs):
    ### TRAINING SECTION ###
    total_train_loss = 0.0

    for batch_index, (images, counts, labels) in enumerate(train_dataloader):
      images, counts, labels = images.to(device), counts.to(device), labels.to(device)

      optimizer.zero_grad()
      output_cls, output_cnt = model(images)

      # setting the loss function depending on 'mode' parameter
      if mode == "multitask":
        loss = loss_cls(output_cls, labels) + lambda_cnt * loss_cnt(output_cnt, counts)
      elif mode == "classification":
        loss = loss_cls(output_cls, labels)
      elif mode == "regression":
        loss = loss_cnt(output_cnt, counts)
      else:
        raise ValueError("The parameter 'mode' should be equal to 'multitask', 'classification' or 'regression'.")

      loss.backward()
      optimizer.step()
      total_train_loss = total_train_loss + loss.item()

    avg_train_loss = total_train_loss / len(train_dataloader)
    print(f"Epoch {i+1}: Average training loss = {avg_train_loss}")

    # updating history train loss lists
    history['avg_train_loss'].append(avg_train_loss)
    history['total_train_loss'].append(total_train_loss)
    ### END OF TRAINING SECTION ###


    ### VALIDATION SECTION ###
    # switching to evaluation mode
    model.eval()

    # setting up for validation
    total_validation_loss = 0.0
    all_true_labels = []
    all_prediction_labels = []
    all_true_counts = []
    all_prediction_counts = []

    with torch.no_grad():
        for images, counts, labels in validation_dataloader:
          images, counts, labels = images.to(device), counts.to(device), labels.to(device)

          output_cls, output_cnt = model(images)
          # setting the loss function depending on 'mode' parameter
          if mode == "multitask":
            loss = loss_cls(output_cls, labels) + lambda_cnt * loss_cnt(output_cnt, counts)
          elif mode == "classification":
            loss = loss_cls(output_cls, labels)
          elif mode == "regression":
            loss = loss_cnt(output_cnt, counts)
          total_validation_loss = total_validation_loss + loss.item()


          # saving outputs to lists
          # added '.cpu()' to prevent error while working with numpy on gpu
          # saving for cnt part
          all_prediction_counts.append(output_cnt.cpu())
          all_true_counts.append(counts.cpu())

          # saving for cls part
          predicted_labels = output_cls.argmax(dim=1)
          all_prediction_labels.append(predicted_labels.cpu())
          all_true_labels.append(labels.cpu())

    avg_validation_loss = total_validation_loss / len(validation_dataloader)

    # combing results saved in the lists
    validation_prediction_labels = torch.cat(all_prediction_labels) # tensor (1000) with all prediction labels
    validation_true_labels = torch.cat(all_true_labels)
    validation_prediction_counts = torch.cat(all_prediction_counts) # tensor (1000, 6) with all prediction counts
    validation_true_counts = torch.cat(all_true_counts)
    # these tensors will be used to calculate metrics

    # converting tensors to numpy format
    validation_prediction_labels_np = validation_prediction_labels.numpy()
    validation_true_labels_np = validation_true_labels.numpy()
    validation_prediction_counts_np = validation_prediction_counts.numpy()
    validation_true_counts_np = validation_true_counts.numpy()


    # a) calcuating metrics for classification part
    # calculating top1 accuracy
    validation_accuracy = accuracy_score(validation_true_labels_np, validation_prediction_labels_np)

    # calculating f1 score
    # introduced average = "macro", since otherwise it would result in error, because we are in multiclass environment
    validation_f1 = f1_score(validation_true_labels_np, validation_prediction_labels_np, average = 'macro', zero_division=0)

    # calculating 'per-pair accuracy'
    # it will be a bit more complicated than calculating f1 and accuracy
    # we can extract 'pair group' by dividing by 9
    true_pair_group = validation_true_labels_np // 9
    prediction_pair_group = validation_prediction_labels_np // 9

    # count cases when true_pair_group is equal to prediction_pair_group
    correct_pairs = (true_pair_group == prediction_pair_group)

    # compute 'per-pair accuracy'
    validation_per_pair_accuracy = correct_pairs.mean()

    print(f"Validation average training loss: {avg_validation_loss}")
    print(f"Validation metircs: top-1 accuracy = {validation_accuracy}, f1 score = {validation_f1}, per-pair accuracy = {validation_per_pair_accuracy}")

    # b) calculating metrics for regression part
    # RMSE
    mse_loss = nn.MSELoss()
    validation_rmse = torch.sqrt(torch.tensor(mse_loss(validation_true_counts, validation_prediction_counts).item())).item()

    # MAE
    mae_loss = nn.L1Loss()
    validation_mae = mae_loss(validation_true_counts, validation_prediction_counts).item()

    # now we have to compute RMSE and MAE per class
    squared_errors = (validation_prediction_counts - validation_true_counts) ** 2 # (1000, 6)
    absolute_errors = torch.abs(validation_prediction_counts - validation_true_counts) # (1000, 6)

    # we take mean over dim = 0
    mean_squared_errors = torch.mean(squared_errors, dim = 0) # (6)
    mean_absolute_errors = torch.mean(absolute_errors, dim = 0) # (6)

    validation_rmse_per_class = torch.sqrt(mean_squared_errors)
    validation_mae_per_class = mean_absolute_errors

    print(f"Validation metircs: RMSE (overall) = {validation_rmse}, MAE (overall) = {validation_mae}")
    print(f"Validation metircs: RMSE (per class) = {validation_rmse_per_class}, MAE (per class) = {validation_mae_per_class}")

    # updating history validation lists
    history['avg_validation_loss'].append(avg_validation_loss)
    history['total_validation_loss'].append(total_validation_loss)
    history['validation_accuracy'].append(validation_accuracy)
    history['validation_f1_score'].append(validation_f1)
    history['validation_per_pair_accuracy'].append(validation_per_pair_accuracy)
    history['validation_rmse'].append(validation_rmse)
    history['validation_mae'].append(validation_mae)
    history['validation_rmse_per_class'].append(validation_rmse_per_class)
    history['validation_mae_per_class'].append(validation_mae_per_class)
    ### END OF VALIDATION SECTION ###

    # path for saving the model
    save_path = f"model_{mode}.pth"

    # EARLY STOPPING mechanism
    # the mechanism works as follows: we assume that we may wait no more that 'patience' epochs (in our case 'patience'=10) for improvement of avg_validation_loss
    # if for 'patience' epochs we observe no improvement for this metric, then we stop training
    # what is more, we also stop training after achieving 'desired_accuracy' (in our case 'desired_accuracy'=0.45) or higher for accuracy on validation dataset
    if validation_accuracy >= desired_accuracy:
      # executing early stopping and saving the model
      torch.save(model.state_dict(), save_path)
      break

    # patience mechanism
    if avg_validation_loss < best_validation_loss:
      best_validation_loss = avg_validation_loss
      epochs_without_improvement = 0
    else:
      epochs_without_improvement += 1
    # checking if we have already run out of patience
    if epochs_without_improvement >= patience:
      # executing early stopping and saving the model
      torch.save(model.state_dict(), save_path)
      break

    # switching back to training mode
    model.train()

  # saving the model
  torch.save(model.state_dict(), save_path)

  return history

# %% [markdown]
# ## **6. Experiments**
# ---
# After implementing all mandatory code in previous section, we may finally focus on main experimentations. We compare three training strategies:
# 1. **Experiment 1:** Multitask approach with $\lambda = 2$
# 2. **Experiment 2:** Classification-only
# 3. **Experiment 3:** Regression-only
#
# Before running the training, we load training and validation datasets using *GeometricShapeDataset* class

# %%
# loading train dataset with augumentations, validation dataset without augumentations
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train", transform=True)
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation", transform=False)

train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size = 1000, shuffle=False)

# %%
test_histories = {}

# Experiment 1
test_histories["multitask"] = run_training(lambda_cnt=1, mode="multitask", n_epochs=2)

# Experiment 2
test_histories["classification"] = run_training(lambda_cnt=0, mode="classification", n_epochs=2)

# Experiment 3
test_histories["regression"] = run_training(lambda_cnt=1, mode="regression", n_epochs=2)
# Out:
# Epoch 1: Average training loss = 6.142597834269206
# Validation average training loss: 5.6971049308776855
# Validation metircs: top-1 accuracy = 0.026, f1 score = 0.0011266500054831839, per-pair accuracy = 0.14
# Validation metircs: RMSE (overall) = 2.628877878189087, MAE (overall) = 1.6481420993804932
# Validation metircs: RMSE (per class) = tensor([2.6431, 2.7770, 3.0042, 2.7491, 1.6475, 2.7334]), MAE (per class) = tensor([1.7653, 1.7585, 1.8016, 1.7583, 1.1132, 1.6919])
# Epoch 2: Average training loss = 5.3746130483370305
# Validation average training loss: 4.822549819946289
# Validation metircs: top-1 accuracy = 0.062, f1 score = 0.020562381279803407, per-pair accuracy = 0.264
# Validation metircs: RMSE (overall) = 2.3241686820983887, MAE (overall) = 1.4570565223693848
# Validation metircs: RMSE (per class) = tensor([1.5232, 2.8212, 2.9447, 2.3854, 1.1947, 2.5185]), MAE (per class) = tensor([1.1646, 1.8013, 1.8604, 1.6073, 0.6768, 1.6320])
# Epoch 1: Average training loss = 4.77555937800847
# Validation average training loss: 4.685558319091797
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.00013240648791790796, per-pair accuracy = 0.075
# Validation metircs: RMSE (overall) = 3.1393234729766846, MAE (overall) = 1.7475732564926147
# Validation metircs: RMSE (per class) = tensor([3.1544, 3.1568, 3.1040, 3.2169, 3.1283, 3.0736]), MAE (per class) = tensor([1.7571, 1.7665, 1.7564, 1.7639, 1.7424, 1.6991])
# Epoch 2: Average training loss = 4.696295389892362
# Validation average training loss: 4.659185886383057
# Validation metircs: top-1 accuracy = 0.008, f1 score = 0.0002622564691874589, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 3.1443028450012207, MAE (overall) = 1.7383984327316284
# Validation metircs: RMSE (per class) = tensor([3.1409, 3.1431, 3.1454, 3.1959, 3.1400, 3.0998]), MAE (per class) = tensor([1.7326, 1.7359, 1.7313, 1.7284, 1.7580, 1.7443])
# Epoch 1: Average training loss = 1.4046795790922557
# Validation average training loss: 1.2978557348251343
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.00017725607594438098, per-pair accuracy = 0.047
# Validation metircs: RMSE (overall) = 2.5482966899871826, MAE (overall) = 1.6895654201507568
# Validation metircs: RMSE (per class) = tensor([2.5960, 2.7270, 2.7565, 2.4382, 2.5653, 2.1594]), MAE (per class) = tensor([1.7579, 1.8379, 1.7254, 1.6482, 1.6617, 1.5063])
# Epoch 2: Average training loss = 0.798717569797597
# Validation average training loss: 0.5687109231948853
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.00021001785151737897, per-pair accuracy = 0.037
# Validation metircs: RMSE (overall) = 1.523157000541687, MAE (overall) = 0.8862031102180481
# Validation metircs: RMSE (per class) = tensor([0.9922, 2.8958, 1.0593, 1.1088, 1.0148, 1.0809]), MAE (per class) = tensor([0.6458, 1.7123, 0.6875, 0.7941, 0.7199, 0.7577])

# %%
test_histories = {}

# Experiment 1
test_histories["multitask"] = run_training(lambda_cnt=2, mode="multitask", n_epochs=100) #lambda =1 dzial git 40% #ta implmentacja wcyiaga 45% w 27 epoce, 46 w 33 ### 45 w 23epoce ###512 46,5 w 27 ###46,3 w 22
# Out:
# Epoch 1: Average training loss = 7.617765135798894
# Validation average training loss: 7.515268325805664
# Validation metircs: top-1 accuracy = 0.016, f1 score = 0.00029996250468691414, per-pair accuracy = 0.071
# Validation metircs: RMSE (overall) = 2.8799328804016113, MAE (overall)= 1.8189479112625122
# Validation metircs: RMSE (per class) = tensor([2.8669, 2.8436, 2.9564, 2.9625, 2.8368, 2.8097]), MAE (per class)= tensor([1.8054, 1.8308, 1.8405, 1.8592, 1.7944, 1.7833])
# Epoch 2: Average training loss = 7.170678108296496
# Validation average training loss: 6.546852111816406
# Validation metircs: top-1 accuracy = 0.03, f1 score = 0.0068333711815879794, per-pair accuracy = 0.176
# Validation metircs: RMSE (overall) = 2.522590160369873, MAE (overall)= 1.6135295629501343
# Validation metircs: RMSE (per class) = tensor([2.6712, 2.8880, 2.1438, 2.9640, 2.4357, 1.8414]), MAE (per class)= tensor([1.7458, 1.8186, 1.4341, 1.8669, 1.6412, 1.1746])
# Epoch 3: Average training loss = 6.053682073633722
# Validation average training loss: 4.995017051696777
# Validation metircs: top-1 accuracy = 0.097, f1 score = 0.044861839082786216, per-pair accuracy = 0.419
# Validation metircs: RMSE (overall) = 1.9842305183410645, MAE (overall)= 1.1961325407028198
# Validation metircs: RMSE (per class) = tensor([1.5933, 2.6695, 1.3003, 2.7691, 1.5142, 1.5189]), MAE (per class)= tensor([1.1188, 1.7120, 0.8012, 1.6960, 0.9037, 0.9451])
# Epoch 4: Average training loss = 4.503414167580029
# Validation average training loss: 3.600533962249756
# Validation metircs: top-1 accuracy = 0.2, f1 score = 0.1374782884696737, per-pair accuracy = 0.68
# Validation metircs: RMSE (overall) = 1.3234325647354126, MAE (overall)= 0.837112545967102
# Validation metircs: RMSE (per class) = tensor([1.0758, 1.7539, 0.9635, 1.6471, 0.9906, 1.2856]), MAE (per class)= tensor([0.6915, 1.0799, 0.6396, 1.0573, 0.6638, 0.8905])
# Epoch 5: Average training loss = 3.3297686340115593
# Validation average training loss: 2.660532236099243
# Validation metircs: top-1 accuracy = 0.29, f1 score = 0.21376461151237225, per-pair accuracy = 0.81
# Validation metircs: RMSE (overall) = 0.9607715010643005, MAE (overall)= 0.6262262463569641
# Validation metircs: RMSE (per class) = tensor([0.9429, 1.0737, 0.8651, 1.0059, 0.9014, 0.9612]), MAE (per class)= tensor([0.6098, 0.6226, 0.6111, 0.6676, 0.6020, 0.6442])
# Epoch 6: Average training loss = 2.737682651966176
# Validation average training loss: 2.341663122177124
# Validation metircs: top-1 accuracy = 0.325, f1 score = 0.25076357296049157, per-pair accuracy = 0.865
# Validation metircs: RMSE (overall) = 0.864388108253479, MAE (overall)= 0.5536381602287292
# Validation metircs: RMSE (per class) = tensor([0.7601, 0.8578, 0.7975, 0.9367, 0.8865, 0.9327]), MAE (per class)= tensor([0.5381, 0.5105, 0.5222, 0.5935, 0.5655, 0.5920])
# Epoch 7: Average training loss = 2.4310745178384985
# Validation average training loss: 2.2226412296295166
# Validation metircs: top-1 accuracy = 0.333, f1 score = 0.282306401280335, per-pair accuracy = 0.87
# Validation metircs: RMSE (overall) = 0.8286846280097961, MAE (overall)= 0.5288617014884949
# Validation metircs: RMSE (per class) = tensor([0.6530, 0.9131, 0.7569, 0.8682, 0.8405, 0.9094]), MAE (per class)= tensor([0.4573, 0.5923, 0.4839, 0.5754, 0.5191, 0.5453])
# Epoch 8: Average training loss = 2.2615619390568833
# Validation average training loss: 2.04197096824646
# Validation metircs: top-1 accuracy = 0.355, f1 score = 0.30233571272750903, per-pair accuracy = 0.901
# Validation metircs: RMSE (overall) = 0.760709822177887, MAE (overall)= 0.4721042215824127
# Validation metircs: RMSE (per class) = tensor([0.6307, 0.7495, 0.7178, 0.8608, 0.7724, 0.8122]), MAE (per class)= tensor([0.4172, 0.4196, 0.4521, 0.5430, 0.4885, 0.5122])
# Epoch 9: Average training loss = 2.1739252543618495
# Validation average training loss: 1.9783610105514526
# Validation metircs: top-1 accuracy = 0.387, f1 score = 0.32286647650309486, per-pair accuracy = 0.912
# Validation metircs: RMSE (overall) = 0.7584565281867981, MAE (overall)= 0.47090962529182434
# Validation metircs: RMSE (per class) = tensor([0.6715, 0.7392, 0.7267, 0.8274, 0.7266, 0.8448]), MAE (per class)= tensor([0.4459, 0.3966, 0.4534, 0.5493, 0.4673, 0.5130])
# Epoch 10: Average training loss = 2.0658134839213487
# Validation average training loss: 1.9776817560195923
# Validation metircs: top-1 accuracy = 0.358, f1 score = 0.300518334385589, per-pair accuracy = 0.91
# Validation metircs: RMSE (overall) = 0.7382751107215881, MAE (overall)= 0.461122065782547
# Validation metircs: RMSE (per class) = tensor([0.6755, 0.7156, 0.7238, 0.8083, 0.7049, 0.7923]), MAE (per class)= tensor([0.4559, 0.3962, 0.4559, 0.5197, 0.4595, 0.4795])
# Epoch 11: Average training loss = 1.9958057217564142
# Validation average training loss: 1.955398440361023
# Validation metircs: top-1 accuracy = 0.364, f1 score = 0.3093285454552756, per-pair accuracy = 0.904
# Validation metircs: RMSE (overall) = 0.7343298196792603, MAE (overall)= 0.4482429623603821
# Validation metircs: RMSE (per class) = tensor([0.5858, 0.8066, 0.6841, 0.7644, 0.7515, 0.7903]), MAE (per class)= tensor([0.3877, 0.5006, 0.4210, 0.4778, 0.4450, 0.4574])
# Epoch 12: Average training loss = 1.9568977305229673
# Validation average training loss: 1.8976178169250488
# Validation metircs: top-1 accuracy = 0.392, f1 score = 0.3311139762589131, per-pair accuracy = 0.911
# Validation metircs: RMSE (overall) = 0.7188392877578735, MAE (overall)= 0.44009172916412354
# Validation metircs: RMSE (per class) = tensor([0.6012, 0.6610, 0.6695, 0.7471, 0.6873, 0.9073]), MAE (per class)= tensor([0.3905, 0.3811, 0.4215, 0.4847, 0.4376, 0.5252])
# Epoch 13: Average training loss = 1.8835223473555653
# Validation average training loss: 1.8761146068572998
# Validation metircs: top-1 accuracy = 0.395, f1 score = 0.33765758981452, per-pair accuracy = 0.927
# Validation metircs: RMSE (overall) = 0.7121249437332153, MAE (overall)= 0.4318779408931732
# Validation metircs: RMSE (per class) = tensor([0.6419, 0.6448, 0.6789, 0.8287, 0.6693, 0.7870]), MAE (per class)= tensor([0.3813, 0.3611, 0.4161, 0.5615, 0.4200, 0.4513])
# Epoch 14: Average training loss = 1.8368531152711693
# Validation average training loss: 1.8056228160858154
# Validation metircs: top-1 accuracy = 0.385, f1 score = 0.3380876055125882, per-pair accuracy = 0.926
# Validation metircs: RMSE (overall) = 0.6800034046173096, MAE (overall)= 0.41110220551490784
# Validation metircs: RMSE (per class) = tensor([0.5650, 0.6584, 0.6700, 0.7396, 0.6978, 0.7339]), MAE (per class)= tensor([0.3529, 0.3772, 0.4105, 0.4625, 0.4278, 0.4357])
# Epoch 15: Average training loss = 1.8168180090315798
# Validation average training loss: 1.8753026723861694
# Validation metircs: top-1 accuracy = 0.395, f1 score = 0.3475882188489176, per-pair accuracy = 0.92
# Validation metircs: RMSE (overall) = 0.7220101952552795, MAE (overall)= 0.4387966990470886
# Validation metircs: RMSE (per class) = tensor([0.5643, 0.7032, 0.8973, 0.7387, 0.6780, 0.7102]), MAE (per class)= tensor([0.3569, 0.4113, 0.5863, 0.4450, 0.4124, 0.4209])
# Epoch 16: Average training loss = 1.7564888626125688
# Validation average training loss: 1.862208604812622
# Validation metircs: top-1 accuracy = 0.417, f1 score = 0.378783633078132, per-pair accuracy = 0.929
# Validation metircs: RMSE (overall) = 0.7096712589263916, MAE (overall)= 0.43360042572021484
# Validation metircs: RMSE (per class) = tensor([0.6804, 0.7890, 0.6611, 0.7665, 0.6530, 0.6967]), MAE (per class)= tensor([0.4540, 0.4260, 0.3988, 0.5057, 0.3969, 0.4203])
# Epoch 17: Average training loss = 1.7133081010047426
# Validation average training loss: 1.7401751279830933
# Validation metircs: top-1 accuracy = 0.426, f1 score = 0.3709254362146515, per-pair accuracy = 0.94
# Validation metircs: RMSE (overall) = 0.6661094427108765, MAE (overall)= 0.3974745273590088
# Validation metircs: RMSE (per class) = tensor([0.5465, 0.6427, 0.6860, 0.7232, 0.6441, 0.7362]), MAE (per class)= tensor([0.3385, 0.3779, 0.4195, 0.4401, 0.3913, 0.4175])
# Epoch 18: Average training loss = 1.673997442773048
# Validation average training loss: 1.7806960344314575
# Validation metircs: top-1 accuracy = 0.429, f1 score = 0.37399521438849015, per-pair accuracy = 0.919
# Validation metircs: RMSE (overall) = 0.6685318350791931, MAE (overall)= 0.3938092887401581
# Validation metircs: RMSE (per class) = tensor([0.5565, 0.7100, 0.6413, 0.7142, 0.6648, 0.7104]), MAE (per class)= tensor([0.3505, 0.3779, 0.3914, 0.4200, 0.4061, 0.4169])
# Epoch 19: Average training loss = 1.6243010581807886
# Validation average training loss: 1.7555245161056519
# Validation metircs: top-1 accuracy = 0.431, f1 score = 0.38226075961816613, per-pair accuracy = 0.935
# Validation metircs: RMSE (overall) = 0.667712390422821, MAE (overall)= 0.39813172817230225
# Validation metircs: RMSE (per class) = tensor([0.6220, 0.6082, 0.6411, 0.7296, 0.7152, 0.6808]), MAE (per class)= tensor([0.3947, 0.3373, 0.3982, 0.4262, 0.4353, 0.3970])
# Epoch 20: Average training loss = 1.561389147812593
# Validation average training loss: 1.722994089126587
# Validation metircs: top-1 accuracy = 0.43, f1 score = 0.37581985255828204, per-pair accuracy = 0.93
# Validation metircs: RMSE (overall) = 0.6640627384185791, MAE (overall)= 0.3968060612678528
# Validation metircs: RMSE (per class) = tensor([0.5588, 0.6177, 0.6836, 0.7449, 0.6612, 0.7019]), MAE (per class)= tensor([0.3492, 0.3406, 0.4481, 0.4332, 0.3908, 0.4189])
# Epoch 21: Average training loss = 1.5640339479378775
# Validation average training loss: 1.831636905670166
# Validation metircs: top-1 accuracy = 0.433, f1 score = 0.38252198419587197, per-pair accuracy = 0.937
# Validation metircs: RMSE (overall) = 0.7128621339797974, MAE (overall)= 0.42472949624061584
# Validation metircs: RMSE (per class) = tensor([0.5644, 0.5812, 0.6818, 0.7873, 0.7231, 0.8861]), MAE (per class)= tensor([0.3353, 0.3265, 0.4007, 0.5191, 0.4085, 0.5582])
# Epoch 22: Average training loss = 1.515215477199419
# Validation average training loss: 1.6814054250717163
# Validation metircs: top-1 accuracy = 0.463, f1 score = 0.4079911184555004, per-pair accuracy = 0.943
# Validation metircs: RMSE (overall) = 0.6577271223068237, MAE (overall)= 0.3902425169944763
# Validation metircs: RMSE (per class) = tensor([0.5745, 0.6136, 0.6829, 0.7500, 0.6379, 0.6733]), MAE (per class)= tensor([0.3554, 0.3550, 0.4250, 0.4374, 0.3793, 0.3894])
# Epoch 23: Average training loss = 1.4757065012099895
# Validation average training loss: 1.675772786140442
# Validation metircs: top-1 accuracy = 0.47, f1 score = 0.4255740883437788, per-pair accuracy = 0.947
# Validation metircs: RMSE (overall) = 0.6555245518684387, MAE (overall)= 0.38239264488220215
# Validation metircs: RMSE (per class) = tensor([0.5577, 0.6165, 0.6491, 0.7336, 0.6487, 0.7119]), MAE (per class)= tensor([0.3476, 0.3441, 0.3884, 0.4240, 0.3728, 0.4174])
# Epoch 24: Average training loss = 1.4594458037234368
# Validation average training loss: 1.7537376880645752
# Validation metircs: top-1 accuracy = 0.431, f1 score = 0.390020153309227, per-pair accuracy = 0.933
# Validation metircs: RMSE (overall) = 0.6839168667793274, MAE (overall)= 0.39851710200309753
# Validation metircs: RMSE (per class) = tensor([0.5987, 0.6237, 0.6508, 0.7685, 0.6519, 0.7872]), MAE (per class)= tensor([0.3499, 0.3492, 0.3832, 0.4360, 0.4014, 0.4714])
# Epoch 25: Average training loss = 1.4014057614279132
# Validation average training loss: 1.7589720487594604
# Validation metircs: top-1 accuracy = 0.449, f1 score = 0.42063038164145583, per-pair accuracy = 0.935
# Validation metircs: RMSE (overall) = 0.6680783033370972, MAE (overall)= 0.39893755316734314
# Validation metircs: RMSE (per class) = tensor([0.6737, 0.5794, 0.6588, 0.7443, 0.6373, 0.7029]), MAE (per class)= tensor([0.4235, 0.3292, 0.4145, 0.4337, 0.3823, 0.4104])
# Epoch 26: Average training loss = 1.3868177993923214
# Validation average training loss: 1.647824764251709
# Validation metircs: top-1 accuracy = 0.457, f1 score = 0.4135708622928555, per-pair accuracy = 0.938
# Validation metircs: RMSE (overall) = 0.6256651282310486, MAE (overall)= 0.3689694106578827
# Validation metircs: RMSE (per class) = tensor([0.5452, 0.5591, 0.6375, 0.6932, 0.6304, 0.6744]), MAE (per class)= tensor([0.3328, 0.3105, 0.4070, 0.4186, 0.3718, 0.3731])
# Epoch 27: Average training loss = 1.359752024319155
# Validation average training loss: 1.7208890914916992
# Validation metircs: top-1 accuracy = 0.446, f1 score = 0.41245395046751776, per-pair accuracy = 0.937
# Validation metircs: RMSE (overall) = 0.6393848061561584, MAE (overall)= 0.3750605881214142
# Validation metircs: RMSE (per class) = tensor([0.5387, 0.5705, 0.6401, 0.7235, 0.6329, 0.7095]), MAE (per class)= tensor([0.3174, 0.3172, 0.3908, 0.4297, 0.3663, 0.4289])
# Epoch 28: Average training loss = 1.3146439680816433
# Validation average training loss: 1.7104836702346802
# Validation metircs: top-1 accuracy = 0.476, f1 score = 0.4365362148946845, per-pair accuracy = 0.939
# Validation metircs: RMSE (overall) = 0.6501171588897705, MAE (overall)= 0.3785317838191986
# Validation metircs: RMSE (per class) = tensor([0.5653, 0.5741, 0.6919, 0.7098, 0.6228, 0.7185]), MAE (per class)= tensor([0.3269, 0.3092, 0.4071, 0.4315, 0.3724, 0.4241])
# Epoch 29: Average training loss = 1.2737317038766036
# Validation average training loss: 1.7237837314605713
# Validation metircs: top-1 accuracy = 0.456, f1 score = 0.4150453329344073, per-pair accuracy = 0.942
# Validation metircs: RMSE (overall) = 0.651073157787323, MAE (overall)= 0.3770679533481598
# Validation metircs: RMSE (per class) = tensor([0.5626, 0.5644, 0.6428, 0.7619, 0.6190, 0.7290]), MAE (per class)= tensor([0.3285, 0.3076, 0.3925, 0.4383, 0.3719, 0.4236])
# Epoch 30: Average training loss = 1.267051048312627
# Validation average training loss: 1.6973590850830078
# Validation metircs: top-1 accuracy = 0.455, f1 score = 0.4217167354796397, per-pair accuracy = 0.944
# Validation metircs: RMSE (overall) = 0.6276167035102844, MAE (overall)= 0.36396774649620056
# Validation metircs: RMSE (per class) = tensor([0.5770, 0.5595, 0.6365, 0.6857, 0.6218, 0.6750]), MAE (per class)= tensor([0.3322, 0.3097, 0.3803, 0.4168, 0.3571, 0.3878])
# Epoch 31: Average training loss = 1.2252945257416854
# Validation average training loss: 1.7270078659057617
# Validation metircs: top-1 accuracy = 0.46, f1 score = 0.4316192275323665, per-pair accuracy = 0.948
# Validation metircs: RMSE (overall) = 0.6458190679550171, MAE (overall)= 0.38160261511802673
# Validation metircs: RMSE (per class) = tensor([0.5553, 0.5634, 0.6448, 0.7117, 0.6302, 0.7466]), MAE (per class)= tensor([0.3346, 0.3165, 0.3982, 0.4154, 0.3785, 0.4464])
# Epoch 32: Average training loss = 1.207053231009355
# Validation average training loss: 1.8255817890167236
# Validation metircs: top-1 accuracy = 0.446, f1 score = 0.40809248164934825, per-pair accuracy = 0.928
# Validation metircs: RMSE (overall) = 0.6597604155540466, MAE (overall)= 0.3818269968032837
# Validation metircs: RMSE (per class) = tensor([0.5790, 0.5780, 0.6878, 0.7414, 0.6739, 0.6822]), MAE (per class)= tensor([0.3342, 0.3084, 0.4273, 0.4312, 0.4008, 0.3891])
# Epoch 33: Average training loss = 1.1820338647416297
# Validation average training loss: 1.7242249250411987
# Validation metircs: top-1 accuracy = 0.462, f1 score = 0.4321316051829582, per-pair accuracy = 0.94
# Validation metircs: RMSE (overall) = 0.6303602457046509, MAE (overall)= 0.37384065985679626
# Validation metircs: RMSE (per class) = tensor([0.5608, 0.5589, 0.6596, 0.6869, 0.6365, 0.6672]), MAE (per class)= tensor([0.3460, 0.3051, 0.4076, 0.4063, 0.3926, 0.3855])
# Epoch 34: Average training loss = 1.1410877459438136
# Validation average training loss: 1.8001644611358643
# Validation metircs: top-1 accuracy = 0.45, f1 score = 0.42270771912192817, per-pair accuracy = 0.946
# Validation metircs: RMSE (overall) = 0.6504818797111511, MAE (overall)= 0.3843922019004822
# Validation metircs: RMSE (per class) = tensor([0.5742, 0.6023, 0.6441, 0.7000, 0.6247, 0.7424]), MAE (per class)= tensor([0.3483, 0.3263, 0.3877, 0.4261, 0.3658, 0.4523])
# Epoch 35: Average training loss = 1.134986551940864
# Validation average training loss: 1.747596263885498
# Validation metircs: top-1 accuracy = 0.472, f1 score = 0.44810611578348486, per-pair accuracy = 0.949
# Validation metircs: RMSE (overall) = 0.6436527967453003, MAE (overall)= 0.3713677227497101
# Validation metircs: RMSE (per class) = tensor([0.5837, 0.5488, 0.6382, 0.7360, 0.6556, 0.6820]), MAE (per class)= tensor([0.3320, 0.3089, 0.3821, 0.4495, 0.3749, 0.3809])
# Epoch 36: Average training loss = 1.1152513293509787
# Validation average training loss: 1.8681756258010864
# Validation metircs: top-1 accuracy = 0.445, f1 score = 0.42038639355137275, per-pair accuracy = 0.94
# Validation metircs: RMSE (overall) = 0.669249415397644, MAE (overall)= 0.39593440294265747
# Validation metircs: RMSE (per class) = tensor([0.6523, 0.5893, 0.6713, 0.7041, 0.7205, 0.6701]), MAE (per class)= tensor([0.4108, 0.3510, 0.3901, 0.4135, 0.4187, 0.3915])
# Epoch 37: Average training loss = 1.1016232172648113
# Validation average training loss: 1.8007256984710693
# Validation metircs: top-1 accuracy = 0.475, f1 score = 0.44280401853138257, per-pair accuracy = 0.942
# Validation metircs: RMSE (overall) = 0.6295359134674072, MAE (overall)= 0.3642796277999878
# Validation metircs: RMSE (per class) = tensor([0.5610, 0.5521, 0.6359, 0.7089, 0.6142, 0.6886]), MAE (per class)= tensor([0.3302, 0.3080, 0.3773, 0.4083, 0.3583, 0.4035])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3100213784.py in <cell line: 0>()
#       2
#       3 # Experiment 1
# ----> 4 test_histories["multitask"] = run_training(lambda_cnt=2, mode="multitask", n_epochs=100) #lambda =1 dzial git 40% #ta implmentacja wcyiaga 45% w 27 epoce, 46 w 33 ### 45 w 23epoce ###512 46,5 w 27 ###45,5 w 28
#
# /tmp/ipython-input-697629734.py in run_training(lambda_cnt, mode, n_epochs, lr, patience)
#      51
#      52       loss.backward()
# ---> 53       optimizer.step()
#      54       total_train_loss = total_train_loss + loss.item()
#      55
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     515                             )
#     516
# --> 517                 out = func(*args, **kwargs)
#     518                 self._optimizer_step_code()
#     519
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in _use_grad(*args, **kwargs)
#      80             torch.set_grad_enabled(self.defaults["differentiable"])
#      81             torch._dynamo.graph_break()
# ---> 82             ret = func(*args, **kwargs)
#      83         finally:
#      84             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in step(self, closure)
#     245             )
#     246
# --> 247             adam(
#     248                 params_with_grad,
#     249                 grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     148                 return disabled_func(*args, **kwargs)
#     149             else:
# --> 150                 return func(*args, **kwargs)
#     151
#     152         return maybe_fallback
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     951         func = _single_tensor_adam
#     952
# --> 953     func(
#     954         params,
#     955         grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     693         )
#     694
# --> 695         torch._foreach_mul_(device_exp_avg_sqs, beta2)
#     696
#     697         # Due to the strictness of the _foreach_addcmul API, we can't have a single
#
# KeyboardInterrupt:

# %%
# Experiment 2
test_histories["classification"] = run_training(mode="classification", n_epochs=100) # 43,4 w 50### 45 w 35epoce### 45,5 w 33
# Out:
# Epoch 1: Average training loss = 4.777627058908449
# Validation average training loss: 4.6847310066223145
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0001885902876001886, per-pair accuracy = 0.064
# Validation metircs: RMSE (overall) = 3.0606489181518555, MAE (overall)= 1.7233660221099854
# Validation metircs: RMSE (per class) = tensor([3.1549, 3.0699, 3.1214, 3.1418, 2.9175, 2.9499]), MAE (per class)= tensor([1.7580, 1.6763, 1.7455, 1.7279, 1.7325, 1.7000])
# Epoch 2: Average training loss = 4.692366200981411
# Validation average training loss: 4.657761573791504
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.0002694440126431421, per-pair accuracy = 0.067
# Validation metircs: RMSE (overall) = 3.0679712295532227, MAE (overall)= 1.7119942903518677
# Validation metircs: RMSE (per class) = tensor([3.1387, 3.0831, 3.1368, 3.1363, 2.9357, 2.9704]), MAE (per class)= tensor([1.7266, 1.6684, 1.7333, 1.7315, 1.7070, 1.7051])
# Epoch 3: Average training loss = 4.358460681658265
# Validation average training loss: 3.9860503673553467
# Validation metircs: top-1 accuracy = 0.041, f1 score = 0.005399106185900199, per-pair accuracy = 0.211
# Validation metircs: RMSE (overall) = 3.108952522277832, MAE (overall)= 1.7858623266220093
# Validation metircs: RMSE (per class) = tensor([3.2201, 2.9827, 3.2289, 3.1778, 3.0901, 2.9420]), MAE (per class)= tensor([1.8983, 1.7164, 1.8875, 1.7536, 1.7207, 1.7386])
# Epoch 4: Average training loss = 3.9731495515674564
# Validation average training loss: 3.7928569316864014
# Validation metircs: top-1 accuracy = 0.055, f1 score = 0.01191673797812809, per-pair accuracy = 0.235
# Validation metircs: RMSE (overall) = 3.0912163257598877, MAE (overall)= 1.7746549844741821
# Validation metircs: RMSE (per class) = tensor([3.2139, 3.0326, 3.1680, 3.1709, 3.0248, 2.9271]), MAE (per class)= tensor([1.8534, 1.7025, 1.8485, 1.7671, 1.7027, 1.7737])
# Epoch 5: Average training loss = 3.8041568461884845
# Validation average training loss: 3.64591383934021
# Validation metircs: top-1 accuracy = 0.041, f1 score = 0.008240739238304911, per-pair accuracy = 0.197
# Validation metircs: RMSE (overall) = 3.101332426071167, MAE (overall)= 1.8086289167404175
# Validation metircs: RMSE (per class) = tensor([3.2551, 3.0211, 3.1705, 3.1744, 3.0535, 2.9212]), MAE (per class)= tensor([1.9159, 1.7194, 1.8581, 1.7741, 1.7402, 1.8439])
# Epoch 6: Average training loss = 3.6289232808647425
# Validation average training loss: 3.397587537765503
# Validation metircs: top-1 accuracy = 0.09, f1 score = 0.043337374365771404, per-pair accuracy = 0.341
# Validation metircs: RMSE (overall) = 3.1587729454040527, MAE (overall)= 1.864247441291809
# Validation metircs: RMSE (per class) = tensor([3.2628, 2.9943, 3.3542, 3.2147, 3.1755, 2.9303]), MAE (per class)= tensor([1.9075, 1.7362, 2.0172, 1.8274, 1.8567, 1.8404])
# Epoch 7: Average training loss = 3.245727449444169
# Validation average training loss: 2.714974880218506
# Validation metircs: top-1 accuracy = 0.169, f1 score = 0.11277840194756601, per-pair accuracy = 0.534
# Validation metircs: RMSE (overall) = 3.2529006004333496, MAE (overall)= 2.0334115028381348
# Validation metircs: RMSE (per class) = tensor([3.2383, 3.0214, 3.7361, 3.3657, 3.1696, 2.9222]), MAE (per class)= tensor([1.8925, 1.8108, 2.4031, 2.1910, 1.9746, 1.9284])
# Epoch 8: Average training loss = 2.750565657378934
# Validation average training loss: 2.379748582839966
# Validation metircs: top-1 accuracy = 0.224, f1 score = 0.18293262804401803, per-pair accuracy = 0.682
# Validation metircs: RMSE (overall) = 3.2626826763153076, MAE (overall)= 2.0879907608032227
# Validation metircs: RMSE (per class) = tensor([3.2159, 3.0646, 3.8306, 3.3949, 3.0519, 2.9367]), MAE (per class)= tensor([1.8839, 1.8617, 2.4696, 2.3243, 1.9395, 2.0490])
# Epoch 9: Average training loss = 2.406453863103339
# Validation average training loss: 2.0639755725860596
# Validation metircs: top-1 accuracy = 0.289, f1 score = 0.22210399551758897, per-pair accuracy = 0.784
# Validation metircs: RMSE (overall) = 3.3103408813476562, MAE (overall)= 2.1869964599609375
# Validation metircs: RMSE (per class) = tensor([3.1716, 3.0586, 4.0380, 3.4795, 3.0578, 2.9280]), MAE (per class)= tensor([1.8991, 1.8933, 2.6866, 2.4723, 2.0164, 2.1543])
# Epoch 10: Average training loss = 2.1759595642698573
# Validation average training loss: 1.9071742296218872
# Validation metircs: top-1 accuracy = 0.281, f1 score = 0.23273342615456, per-pair accuracy = 0.811
# Validation metircs: RMSE (overall) = 3.324629545211792, MAE (overall)= 2.236037492752075
# Validation metircs: RMSE (per class) = tensor([3.1421, 3.0906, 4.0559, 3.5893, 3.0226, 2.9026]), MAE (per class)= tensor([1.9155, 1.9423, 2.7215, 2.6388, 2.0486, 2.1495])
# Epoch 11: Average training loss = 2.0316099334270397
# Validation average training loss: 1.8259822130203247
# Validation metircs: top-1 accuracy = 0.291, f1 score = 0.2299440373694793, per-pair accuracy = 0.84
# Validation metircs: RMSE (overall) = 3.3832337856292725, MAE (overall)= 2.3270885944366455
# Validation metircs: RMSE (per class) = tensor([3.1839, 3.0221, 4.2762, 3.6471, 3.0844, 2.8822]), MAE (per class)= tensor([1.9519, 1.9471, 2.9690, 2.7789, 2.1121, 2.2037])
# Epoch 12: Average training loss = 1.8993908065430662
# Validation average training loss: 1.7465146780014038
# Validation metircs: top-1 accuracy = 0.333, f1 score = 0.28568187379042415, per-pair accuracy = 0.849
# Validation metircs: RMSE (overall) = 3.3689680099487305, MAE (overall)= 2.293325901031494
# Validation metircs: RMSE (per class) = tensor([3.2049, 3.0661, 4.2118, 3.5910, 3.0734, 2.8890]), MAE (per class)= tensor([1.9510, 1.9616, 2.8654, 2.6881, 2.1147, 2.1792])
# Epoch 13: Average training loss = 1.8252320847612746
# Validation average training loss: 1.6432148218154907
# Validation metircs: top-1 accuracy = 0.35, f1 score = 0.28563805208455706, per-pair accuracy = 0.869
# Validation metircs: RMSE (overall) = 3.380140542984009, MAE (overall)= 2.318565845489502
# Validation metircs: RMSE (per class) = tensor([3.1836, 3.0956, 4.2632, 3.6460, 2.9995, 2.8929]), MAE (per class)= tensor([1.9581, 1.9753, 2.8956, 2.7941, 2.0726, 2.2155])
# Epoch 14: Average training loss = 1.7480537663114832
# Validation average training loss: 1.5868616104125977
# Validation metircs: top-1 accuracy = 0.384, f1 score = 0.33494563904894975, per-pair accuracy = 0.879
# Validation metircs: RMSE (overall) = 3.3496811389923096, MAE (overall)= 2.279439687728882
# Validation metircs: RMSE (per class) = tensor([3.1642, 3.1611, 4.1542, 3.5975, 2.9520, 2.8989]), MAE (per class)= tensor([1.9667, 1.9643, 2.7953, 2.7285, 2.0503, 2.1715])
# Epoch 15: Average training loss = 1.6840286956611255
# Validation average training loss: 1.5010236501693726
# Validation metircs: top-1 accuracy = 0.394, f1 score = 0.34645941260355606, per-pair accuracy = 0.898
# Validation metircs: RMSE (overall) = 3.3604233264923096, MAE (overall)= 2.2997019290924072
# Validation metircs: RMSE (per class) = tensor([3.1581, 3.1480, 4.2157, 3.6196, 2.9540, 2.8760]), MAE (per class)= tensor([1.9689, 1.9909, 2.8402, 2.7562, 2.0551, 2.1869])
# Epoch 16: Average training loss = 1.6407545297703845
# Validation average training loss: 1.6368335485458374
# Validation metircs: top-1 accuracy = 0.36, f1 score = 0.302737551045205, per-pair accuracy = 0.884
# Validation metircs: RMSE (overall) = 3.3956661224365234, MAE (overall)= 2.326329231262207
# Validation metircs: RMSE (per class) = tensor([3.1834, 3.1383, 4.3237, 3.6359, 2.9659, 2.9138]), MAE (per class)= tensor([1.9758, 1.9665, 2.9443, 2.7944, 2.0596, 2.2172])
# Epoch 17: Average training loss = 1.589000050903212
# Validation average training loss: 1.5401899814605713
# Validation metircs: top-1 accuracy = 0.38, f1 score = 0.32919128411059423, per-pair accuracy = 0.9
# Validation metircs: RMSE (overall) = 3.3804402351379395, MAE (overall)= 2.300656795501709
# Validation metircs: RMSE (per class) = tensor([3.1777, 3.1320, 4.3075, 3.5841, 2.9670, 2.9075]), MAE (per class)= tensor([1.9747, 1.9591, 2.9281, 2.7035, 2.0560, 2.1826])
# Epoch 18: Average training loss = 1.5414970546749467
# Validation average training loss: 1.4711371660232544
# Validation metircs: top-1 accuracy = 0.387, f1 score = 0.33268035613917263, per-pair accuracy = 0.907
# Validation metircs: RMSE (overall) = 3.3738136291503906, MAE (overall)= 2.294497489929199
# Validation metircs: RMSE (per class) = tensor([3.1780, 3.1446, 4.2583, 3.5599, 2.9921, 2.9238]), MAE (per class)= tensor([1.9751, 1.9717, 2.8833, 2.6729, 2.0636, 2.2006])
# Epoch 19: Average training loss = 1.4873266203183655
# Validation average training loss: 1.4829227924346924
# Validation metircs: top-1 accuracy = 0.398, f1 score = 0.34211544240234615, per-pair accuracy = 0.892
# Validation metircs: RMSE (overall) = 3.375185251235962, MAE (overall)= 2.3078789710998535
# Validation metircs: RMSE (per class) = tensor([3.1503, 3.1671, 4.2708, 3.6050, 2.9624, 2.8958]), MAE (per class)= tensor([1.9887, 1.9746, 2.9011, 2.7545, 2.0466, 2.1818])
# Epoch 20: Average training loss = 1.4676685155706202
# Validation average training loss: 1.4742310047149658
# Validation metircs: top-1 accuracy = 0.402, f1 score = 0.3626425986197762, per-pair accuracy = 0.894
# Validation metircs: RMSE (overall) = 3.3688454627990723, MAE (overall)= 2.2823081016540527
# Validation metircs: RMSE (per class) = tensor([3.1875, 3.1623, 4.2401, 3.5639, 3.0016, 2.8714]), MAE (per class)= tensor([1.9628, 1.9552, 2.8949, 2.6879, 2.0683, 2.1248])
# Epoch 21: Average training loss = 1.4300030799622232
# Validation average training loss: 1.4196962118148804
# Validation metircs: top-1 accuracy = 0.429, f1 score = 0.3994724259819292, per-pair accuracy = 0.916
# Validation metircs: RMSE (overall) = 3.3594462871551514, MAE (overall)= 2.2814688682556152
# Validation metircs: RMSE (per class) = tensor([3.1810, 3.1712, 4.2296, 3.5509, 2.9522, 2.8854]), MAE (per class)= tensor([1.9652, 1.9669, 2.8889, 2.6833, 2.0360, 2.1486])
# Epoch 22: Average training loss = 1.3851818632572255
# Validation average training loss: 1.4565497636795044
# Validation metircs: top-1 accuracy = 0.383, f1 score = 0.3433433021382656, per-pair accuracy = 0.913
# Validation metircs: RMSE (overall) = 3.3269503116607666, MAE (overall)= 2.2473526000976562
# Validation metircs: RMSE (per class) = tensor([3.1435, 3.1767, 4.1441, 3.5328, 2.9062, 2.8876]), MAE (per class)= tensor([1.9874, 1.9690, 2.7812, 2.6368, 1.9935, 2.1162])
# Epoch 23: Average training loss = 1.353908619136675
# Validation average training loss: 1.4834012985229492
# Validation metircs: top-1 accuracy = 0.4, f1 score = 0.36030601581418487, per-pair accuracy = 0.915
# Validation metircs: RMSE (overall) = 3.3353564739227295, MAE (overall)= 2.252815008163452
# Validation metircs: RMSE (per class) = tensor([3.1634, 3.1804, 4.1443, 3.5338, 2.9311, 2.8932]), MAE (per class)= tensor([1.9754, 1.9797, 2.7837, 2.6352, 2.0145, 2.1285])
# Epoch 24: Average training loss = 1.3259563598226993
# Validation average training loss: 1.4621654748916626
# Validation metircs: top-1 accuracy = 0.387, f1 score = 0.353275263665892, per-pair accuracy = 0.909
# Validation metircs: RMSE (overall) = 3.3370723724365234, MAE (overall)= 2.2643542289733887
# Validation metircs: RMSE (per class) = tensor([3.1526, 3.2144, 4.1481, 3.5550, 2.8838, 2.8955]), MAE (per class)= tensor([2.0045, 1.9771, 2.7731, 2.6741, 2.0072, 2.1501])
# Epoch 25: Average training loss = 1.2823931004138702
# Validation average training loss: 1.4885185956954956
# Validation metircs: top-1 accuracy = 0.405, f1 score = 0.3608724897236658, per-pair accuracy = 0.915
# Validation metircs: RMSE (overall) = 3.3534064292907715, MAE (overall)= 2.2804722785949707
# Validation metircs: RMSE (per class) = tensor([3.1572, 3.2085, 4.1667, 3.6012, 2.9389, 2.8710]), MAE (per class)= tensor([1.9855, 1.9806, 2.8370, 2.7221, 2.0405, 2.1172])
# Epoch 26: Average training loss = 1.2641682582544096
# Validation average training loss: 1.449096441268921
# Validation metircs: top-1 accuracy = 0.428, f1 score = 0.39483294567157906, per-pair accuracy = 0.917
# Validation metircs: RMSE (overall) = 3.3657989501953125, MAE (overall)= 2.2857182025909424
# Validation metircs: RMSE (per class) = tensor([3.1598, 3.1980, 4.2066, 3.5567, 2.9936, 2.9074]), MAE (per class)= tensor([1.9873, 1.9821, 2.8393, 2.6760, 2.0731, 2.1566])
# Epoch 27: Average training loss = 1.2445083577582177
# Validation average training loss: 1.4092968702316284
# Validation metircs: top-1 accuracy = 0.442, f1 score = 0.4147506415580502, per-pair accuracy = 0.929
# Validation metircs: RMSE (overall) = 3.3665952682495117, MAE (overall)= 2.281681537628174
# Validation metircs: RMSE (per class) = tensor([3.1619, 3.2031, 4.2543, 3.5369, 2.9638, 2.8901]), MAE (per class)= tensor([1.9882, 1.9706, 2.8840, 2.6640, 2.0533, 2.1300])
# Epoch 28: Average training loss = 1.2018682250739834
# Validation average training loss: 1.4590051174163818
# Validation metircs: top-1 accuracy = 0.405, f1 score = 0.376809352392987, per-pair accuracy = 0.906
# Validation metircs: RMSE (overall) = 3.330470085144043, MAE (overall)= 2.232560157775879
# Validation metircs: RMSE (per class) = tensor([3.1802, 3.1778, 4.1436, 3.5058, 2.9267, 2.8836]), MAE (per class)= tensor([1.9570, 1.9575, 2.7897, 2.5861, 2.0076, 2.0974])
# Epoch 29: Average training loss = 1.1476647228213912
# Validation average training loss: 1.4873076677322388
# Validation metircs: top-1 accuracy = 0.43, f1 score = 0.4016686864055605, per-pair accuracy = 0.922
# Validation metircs: RMSE (overall) = 3.384603500366211, MAE (overall)= 2.3084750175476074
# Validation metircs: RMSE (per class) = tensor([3.1751, 3.2151, 4.2897, 3.5886, 2.9538, 2.8828]), MAE (per class)= tensor([1.9955, 1.9871, 2.9202, 2.7489, 2.0535, 2.1457])
# Epoch 30: Average training loss = 1.1471183993292193
# Validation average training loss: 1.5086029767990112
# Validation metircs: top-1 accuracy = 0.429, f1 score = 0.40251941771072164, per-pair accuracy = 0.92
# Validation metircs: RMSE (overall) = 3.3615405559539795, MAE (overall)= 2.2683093547821045
# Validation metircs: RMSE (per class) = tensor([3.1710, 3.2321, 4.1967, 3.5695, 2.9290, 2.8923]), MAE (per class)= tensor([2.0047, 1.9681, 2.8180, 2.6733, 2.0332, 2.1125])
# Epoch 31: Average training loss = 1.1312734882036846
# Validation average training loss: 1.478845238685608
# Validation metircs: top-1 accuracy = 0.434, f1 score = 0.3990625275176075, per-pair accuracy = 0.92
# Validation metircs: RMSE (overall) = 3.3353514671325684, MAE (overall)= 2.2486016750335693
# Validation metircs: RMSE (per class) = tensor([3.1681, 3.2136, 4.1328, 3.5614, 2.8697, 2.8957]), MAE (per class)= tensor([1.9904, 1.9717, 2.7622, 2.6692, 1.9797, 2.1185])
# Epoch 32: Average training loss = 1.106822300464549
# Validation average training loss: 1.4437427520751953
# Validation metircs: top-1 accuracy = 0.44, f1 score = 0.4103795431667354, per-pair accuracy = 0.92
# Validation metircs: RMSE (overall) = 3.3300700187683105, MAE (overall)= 2.2273976802825928
# Validation metircs: RMSE (per class) = tensor([3.1553, 3.1853, 4.1088, 3.5203, 2.9606, 2.8973]), MAE (per class)= tensor([1.9608, 1.9577, 2.7348, 2.5959, 2.0110, 2.1042])
# Epoch 33: Average training loss = 1.053646665092901
# Validation average training loss: 1.4995671510696411
# Validation metircs: top-1 accuracy = 0.455, f1 score = 0.4259553856970182, per-pair accuracy = 0.921
# Validation metircs: RMSE (overall) = 3.364298105239868, MAE (overall)= 2.2756266593933105
# Validation metircs: RMSE (per class) = tensor([3.1838, 3.2016, 4.2097, 3.5595, 2.9300, 2.9236]), MAE (per class)= tensor([2.0029, 1.9675, 2.8266, 2.6683, 2.0310, 2.1574])
# Epoch 34: Average training loss = 1.0528588937529435
# Validation average training loss: 1.5427113771438599
# Validation metircs: top-1 accuracy = 0.428, f1 score = 0.4059521693391483, per-pair accuracy = 0.919
# Validation metircs: RMSE (overall) = 3.3584582805633545, MAE (overall)= 2.2628695964813232
# Validation metircs: RMSE (per class) = tensor([3.1758, 3.1869, 4.1747, 3.5580, 2.9863, 2.9031]), MAE (per class)= tensor([1.9820, 1.9711, 2.8092, 2.6438, 2.0526, 2.1186])
# Epoch 35: Average training loss = 1.0140186852597175
# Validation average training loss: 1.5121012926101685
# Validation metircs: top-1 accuracy = 0.422, f1 score = 0.3987173857200525, per-pair accuracy = 0.925
# Validation metircs: RMSE (overall) = 3.3747899532318115, MAE (overall)= 2.289527177810669
# Validation metircs: RMSE (per class) = tensor([3.1585, 3.1813, 4.2851, 3.5951, 2.9315, 2.8909]), MAE (per class)= tensor([1.9824, 1.9644, 2.9148, 2.7201, 2.0221, 2.1334])
# Epoch 36: Average training loss = 0.9975654038977115
# Validation average training loss: 1.5163110494613647
# Validation metircs: top-1 accuracy = 0.442, f1 score = 0.4170736156248657, per-pair accuracy = 0.92
# Validation metircs: RMSE (overall) = 3.3626716136932373, MAE (overall)= 2.2709667682647705
# Validation metircs: RMSE (per class) = tensor([3.1519, 3.2046, 4.2398, 3.5641, 2.9236, 2.9009]), MAE (per class)= tensor([1.9914, 1.9779, 2.8471, 2.6526, 2.0208, 2.1360])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3357126825.py in <cell line: 0>()
#       1 # Experiment 2
# ----> 2 test_histories["classification"] = run_training(lambda_cnt=2, mode="classification", n_epochs=100) # 43,4 w 50### 45 w 35epoce
#
# /tmp/ipython-input-697629734.py in run_training(lambda_cnt, mode, n_epochs, lr, patience)
#      34     total_train_loss = 0.0
#      35
# ---> 36     for batch_index, (images, counts, labels) in enumerate(train_dataloader):
#      37       images, counts, labels = images.to(device), counts.to(device), labels.to(device)
#      38
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     786     def _next_data(self):
#     787         index = self._next_index()  # may raise StopIteration
# --> 788         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789         if self._pin_memory:
#     790             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /tmp/ipython-input-1431299061.py in __getitem__(self, index)
#      34     """
#      35     #row = self.labels_df[index] # resulted in error
# ---> 36     row = self.labels_df.iloc[index]
#      37
#      38     # obtaining image
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1752             self._validate_integer(key, axis)
#    1753
# -> 1754             return self.obj._ixs(key, axis=axis)
#    1755
#    1756     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3994         # irow
#    3995         if axis == 0:
# -> 3996             new_mgr = self._mgr.fast_xs(i)
#    3997
#    3998             # if we are a copy, mark as such
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in fast_xs(self, loc)
#     993             result = np.empty(n, dtype=object)
#     994         else:
# --> 995             result = np.empty(n, dtype=dtype)
#     996             result = ensure_wrapped_if_datetimelike(result)
#     997
#
# KeyboardInterrupt:

# %%
# Experiment 3
test_histories["regression"] = run_training(mode="regression", n_epochs=100) #
# Out:
# Epoch 1: Average training loss = 1.3744236864942185
# Validation average training loss: 1.2208077907562256
# Validation metircs: top-1 accuracy = 0.006, f1 score = 0.0002447381302006853, per-pair accuracy = 0.095
# Validation metircs: RMSE (overall) = 2.5025618076324463, MAE (overall)= 1.5664230585098267
# Validation metircs: RMSE (per class) = tensor([2.6146, 2.4685, 2.9131, 2.6491, 1.5386, 2.6031]), MAE (per class)= tensor([1.6509, 1.5728, 1.8538, 1.6700, 1.0327, 1.6183])
# Epoch 2: Average training loss = 0.9443892227842453
# Validation average training loss: 0.6964832544326782
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.00029394473838918284, per-pair accuracy = 0.038
# Validation metircs: RMSE (overall) = 1.6101638078689575, MAE (overall)= 1.0267802476882935
# Validation metircs: RMSE (per class) = tensor([1.5517, 1.7884, 2.0587, 1.2795, 1.2689, 1.5698]), MAE (per class)= tensor([1.0358, 1.1735, 1.2683, 0.8403, 0.8365, 1.0064])
# Epoch 3: Average training loss = 0.4876814991869825
# Validation average training loss: 0.3943120539188385
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.00036578451634142325, per-pair accuracy = 0.064
# Validation metircs: RMSE (overall) = 1.0671319961547852, MAE (overall)= 0.6933422684669495
# Validation metircs: RMSE (per class) = tensor([1.1023, 1.2237, 0.9038, 1.0294, 1.0215, 1.0955]), MAE (per class)= tensor([0.7799, 0.8540, 0.5880, 0.6374, 0.6162, 0.6846])
# Epoch 4: Average training loss = 0.33786596960209786
# Validation average training loss: 0.35169684886932373
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0003055861141669722, per-pair accuracy = 0.071
# Validation metircs: RMSE (overall) = 0.991849958896637, MAE (overall)= 0.6366348266601562
# Validation metircs: RMSE (per class) = tensor([0.9832, 1.0544, 1.0277, 0.9319, 0.9253, 1.0214]), MAE (per class)= tensor([0.6570, 0.6897, 0.7241, 0.5673, 0.5588, 0.6230])
# Epoch 5: Average training loss = 0.28280830615801167
# Validation average training loss: 0.29541853070259094
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.0006922810661128418, per-pair accuracy = 0.061
# Validation metircs: RMSE (overall) = 0.8924320936203003, MAE (overall)= 0.5611653923988342
# Validation metircs: RMSE (per class) = tensor([0.8275, 0.8827, 0.7730, 0.9823, 0.9581, 0.9133]), MAE (per class)= tensor([0.5864, 0.5453, 0.4781, 0.6041, 0.5573, 0.5958])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-861952206.py in <cell line: 0>()
#       1 # Experiment 3
# ----> 2 test_histories["regression"] = run_training(lambda_cnt=2, mode="regression", n_epochs=100) #
#
# /tmp/ipython-input-697629734.py in run_training(lambda_cnt, mode, n_epochs, lr, patience)
#      34     total_train_loss = 0.0
#      35
# ---> 36     for batch_index, (images, counts, labels) in enumerate(train_dataloader):
#      37       images, counts, labels = images.to(device), counts.to(device), labels.to(device)
#      38
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     786     def _next_data(self):
#     787         index = self._next_index()  # may raise StopIteration
# --> 788         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789         if self._pin_memory:
#     790             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /tmp/ipython-input-1431299061.py in __getitem__(self, index)
#      89
#      90     # assigning counts tensor to correct class; to do it we use _map_counts_to_class_label method that is defined later
# ---> 91     class_label = self._map_counts_to_class_label(counts_tensor)
#      92
#      93     return image, counts_tensor, class_label
#
# /tmp/ipython-input-1431299061.py in _map_counts_to_class_label(self, counts_tensor)
#      99
#     100     index_1 = (torch.where(counts_tensor > 0)[0][0]).item()
# --> 101     index_2 = (torch.where(counts_tensor > 0)[0][1]).item()
#     102     count_1 = counts_tensor[index_1].item()
#     103     count_2 = counts_tensor[index_2].item()
#
# KeyboardInterrupt:

# %% [markdown]
# ## **7. Plot section**
# ---
# This section consists of functions, which will be used for vizualziation and analysis purposes:
# 1.  ***plot_results:*** creates plots for single model, which will vizualize the dynamics of metrics during training.
# 2.  ***plot_comparison:*** shows comparison of metrics throughout training for three models developed in pevious section.
# 3. ***plot_confusion_matrix:*** generatesconfusion matrix dor certain model.

# %%
# plots function for generating plots for single model

def plot_results(history):
  total_epochs = len(history['avg_train_loss'])
  x_axis = range(1, total_epochs + 1)

  # Plot 1 (Average training and validation loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['avg_train_loss'], label = "Average training loss")
  plt.plot(x_axis, history['avg_validation_loss'], label = "Average validation loss")
  plt.title("Average training loss vs. Average validation loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 2 (Total training loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['total_train_loss'], label = "Total training loss")
  plt.title("Total training loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 3 (Total validation loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['total_validation_loss'], color = "tab:orange", label = "Total validation loss")
  plt.title("Total validation loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 4 (Validation accuracy)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_accuracy'], color = "tab:orange", label = "Validation accuracy")
  plt.title("Validation accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 5 (Validation f1 score)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_f1_score'], color = "tab:orange", label = "Validation F1-score")
  plt.title("Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 6 (Validation per-pair accuracy)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_per_pair_accuracy'], color = "tab:orange", label = "Validation per-pair accuracy")
  plt.title("Validation per-pair accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Per-pair accuracy")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 7 (Validation RMSE)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_rmse'], color = "tab:orange", label = "Validation RMSE")
  plt.title("Validation RMSE")
  plt.xlabel("Epoch")
  plt.ylabel("RMSE")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 8 (Validation MAE)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_mae'], color = "tab:orange", label = "Validation MAE")
  plt.title("Validation MAE")
  plt.xlabel("Epoch")
  plt.ylabel("MAE")
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
plot_results(test_histories['multitask'])

# %%
# plots function for generating comparison plots for different models

def plot_comparison(histories):
    x_axis_multitask = range(1, len(histories['multitask']['avg_train_loss']) + 1)
    x_axis_classification = range(1, len(histories['classification']['avg_train_loss']) + 1)
    x_axis_regression = range(1, len(histories['regression']['avg_train_loss']) + 1)

    # Plot 1 (Accuracy)
    accuracy_multitask = histories['multitask']['validation_accuracy']
    accuracy_classification = histories['classification']['validation_accuracy']
    accuracy_regression = histories['regression']['validation_accuracy']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, accuracy_multitask, label = f"Multitask (Max = {max(accuracy_multitask):.2%})")
    plt.plot(x_axis_classification, accuracy_classification, label = f"Classification (Max = {max(accuracy_classification):.2%})")
    plt.plot(x_axis_regression, accuracy_regression, label = f"Regression (Max = {max(accuracy_regression):.2%})")
    plt.title("Model comparison: Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 2 (f1-score)
    f1_multitask = histories['multitask']['validation_f1_score']
    f1_classification = histories['classification']['validation_f1_score']
    f1_regression = histories['regression']['validation_f1_score']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, f1_multitask, label = f"Multitask (Max = {max(f1_multitask):.2%})")
    plt.plot(x_axis_classification, f1_classification, label = f"Classification (Max = {max(f1_classification):.2%})")
    plt.plot(x_axis_regression, f1_regression, label = f"Regression (Max = {max(f1_regression):.2%})")
    plt.title("Model comparison: F1-score")
    plt.xlabel("Epoch")
    plt.ylabel("F1-score")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 3 (per-pair accuracy)
    per_pair_accuracy_multitask = histories['multitask']['validation_per_pair_accuracy']
    per_pair_accuracy_classification = histories['classification']['validation_per_pair_accuracy']
    per_pair_accuracy_regression = histories['regression']['validation_per_pair_accuracy']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, per_pair_accuracy_multitask, label = f"Multitask (Max = {max(per_pair_accuracy_multitask):.2%})")
    plt.plot(x_axis_classification, per_pair_accuracy_classification, label = f"Classification (Max = {max(per_pair_accuracy_classification):.2%})")
    plt.plot(x_axis_regression, per_pair_accuracy_regression, label = f"Regression (Max = {max(per_pair_accuracy_regression):.2%})")
    plt.title("Model comparison: per-pair accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Per-pair accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 4 (RMSE)
    rmse_multitask = histories['multitask']['validation_rmse']
    rmse_classification = histories['classification']['validation_rmse']
    rmse_regression = histories['regression']['validation_rmse']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, rmse_multitask, label = f"Multitask (Min = {min(rmse_multitask):.2%})")
    plt.plot(x_axis_classification, rmse_classification, label = f"Classification (Min = {min(rmse_classification):.2%})")
    plt.plot(x_axis_regression, rmse_regression, label = f"Regression (Min = {min(rmse_regression):.2%})")
    plt.title("Model comparison: RMSE")
    plt.xlabel("Epoch")
    plt.ylabel("RMSE")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 5 (MAE)
    mae_multitask = histories['multitask']['validation_mae']
    mae_classification = histories['classification']['validation_mae']
    mae_regression = histories['regression']['validation_mae']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, mae_multitask, label = f"Multitask (Min = {min(mae_multitask):.2%})")
    plt.plot(x_axis_classification, mae_classification, label = f"Classification (Min = {min(mae_classification):.2%})")
    plt.plot(x_axis_regression, mae_regression, label = f"Regression (Min = {min(mae_regression):.2%})")
    plt.title("Model comparison: MAE")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_comparison(test_histories)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1158489207.py in <cell line: 0>()
# ----> 1 plot_comparison(test_histories)
#
# /tmp/ipython-input-834733216.py in plot_comparison(histories)
#      11
#      12     plt.figure(figsize = (10, 6))
# ---> 13     plt.plot(x_axis, accuracy_multitask, label = f"Multitask (Max = {max(accuracy_multitask):.2%})")
#      14     plt.plot(x_axis, accuracy_classification, label = f"Classification (Max = {max(accuracy_classification):.2%})")
#      15     plt.plot(x_axis, accuracy_regression, label = f"Regression (Max = {max(accuracy_regression):.2%})")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295                 this += args[0],
#     296                 args = args[1:]
# --> 297             yield from self._plot_args(
#     298                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299                 return_kwargs=return_kwargs
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     492
#     493         if x.shape[0] != y.shape[0]:
# --> 494             raise ValueError(f"x and y must have same first dimension, but "
#     495                              f"have shapes {x.shape} and {y.shape}")
#     496         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (2,)

# %%
def plot_confusion_matrix(model, loader, device):

    # setting evaluation mode
    model.eval()

    all_prediction_labels = []
    all_true_labels = []

    with torch.no_grad():
        for images, counts, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            output_cls, output_cnt = model(images)
            prediction_labels = output_cls.argmax(dim=1)

            all_prediction_labels.extend(prediction_labels.cpu().numpy())
            all_true_labels.extend(labels.cpu().numpy())

    # vizualizing for 135 distinct classes would be too cluttered, so we want to showcase less objects in our confusion matrix
    # converting classes to class groups
    true_pairs = np.array(all_true_labels) // 9
    prediction_pairs = np.array(all_prediction_labels) // 9

    # preparing labels for confusion matrix
    shape_names = ['square', 'circle', 'up', 'right', 'down', 'left']
    pairs = sorted([(i, j) for i in range(6) for j in range(i + 1, 6)])
    pair_labels = [f"{shape_names[p[0]]}+{shape_names[p[1]]}" for p in pairs]

    # computing confusion matrix
    confusion_matrix = confusion_matrix(true_pairs, prediction_pairs)

    # plotting heatmap
    plt.figure(figsize=(10, 6))
    sns.heatmap(confusion_matrix, annot=True, xticklabels=pair_labels, yticklabels=pair_labels)
    plt.title('Confusion Matrix')
    plt.ylabel('True pair')
    plt.xlabel('Prediction pair')
    #plt.xticks(rotation=45)
    #plt.tight_layout()
    plt.show()

# %%
def load_model(save_path):
    model = Model()

    # loading model
    model.load_state_dict(torch.load(save_path))
    model.to(device)

    # setting evaluation mode
    model.eval()

    return model

# %%
# loading models
multitask_model = load_model("model_multitask.pth")
classification_model = load_model("model_classification.pth")
regression_model = load_model("model_regression.pth")

# plotting confusion matrices
plot_confusion_matrix(multitask_model, validation_dataloader, device)
plot_confusion_matrix(classification_model, validation_dataloader, device)
plot_confusion_matrix(regression_model, validation_dataloader, device)
