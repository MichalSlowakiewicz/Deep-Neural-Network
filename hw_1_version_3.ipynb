# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSlowakiewicz/Deep-Neural-Network/blob/master/hw_1_version_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project: Multitask Learning for Geometric Shape Classification and Counting**
#
# ## 1. Overview
#
# In this project, you will design, implement, and evaluate a **multitask neural network** that performs **two tasks simultaneously**:
#
# 1. **Classification** – identify which pair of geometric shape types appears in a 28×28 binary image (135 possible configurations).
# 2. **Regression** – predict how many shapes of each type are present (6 regression targets).
#
# This project focuses on **multi-task learning**, i.e., using one shared model to learn several related tasks at once. You will compare how adding an auxiliary task affects performance and training dynamics.
#
# ---
#
# ## 2. Dataset
#
# You will use the **Geometric Shape Numbers (GSN)** dataset:
#
# ```bash
# !wget https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# !unzip data_gsn.zip &> /dev/null
# !rm data_gsn.zip
# ```
#
# This will create a directory `data/` containing:
#
# * **10,000 images** (28×28x1, grayscale)
# * **labels.csv** – counts of each of six shape types per image
#
# Each image contains exactly **two types** of geometric figures (out of six) and **10 shapes total**.
#
# **Shape classes:**
#
# | Index | Shape type     |
# | ----: | -------------- |
# |     0 | square         |
# |     1 | circle         |
# |     2 | triangle up    |
# |     3 | triangle right |
# |     4 | triangle down  |
# |     5 | triangle left  |
#
# Example row from `labels.csv`:
#
# ```
# name,squares,circles,up,right,down,left
# img_00000.png,0,0,0,4,0,6
# ```
#
# Here, the image contains **4 right-pointing triangles** and **6 left-pointing triangles**.
#
# **Split:**
#
# * Training: first 9,000 samples
# * Validation: last 1,000 samples
#
# Examples:
# ![example.png](data:image/png;base64,...)
#
# ---
#
# ## 3. Tasks and objectives
#
# You must design a **multitask deep learning system** that:
#
# 1. **Classifies** each image into one of **135 possible configurations**, representing:
#
#    * which **two shape classes** appear, and
#    * how their counts (1–9) sum to 10.
#
#    → Example: "3 circles + 7 squares" is one configuration class.
#
# 2. **Regresses** the number of shapes of each type (a 6-dimensional real-valued output).
#
# 3. Combines both objectives in a **joint loss** function (Hint: losses are implemented in PyTorch):
#
#
# $$ Loss = \text{NLLLoss(classification)} + \lambda_{\text{cnt}} \cdot \text{SmoothL1Loss(regression)}
# $$
#
# ---
#
# ## 4. Model requirements
#
# ### Architecture constraints
#
# You must use **exactly this feature extractor (backbone)**:
#
# ```python
# nn.Sequential(
#     nn.Conv2d(1, 8, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(8, 16, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(16, 32, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Conv2d(32, 64, 3, stride=1, padding=1), nn.ReLU(),
#     nn.Flatten(start_dim=1),
#     nn.Linear(64 * 28 * 28, 256), nn.ReLU()
# )
# ```
#
# Then add **two separate heads**:
#
# * `head_cls`: outputs log-probabilities for 135 classes
# * `head_cnt`: outputs 6 regression values (counts)
#
# The model must return two outputs: `(log_probs, counts)`.
#
# You may add dropout or batch normalization inside the heads, **but you must not modify the backbone**.
#
# ---
#
# ## 5. Training setup
#
# * Optimizer: **Adam**, learning rate = 1e-3
# * Epochs: up to **100** (use **early stopping**)
# * Batch sizes: **64** (train), **1000** (validation)
# * Device: GPU allowed for Notebook, but your **final code must run on GPU within ~30 minutes**
# * Random seed: set `torch.manual_seed(1)` for reproducibility
# * Split: **exactly 9,000 train / 1,000 validation**
#
#
# ---
#
# ## 6. Data preprocessing and augmentation
#
# You must implement a **PyTorch `Dataset` class** that:
#
# * Reads `labels.csv`
# * Loads the corresponding image (from `data/`)
# * Returns both:
#   * the image (as a tensor)
#   * the labels (counts for 6 shapes)
# * Optionally applies transformations
#
# ### Required augmentations
#
# You must implement **at least three** of the following:
#
# 1. Random horizontal flip
# 2. Random vertical flip
# 3. Random 90° rotation (must correctly rotate orientation labels: up → right → down → left)
# 4. Random brightness/contrast (mild)
# 5. Gaussian noise
# 6. Random erasing (small areas only)
#
#
# ---
#
# ## 7. Evaluation metrics
#
# Implement and report the following metrics on the validation set:
#
# ### (a) **Classification (135-way)**
#
# * Top-1 accuracy
# * Macro F1-score
# * Per-pair accuracy (aggregate by unordered shape pair, e.g. {circle, up})
#
# ### (b) **Regression (6-D counts)**
#
# * RMSE per class and overall
# * MAE per class and overall
#
# Also plot:
#
# * Training and validation losses
# * Validation accuracy and RMSE over epochs
#
# **Important**: This task is not about finding the best architecture; we expect at least 50% accuracy, but achieving results higher than that will not affect the grade for the assignment**.
#
#
# ---
#
# ## 8. Experiments and analysis
#
# You must train and compare **three model settings**:
#
# | Setting | Description                                      |
# | :------ | :----------------------------------------------- |
# | 1       | **Classification-only:** λ_cnt = 0               |
# | 2       | **Regression-only:** classification loss ignored |
# | 3       | **Multitask:** λ_cnt = with your choose          |
#
# For each experiment:
#
# * Train until early stopping
# * Record loss, accuracy, RMSE, and runtime
# * Compare results and explain how λ influences learning
# * Discuss whether multitask learning improves the main tasks
#
#
# ---
#
# ## 9. Final deliverables
#
# You must submit .zip project with:
#
# 1. **Code** (`.ipynb` or `.py`) that:
#
#    * Downloads and extracts the dataset
#    * Defines dataset, dataloaders, model, loss, training loop, evaluation, and plotting
#    * Can run start-to-end without interaction, and finishes within 30 minutes on Colab T4 GPUs
#    * Includes three experiment configurations
#
# 2. **Report (2–4 pages, PDF)** including:
#    * Section on (EDA) Exploratory Data Analysis in your report: no more than 3 graphs or tables describing the data set.
#    * Model architecture
#    * Description and justification of augmentations
#    * Results table (loss, accuracy, RMSE for all runs)
#    * Learning curves
#    * Discussion on multitask effects
#
# 3. **README.md**:
#
#    * Link to Colab version of task for fast replication.
#    * Approximate runtime and resource requirements
#
# ---
#
# ## 10. Grading rubric
#
# Component	Description	Points
# 1. Implementation correctness	Correct use of the fixed backbone, two-headed model, and proper training loop (classification + regression).	30%
# 2. Data & augmentations	Proper dataset loading, preprocessing, and at least three augmentations with brief justification.	20%
# 3. Evaluation & experiments	Correct computation of metrics (accuracy, F1, RMSE) and completion of all three λ configurations (λ=0, regression-only, your choice λ).	30%
# 4. Report & analysis
# A clear separation of concerns (e.g. headers in notebooks, modules in code) and concise 2–4 page report with results tables, learning curves, confusion matrix, and short discussion on multitask effects and error examples.
# 20%
#
# ###### Readability and modularity will be considered within each grading component. Clear structure (headers in notebooks, docstrings, modular code) significantly improves evaluation speed. Emphasize using clear headers to help reviewers navigate efficiently.
# ---

# %% [markdown]
# # **Project: Multitask Learning for Geometric Shape Classification and Counting**
# ---
# ### **Introduction**
# This project focused on constructing a single **Multitask neural network** capable of both recognizing and counting shapes on 28x28 binary images. The main objective is to compare the performance and training progression of a **Multitask** approach against **Classification-only** and **Regression-only** models.
#
# ---
# **Author:** Michał Słowakiewicz, 448827

# %% [markdown]
# ## **1. Environment setup**
# ---
# This section is responsible for downloading the dataset with 28x28 binary images, importing all the necessary libraries (PyTorch, Pandas, Numpy etc.) and seeting random seed for reproductability of the code.

# %%
# !wget  https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# !unzip data_gsn.zip &> /dev/null
# !rm data_gsn.zip
# Out:
# --2025-11-23 18:05:13--  https://github.com/marcin119a/data/raw/refs/heads/main/data_gsn.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/marcin119a/data/refs/heads/main/data_gsn.zip [following]
# --2025-11-23 18:05:14--  https://raw.githubusercontent.com/marcin119a/data/refs/heads/main/data_gsn.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5544261 (5.3M) [application/zip]
# Saving to: ‘data_gsn.zip’
#
# data_gsn.zip        100%[===================>]   5.29M  --.-KB/s    in 0.05s
#
# 2025-11-23 18:05:14 (108 MB/s) - ‘data_gsn.zip’ saved [5544261/5544261]

# %%
# torch imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch import Tensor
import torch.nn.functional as F

# the rest of imports
import pandas as pd
import numpy as np
import os
from PIL import Image
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setting seed
torch.manual_seed(1)

# %%
# choosing device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data_folder = "data"
csv_file_path = os.path.join(data_folder, "labels.csv")
batch_size = 64

# %% [markdown]
# ## **2. Data preparation**
# ---
# In this section there is an implementation of the *GeometricShapesDataset* class, which is fundamental for this project.
#
# The neural network developed in this project had a huge potential for overfitting, therefore it was essential to introduce potential augumentations of dataset in this class. We implemented three following augumentations:
# 1. **Random horizontal flip**: flips image horizontally and switches Left/Right labels.
# 2. **Random vertical flip**: flips image vertically and switches Down/Up labels.
# 3. **Random gaussian noise**: adds gaussion noise (with mean equal to 0 and standard deviation equal to 0.1) to image.
#
# Moreover, after implementation of this class, it was tested to see whether it returns desired outputs.

# %%
# implementing Dataset class in PyTorch

class GeometricShapesDataset(Dataset):

  def __init__(self, csv_file_path, root_directory, mode = "train", transform = False):
    """
    Parameters:
      csv_file_path - path to file labels.csv containig labels for the dataset
      root_directory - path to folder containing images
      mode - parameter responsible for determining whether we use training mode (first 9000 images; = "train") or we use validation mode (last 1000 images; = "validation")
      transform (True or False) - parameter responsible for decision whether to use chosen augumentations
    """
    self.root_directory = root_directory
    self.transform = transform

    labels = pd.read_csv(csv_file_path)

    if mode == "train":
      self.labels_df = labels[:9000]
    elif mode == "validation":
      self.labels_df = labels[-1000:]
    else:
      raise ValueError("Parameter 'mode' should be equal to 'train' or 'validation'.")

    # self.len = len(self.labels_df) # replaced by __len__ method

  def __len__(self):
     return len(self.labels_df)

  def __getitem__(self, index):
    """
    Method introduced to get data from labels_df.
    """
    #row = self.labels_df[index] # resulted in error
    row = self.labels_df.iloc[index]

    # obtaining image
    image_name = row["name"]
    image_path = os.path.join(self.root_directory, image_name)
    image = Image.open(image_path).convert("L") # without ".convert("L")" the image wouldn't be converted to grayscale and the numbers of channels wouldn't match on training, resulting in an error

    # coverting row to pytorch tensor
    counts_tensor = torch.tensor(row[1:].values.astype(np.float32))

    ### Addressing the augumentations
    if self.transform == True:
      # only some random part of images will be chaneged
      # each augumentation will have 50% chances of being introduced for each image

      # horizontal flip augumentation
      if torch.rand(1) < 0.5:
        image = image.transpose(Image.FLIP_LEFT_RIGHT)

        # now only 'triangle left' and 'triangle right' labels require switching
        right_count = counts_tensor[3].item()
        left_count = counts_tensor[5].item()

        counts_tensor[3] = left_count
        counts_tensor[5] = right_count

      # vertical flip augumentation
      if torch.rand(1) < 0.5:
        image = image.transpose(Image.FLIP_TOP_BOTTOM)

        # now only 'triangle up' and 'triangle down' labels require switching
        up_count = counts_tensor[2].item()
        down_count = counts_tensor[4].item()

        counts_tensor[2] = down_count
        counts_tensor[4] = up_count

      # transforming image into tensor
      image = transforms.ToTensor()(image)

      # gaussian noise augumentation
      if torch.rand(1) < 0.5:
        gaussian_noise = torch.randn_like(image) * 0.1

        # adding noise to image
        image = image + gaussian_noise

        # clamping values to interval (0, 1)
        image = torch.clamp(image, 0, 1)

    else:
      # transforming image into tensor
      image = transforms.ToTensor()(image)

    # assigning counts tensor to correct class; to do it we use _map_counts_to_class_label method that is defined later
    class_label = self._map_counts_to_class_label(counts_tensor)

    return image, counts_tensor, class_label

  def _map_counts_to_class_label(self, counts_tensor):
    """
    Function responsible for mapping 'counts_tensor' to one of the 135 classification classes.
    """

    index_1 = (torch.where(counts_tensor > 0)[0][0]).item()
    index_2 = (torch.where(counts_tensor > 0)[0][1]).item()
    count_1 = counts_tensor[index_1].item()
    count_2 = counts_tensor[index_2].item()

    # defining the 135 classes

    # first introduce part responsible for encoding what 2 classes of shapes are taken
    pairs = sorted([(i, j) for i in range(6) for j in range(i+1, 6)]) # 15 distinct pairs
    current_pair = tuple(sorted((index_1, index_2)))
    pair_class = pairs.index(current_pair)

    # now we define the part responsible for encoding what is the distribution of count_1 and count_2
    # let us introduce mapping: (1, 9) -> class 0, (2, 8) -> class 1, ..., (9, 1) -> class 8; 9 classes in total
    # therefore we may use formula
    distribution_class = int(counts_tensor[current_pair[0]].item()) - 1

    # final label
    label = (pair_class * 9) + distribution_class # 15*9 = 135 distinct classes

    return torch.tensor(label, dtype = torch.int64)

# %%
# Testing part for class GeometricShapesDataset(Dataset)

# Test 1
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train")
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation")

print("Test 1")
print(f"Size of training dataset: {len(train_dataset)}")
print(f"Size of training dataset: {len(validation_dataset)}")


# now we'll test with paramater 'transfrom' using placeholder

placeholder_transform = transforms.ToTensor()

# Test 2
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train", transform = placeholder_transform)
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation", transform = placeholder_transform)

print("Test 2")
print(f"Size of training dataset: {len(train_dataset)}")
print(f"Size of training dataset: {len(validation_dataset)}")


# Test 3
# create DataLoader
train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size = 1000, shuffle=False)


for images, counts, labels in train_dataloader:
    print("Test 3")
    # Verfification of shapes and types of images, count, labels in one batch
    print(f"Image batch: shape={images.shape}, type={images.dtype}")
    print(f"Counts batch: shape={counts.shape}, type={counts.dtype}")
    print(f"Labels batch: shape={labels.shape}, type={labels.dtype}")

    print("Example")
    print(f"Counts: {counts[0]}")
    print(f"Label:  {labels[0]}")

    break
# Out:
# Test 1
# Size of training dataset: 9000
# Size of training dataset: 1000
# Test 2
# Size of training dataset: 9000
# Size of training dataset: 1000
# Test 3
# Image batch: shape=torch.Size([64, 1, 28, 28]), type=torch.float32
# Counts batch: shape=torch.Size([64, 6]), type=torch.float32
# Labels batch: shape=torch.Size([64]), type=torch.int64
# Example
# Counts: tensor([0., 6., 0., 0., 4., 0.])
# Label:  68

# %% [markdown]
# ## **3. Explanatory Data Analysis**
# ---
# Before training, explanatory data analysis was conducted in order to understand class distribution, learn about dataset and look for potential imbalances in dataset. We generated the plot representing distribution of shapes and classes  and vizualized what classes are missing in dataset.

# %%
# Explanatory Data Analysis
labels = pd.read_csv(csv_file_path)

labels_train = labels[:9000]

# counting shape types
shapes_columns = ["squares", "circles", "up", "right", "down", "left"]
shapes_df = labels_train[shapes_columns]
shapes_counts = shapes_df.sum()
print("Shapes counts: ")
print(shapes_counts)

# Plot 1 showing distribution of shapes
plt.figure(figsize=(10,6))
bars = plt.bar(shapes_counts.index, shapes_counts.values)
plt.bar_label(bars)
plt.title("Distribution of shapes in traininng dataset")
plt.xlabel("Shape")
plt.ylabel("Counts")
plt.grid(axis = "y", linestyle="--", alpha = 0.5)
plt.savefig("EDA_plot_1.jpg")
plt.show()

# mapping rows to one of the 135 classses (similiar logic to the one used to GeometricShapesDataset)
pairs = sorted([(i, j) for i in range(6) for j in range(i + 1, 6)])

def map_row_to_class(row):
    vector_counts = row[shapes_columns]
    index_1 = np.where(vector_counts > 0)[0][0]
    index_2 = np.where(vector_counts > 0)[0][1]

    current_pair = tuple(sorted((index_1, index_2)))
    pair_class = pairs.index(current_pair)

    count_for_first_index = vector_counts.iloc[current_pair[0]]
    distribution_class = int(count_for_first_index) - 1

    label = (pair_class * 9) + distribution_class
    return label

# creating new column representing one of 135 classes
labels_train["class_135"] = labels_train.apply(map_row_to_class, axis = 1)

# counting appearences of each class
class_counts = labels_train["class_135"].value_counts()

# print some information
print("Metrics:")
print(class_counts.describe())
print("Most common classes:")
print(class_counts.head(5))
print("Rarest classes:")
print(class_counts.tail(5))

# Plot 2
plt.figure(figsize=(10,6))
plt.bar(class_counts.index, class_counts.values,  edgecolor='black', alpha=0.5)
plt.title("Distribution of 135 classes among training dataset")
plt.xlabel("Class")
plt.ylabel("Counts")
plt.grid(axis = "y", linestyle="--", alpha = 0.5)
plt.savefig("EDA_plot_2.jpg")
plt.show()


# Presence matrix - showing exactly wihich classes are present in dataset
presence_matrix = np.zeros((15, 9))

# 1 if class is present within datset, 0 otherwise
present_classes = labels_train['class_135'].unique()
for class_id in present_classes:
  index_1 = class_id // 9
  index_2 = class_id % 9
  presence_matrix[index_1, index_2] = 1

# preparing labels
shape_names = ['squre', 'circle', 'up', 'right', 'down', 'left']
pair_labels = [f"{shape_names[p[0]]}+{shape_names[p[1]]}" for p in pairs]
number_labels = [f"{i+1}:{9-i}" for i in range(9)]

# Plot 3
plt.figure(figsize=(10,6))
sns.heatmap(presence_matrix, annot=False, cmap="Greens", cbar=False, linecolor='lightgray', linewidths=1, xticklabels=number_labels, yticklabels=pair_labels)
nb_missing_classes = 135 - len(present_classes)
plt.title((f"Presence Matrix - {nb_missing_classes}/135 missing classes"))
plt.xlabel("Distribution")
plt.ylabel("Shape")
plt.savefig("EDA_plot_3.jpg")
plt.show()
# Out:
# Shapes counts:
# squares    14923
# circles    15490
# up         14811
# right      15069
# down       15226
# left       14481
# dtype: int64
# /tmp/ipython-input-102634887.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labels_train["class_135"] = labels_train.apply(map_row_to_class, axis = 1)
# Metrics:
# count    105.000000
# mean      85.714286
# std        8.627677
# min       56.000000
# 25%       80.000000
# 50%       86.000000
# 75%       92.000000
# max      105.000000
# Name: count, dtype: float64
# Most common classes:
# class_135
# 88    105
# 59    104
# 92    101
# 97     99
# 23     98
# Name: count, dtype: int64
# Rarest classes:
# class_135
# 24     70
# 48     69
# 103    68
# 10     65
# 37     56
# Name: count, dtype: int64

# %% [markdown]
# ## **4. Model Architecture**
# ---
# In this section the model architecture was constructed. We used the required **backbone** and two heads for classification and regression tasks:
# 1. **Backbone:** a convolutional solution designed to extract information from 28x28 images with various shapes (4 convolutional layers, Flatten, 1 Linear layer).
# 2. **Classification Head:** head responsible for predicting affiliation to 135 classes (2 linear layers, Dropout)
# 3. **Regression Head:** head responsible for predicting counts values (2 linear layers).
#
#
# Since the neural network had huge tendencies towards overfitting, Dropout was introduced in classification head to prevent that.

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()

    # backbone
    self.backbone = nn.Sequential(
      nn.Conv2d(1, 8, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(8, 16, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(16, 32, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Conv2d(32, 64, 3, stride=1, padding=1),
      nn.ReLU(),
      nn.Flatten(start_dim=1),
      nn.Linear(64 * 28 * 28, 256),
      nn.ReLU()
    )

    # head_cls and head_cnt

    # initial form of heads - it didn't perform well (maximum accuracy it achieved was about 25%)
    #self.head_cls = nn.Linear(256, 135)
    #self.head_cnt = nn.Linear(256, 6)

    # new form for heads - we try deeper approach with dropout to prevent overfitting
    self.head_cls = nn.Sequential(
        nn.Linear(256, 128),
        nn.ReLU(),
        nn.Dropout(p=0.5),
        nn.Linear(128, 135)
    )

    self.head_cnt = nn.Sequential(
        nn.Linear(256, 32),
        nn.ReLU(),
        nn.Linear(32, 6)
    )

  def forward(self, x: Tensor) -> Tensor:
    x = self.backbone(x) # (batch_size, 256)
    logits_cls = self.head_cls(x)
    counts_cnt = self.head_cnt(x)
    log_probs_cls = F.log_softmax(logits_cls, dim=1)

    return log_probs_cls, counts_cnt

# %% [markdown]
# ## **5. Traning Loop**
# ---
# Here the function *run_training* was defined, which will be widely used during experimentation. The function has all necessary functionalities and handles:
#
#
# * **Modes:** Multitask, Classification-only and Regression-only. Each of this modes operates using different loss function.
# * **Metrics calculation:** Function keeps track of training loss, accuracy, F1-score, per-pair accuracy, RMSE and MAE. Function returns metrics history, enabling the user to analyze training progression.
# * **Early stopping:** Parameters *patience* and *desired_accuracy* are responsible for defining early stopping conditions enabling finishing training before reaching maximum number of epochs.
# * **Saving:** When the training is finished, functions saves model parameters to *.pth* file.
#
# The function consists of training part, in which training is done, and validation part, where metrics are calculated.

# %%
# To run final experiments, we define function, which will be responsible for training
def run_training(mode, lambda_cnt=1, n_epochs=100, lr=1e-3, patience=10, desired_accuracy=0.45):

  # inicializing model
  model = Model().to(device)
  optimizer = optim.Adam(model.parameters(), lr=lr)

  # parameters for early stopping mechanism
  epochs_without_improvement = 0
  best_validation_loss = float('inf')

  # defining loss functions
  loss_cls = nn.NLLLoss()
  loss_cnt = nn.SmoothL1Loss()

  # creating lists that will be responsible for storing data that will enable us to create plots about learnig curves and metrics
  history = {
    'avg_train_loss': [], 'total_train_loss': [],
    'avg_validation_loss': [], 'total_validation_loss': [],
    'validation_accuracy': [], 'validation_f1_score': [],
    'validation_per_pair_accuracy': [],
    'validation_rmse': [], 'validation_mae': [],
    'validation_rmse_per_class': [], 'validation_mae_per_class': []
  }

  # setting training mode
  model.train()

  # training loop
  for i in range(n_epochs):
    ### TRAINING SECTION ###
    total_train_loss = 0.0

    for batch_index, (images, counts, labels) in enumerate(train_dataloader):
      images, counts, labels = images.to(device), counts.to(device), labels.to(device)

      optimizer.zero_grad()
      output_cls, output_cnt = model(images)

      # setting the loss function depending on 'mode' parameter
      if mode == "multitask":
        loss = loss_cls(output_cls, labels) + lambda_cnt * loss_cnt(output_cnt, counts)
      elif mode == "classification":
        loss = loss_cls(output_cls, labels)
      elif mode == "regression":
        loss = loss_cnt(output_cnt, counts)
      else:
        raise ValueError("The parameter 'mode' should be equal to 'multitask', 'classification' or 'regression'.")

      loss.backward()
      optimizer.step()
      total_train_loss = total_train_loss + loss.item()

    avg_train_loss = total_train_loss / len(train_dataloader)
    print(f"Epoch {i+1}: Average training loss = {avg_train_loss}")

    # updating history train loss lists
    history['avg_train_loss'].append(avg_train_loss)
    history['total_train_loss'].append(total_train_loss)
    ### END OF TRAINING SECTION ###


    ### VALIDATION SECTION ###
    # switching to evaluation mode
    model.eval()

    # setting up for validation
    total_validation_loss = 0.0
    all_true_labels = []
    all_prediction_labels = []
    all_true_counts = []
    all_prediction_counts = []

    with torch.no_grad():
        for images, counts, labels in validation_dataloader:
          images, counts, labels = images.to(device), counts.to(device), labels.to(device)

          output_cls, output_cnt = model(images)
          # setting the loss function depending on 'mode' parameter
          if mode == "multitask":
            loss = loss_cls(output_cls, labels) + lambda_cnt * loss_cnt(output_cnt, counts)
          elif mode == "classification":
            loss = loss_cls(output_cls, labels)
          elif mode == "regression":
            loss = loss_cnt(output_cnt, counts)
          total_validation_loss = total_validation_loss + loss.item()


          # saving outputs to lists
          # added '.cpu()' to prevent error while working with numpy on gpu
          # saving for cnt part
          all_prediction_counts.append(output_cnt.cpu())
          all_true_counts.append(counts.cpu())

          # saving for cls part
          predicted_labels = output_cls.argmax(dim=1)
          all_prediction_labels.append(predicted_labels.cpu())
          all_true_labels.append(labels.cpu())

    avg_validation_loss = total_validation_loss / len(validation_dataloader)

    # combing results saved in the lists
    validation_prediction_labels = torch.cat(all_prediction_labels) # tensor (1000) with all prediction labels
    validation_true_labels = torch.cat(all_true_labels)
    validation_prediction_counts = torch.cat(all_prediction_counts) # tensor (1000, 6) with all prediction counts
    validation_true_counts = torch.cat(all_true_counts)
    # these tensors will be used to calculate metrics

    # converting tensors to numpy format
    validation_prediction_labels_np = validation_prediction_labels.numpy()
    validation_true_labels_np = validation_true_labels.numpy()
    validation_prediction_counts_np = validation_prediction_counts.numpy()
    validation_true_counts_np = validation_true_counts.numpy()


    # a) calcuating metrics for classification part
    # calculating top1 accuracy
    validation_accuracy = accuracy_score(validation_true_labels_np, validation_prediction_labels_np)

    # calculating f1 score
    # introduced average = "macro", since otherwise it would result in error, because we are in multiclass environment
    validation_f1 = f1_score(validation_true_labels_np, validation_prediction_labels_np, average = 'macro', zero_division=0)

    # calculating 'per-pair accuracy'
    # it will be a bit more complicated than calculating f1 and accuracy
    # we can extract 'pair group' by dividing by 9
    true_pair_group = validation_true_labels_np // 9
    prediction_pair_group = validation_prediction_labels_np // 9

    # count cases when true_pair_group is equal to prediction_pair_group
    correct_pairs = (true_pair_group == prediction_pair_group)

    # compute 'per-pair accuracy'
    validation_per_pair_accuracy = correct_pairs.mean()

    print(f"Validation average training loss: {avg_validation_loss}")
    print(f"Validation metircs: top-1 accuracy = {validation_accuracy}, f1 score = {validation_f1}, per-pair accuracy = {validation_per_pair_accuracy}")

    # b) calculating metrics for regression part
    # RMSE
    mse_loss = nn.MSELoss()
    validation_rmse = torch.sqrt(torch.tensor(mse_loss(validation_true_counts, validation_prediction_counts).item())).item()

    # MAE
    mae_loss = nn.L1Loss()
    validation_mae = mae_loss(validation_true_counts, validation_prediction_counts).item()

    # now we have to compute RMSE and MAE per class
    squared_errors = (validation_prediction_counts - validation_true_counts) ** 2 # (1000, 6)
    absolute_errors = torch.abs(validation_prediction_counts - validation_true_counts) # (1000, 6)

    # we take mean over dim = 0
    mean_squared_errors = torch.mean(squared_errors, dim = 0) # (6)
    mean_absolute_errors = torch.mean(absolute_errors, dim = 0) # (6)

    validation_rmse_per_class = torch.sqrt(mean_squared_errors)
    validation_mae_per_class = mean_absolute_errors

    print(f"Validation metircs: RMSE (overall) = {validation_rmse}, MAE (overall) = {validation_mae}")
    print(f"Validation metircs: RMSE (per class) = {validation_rmse_per_class}, MAE (per class) = {validation_mae_per_class}")

    # updating history validation lists
    history['avg_validation_loss'].append(avg_validation_loss)
    history['total_validation_loss'].append(total_validation_loss)
    history['validation_accuracy'].append(validation_accuracy)
    history['validation_f1_score'].append(validation_f1)
    history['validation_per_pair_accuracy'].append(validation_per_pair_accuracy)
    history['validation_rmse'].append(validation_rmse)
    history['validation_mae'].append(validation_mae)
    history['validation_rmse_per_class'].append(validation_rmse_per_class)
    history['validation_mae_per_class'].append(validation_mae_per_class)
    ### END OF VALIDATION SECTION ###

    # path for saving the model
    save_path = f"model_{mode}.pth"

    # EARLY STOPPING mechanism
    # the mechanism works as follows: we assume that we may wait no more that 'patience' epochs (in our case 'patience'=10) for improvement of avg_validation_loss
    # if for 'patience' epochs we observe no improvement for this metric, then we stop training
    # what is more, we also stop training after achieving 'desired_accuracy' (in our case 'desired_accuracy'=0.45) or higher for accuracy on validation dataset
    if validation_accuracy >= desired_accuracy:
      # executing early stopping and saving the model
      torch.save(model.state_dict(), save_path)
      break

    # patience mechanism
    if avg_validation_loss < best_validation_loss:
      best_validation_loss = avg_validation_loss
      epochs_without_improvement = 0
    else:
      epochs_without_improvement += 1
    # checking if we have already run out of patience
    if epochs_without_improvement >= patience:
      # executing early stopping and saving the model
      torch.save(model.state_dict(), save_path)
      break

    # switching back to training mode
    model.train()

  # saving the model
  torch.save(model.state_dict(), save_path)

  return history

# %% [markdown]
# ## **6. Experiments**
# ---
# After implementing all mandatory code in previous section, we may finally focus on main experimentations. We compare three training strategies:
# 1. **Experiment 1:** Multitask approach with $\lambda = 2$
# 2. **Experiment 2:** Classification-only
# 3. **Experiment 3:** Regression-only
#
# Before running the training, we load training and validation datasets using *GeometricShapeDataset* class

# %%
# loading train dataset with augumentations, validation dataset without augumentations
train_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="train", transform=True)
validation_dataset = GeometricShapesDataset(csv_file_path=csv_file_path, root_directory=data_folder, mode="validation", transform=False)

train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size = 1000, shuffle=False)

# %%
test_histories = {}

# Experiment 1
test_histories["multitask"] = run_training(mode="multitask", lambda_cnt=2, n_epochs=100) #
# Out:
# Epoch 1: Average training loss = 7.558791809893669
# Validation average training loss: 6.8952507972717285
# Validation metircs: top-1 accuracy = 0.033, f1 score = 0.004992197263715049, per-pair accuracy = 0.155
# Validation metircs: RMSE (overall) = 2.513106107711792, MAE (overall) = 1.6170070171356201
# Validation metircs: RMSE (per class) = tensor([2.4253, 2.6940, 1.4678, 2.7915, 2.7457, 2.6961]), MAE (per class) = tensor([1.6936, 1.7942, 0.9582, 1.7726, 1.7692, 1.7142])
# Epoch 2: Average training loss = 6.232441763505868
# Validation average training loss: 5.156594753265381
# Validation metircs: top-1 accuracy = 0.087, f1 score = 0.03559734684321549, per-pair accuracy = 0.306
# Validation metircs: RMSE (overall) = 1.9557961225509644, MAE (overall) = 1.1946274042129517
# Validation metircs: RMSE (per class) = tensor([1.0972, 2.7061, 1.0156, 2.4624, 1.0887, 2.4787]), MAE (per class) = tensor([0.7444, 1.7421, 0.6596, 1.6117, 0.7708, 1.6391])
# Epoch 3: Average training loss = 4.786588643459564
# Validation average training loss: 3.639632225036621
# Validation metircs: top-1 accuracy = 0.224, f1 score = 0.15478502153357573, per-pair accuracy = 0.665
# Validation metircs: RMSE (overall) = 1.2774953842163086, MAE (overall) = 0.865037202835083
# Validation metircs: RMSE (per class) = tensor([0.9694, 1.7050, 0.9944, 1.2222, 1.0372, 1.5449]), MAE (per class) = tensor([0.6840, 1.1779, 0.6550, 0.8592, 0.7287, 1.0854])
# Epoch 4: Average training loss = 3.5082926378182484
# Validation average training loss: 2.785602569580078
# Validation metircs: top-1 accuracy = 0.249, f1 score = 0.1726692366903343, per-pair accuracy = 0.797
# Validation metircs: RMSE (overall) = 0.9881184697151184, MAE (overall) = 0.6503961682319641
# Validation metircs: RMSE (per class) = tensor([0.8062, 1.1552, 0.9145, 1.0164, 0.9264, 1.0707]), MAE (per class) = tensor([0.5650, 0.7445, 0.5815, 0.6842, 0.5939, 0.7333])
# Epoch 5: Average training loss = 2.809641161708967
# Validation average training loss: 2.4473378658294678
# Validation metircs: top-1 accuracy = 0.313, f1 score = 0.2441563412500764, per-pair accuracy = 0.844
# Validation metircs: RMSE (overall) = 0.9129776358604431, MAE (overall) = 0.5991180539131165
# Validation metircs: RMSE (per class) = tensor([0.7604, 0.8721, 0.8145, 1.0685, 0.9634, 0.9640]), MAE (per class) = tensor([0.4790, 0.6214, 0.5001, 0.7821, 0.5736, 0.6385])
# Epoch 6: Average training loss = 2.526575359046882
# Validation average training loss: 2.3354873657226562
# Validation metircs: top-1 accuracy = 0.335, f1 score = 0.27305960526295564, per-pair accuracy = 0.883
# Validation metircs: RMSE (overall) = 0.8868914842605591, MAE (overall) = 0.5795377492904663
# Validation metircs: RMSE (per class) = tensor([0.7773, 0.9756, 0.8410, 1.0316, 0.7910, 0.8754]), MAE (per class) = tensor([0.4737, 0.6411, 0.5488, 0.7338, 0.4868, 0.5930])
# Epoch 7: Average training loss = 2.389458602201854
# Validation average training loss: 2.1971256732940674
# Validation metircs: top-1 accuracy = 0.341, f1 score = 0.27875655144468264, per-pair accuracy = 0.876
# Validation metircs: RMSE (overall) = 0.8310064077377319, MAE (overall) = 0.527993381023407
# Validation metircs: RMSE (per class) = tensor([0.6555, 0.9317, 0.7667, 0.9190, 0.8280, 0.8531]), MAE (per class) = tensor([0.4128, 0.6026, 0.4461, 0.6224, 0.5208, 0.5633])
# Epoch 8: Average training loss = 2.235352188982862
# Validation average training loss: 2.0846781730651855
# Validation metircs: top-1 accuracy = 0.328, f1 score = 0.2661385277022249, per-pair accuracy = 0.892
# Validation metircs: RMSE (overall) = 0.7779515385627747, MAE (overall) = 0.49313852190971375
# Validation metircs: RMSE (per class) = tensor([0.6337, 0.7086, 0.7804, 0.8936, 0.7685, 0.8541]), MAE (per class) = tensor([0.3938, 0.4686, 0.4528, 0.6279, 0.4472, 0.5686])
# Epoch 9: Average training loss = 2.1495732424107006
# Validation average training loss: 2.020141124725342
# Validation metircs: top-1 accuracy = 0.389, f1 score = 0.32750290432016765, per-pair accuracy = 0.916
# Validation metircs: RMSE (overall) = 0.7768610119819641, MAE (overall) = 0.48624905943870544
# Validation metircs: RMSE (per class) = tensor([0.6426, 0.7195, 0.8010, 0.8357, 0.7888, 0.8534]), MAE (per class) = tensor([0.3955, 0.4737, 0.4512, 0.5565, 0.4838, 0.5567])
# Epoch 10: Average training loss = 2.0595035180977894
# Validation average training loss: 2.047166347503662
# Validation metircs: top-1 accuracy = 0.371, f1 score = 0.3342152764994076, per-pair accuracy = 0.908
# Validation metircs: RMSE (overall) = 0.7978081703186035, MAE (overall) = 0.508004367351532
# Validation metircs: RMSE (per class) = tensor([0.6356, 0.8068, 0.9051, 0.8470, 0.7328, 0.8309]), MAE (per class) = tensor([0.4084, 0.5348, 0.5857, 0.5745, 0.4207, 0.5240])
# Epoch 11: Average training loss = 2.0070915315168123
# Validation average training loss: 1.9143742322921753
# Validation metircs: top-1 accuracy = 0.361, f1 score = 0.29837318132005325, per-pair accuracy = 0.912
# Validation metircs: RMSE (overall) = 0.7168060541152954, MAE (overall) = 0.4411383867263794
# Validation metircs: RMSE (per class) = tensor([0.5855, 0.6486, 0.7359, 0.8105, 0.7147, 0.7812]), MAE (per class) = tensor([0.3697, 0.4088, 0.4304, 0.5157, 0.4192, 0.5030])
# Epoch 12: Average training loss = 1.947089896134451
# Validation average training loss: 1.866458535194397
# Validation metircs: top-1 accuracy = 0.387, f1 score = 0.32937600154622376, per-pair accuracy = 0.918
# Validation metircs: RMSE (overall) = 0.7048426866531372, MAE (overall) = 0.4351412355899811
# Validation metircs: RMSE (per class) = tensor([0.5953, 0.6443, 0.7188, 0.7572, 0.7002, 0.7943]), MAE (per class) = tensor([0.3622, 0.4006, 0.4322, 0.5068, 0.4137, 0.4953])
# Epoch 13: Average training loss = 1.8660964044273323
# Validation average training loss: 1.8788304328918457
# Validation metircs: top-1 accuracy = 0.398, f1 score = 0.337700716084565, per-pair accuracy = 0.931
# Validation metircs: RMSE (overall) = 0.7086003422737122, MAE (overall) = 0.4446711540222168
# Validation metircs: RMSE (per class) = tensor([0.7020, 0.6358, 0.7055, 0.7595, 0.6756, 0.7646]), MAE (per class) = tensor([0.4385, 0.4231, 0.4011, 0.5073, 0.3916, 0.5064])
# Epoch 14: Average training loss = 1.812914531281654
# Validation average training loss: 1.737174391746521
# Validation metircs: top-1 accuracy = 0.427, f1 score = 0.38806339234228726, per-pair accuracy = 0.937
# Validation metircs: RMSE (overall) = 0.6694490909576416, MAE (overall) = 0.4103645384311676
# Validation metircs: RMSE (per class) = tensor([0.5506, 0.6042, 0.6995, 0.7309, 0.6738, 0.7370]), MAE (per class) = tensor([0.3341, 0.3672, 0.4123, 0.4848, 0.3956, 0.4682])
# Epoch 15: Average training loss = 1.7718064396093922
# Validation average training loss: 1.7982807159423828
# Validation metircs: top-1 accuracy = 0.427, f1 score = 0.3783087950503545, per-pair accuracy = 0.929
# Validation metircs: RMSE (overall) = 0.6845356225967407, MAE (overall) = 0.42731571197509766
# Validation metircs: RMSE (per class) = tensor([0.5531, 0.6254, 0.7248, 0.7297, 0.6916, 0.7605]), MAE (per class) = tensor([0.3469, 0.3721, 0.4371, 0.4911, 0.3993, 0.5173])
# Epoch 16: Average training loss = 1.722244235640722
# Validation average training loss: 1.7752482891082764
# Validation metircs: top-1 accuracy = 0.427, f1 score = 0.38092101959570535, per-pair accuracy = 0.932
# Validation metircs: RMSE (overall) = 0.6879015564918518, MAE (overall) = 0.4212178885936737
# Validation metircs: RMSE (per class) = tensor([0.6667, 0.6204, 0.7097, 0.7106, 0.6846, 0.7298]), MAE (per class) = tensor([0.3954, 0.3679, 0.4303, 0.4761, 0.3857, 0.4718])
# Epoch 17: Average training loss = 1.680383436223294
# Validation average training loss: 1.800971269607544
# Validation metircs: top-1 accuracy = 0.39, f1 score = 0.35062964420511783, per-pair accuracy = 0.925
# Validation metircs: RMSE (overall) = 0.683169424533844, MAE (overall) = 0.4212961792945862
# Validation metircs: RMSE (per class) = tensor([0.5751, 0.6003, 0.7416, 0.6983, 0.7114, 0.7521]), MAE (per class) = tensor([0.3335, 0.3536, 0.4499, 0.4631, 0.4193, 0.5083])
# Epoch 18: Average training loss = 1.6876985899945522
# Validation average training loss: 1.7962398529052734
# Validation metircs: top-1 accuracy = 0.406, f1 score = 0.3646778706627528, per-pair accuracy = 0.928
# Validation metircs: RMSE (overall) = 0.675682544708252, MAE (overall) = 0.41180655360221863
# Validation metircs: RMSE (per class) = tensor([0.5473, 0.6148, 0.7545, 0.7089, 0.6728, 0.7330]), MAE (per class) = tensor([0.3236, 0.3728, 0.4755, 0.4599, 0.3856, 0.4535])
# Epoch 19: Average training loss = 1.59826996394083
# Validation average training loss: 1.7609617710113525
# Validation metircs: top-1 accuracy = 0.43, f1 score = 0.39286544975992865, per-pair accuracy = 0.925
# Validation metircs: RMSE (overall) = 0.6598722338676453, MAE (overall) = 0.398629367351532
# Validation metircs: RMSE (per class) = tensor([0.6249, 0.6119, 0.6690, 0.6846, 0.6539, 0.7099]), MAE (per class) = tensor([0.3589, 0.3866, 0.3833, 0.4462, 0.3730, 0.4438])
# Epoch 20: Average training loss = 1.5534302232958745
# Validation average training loss: 1.7707542181015015
# Validation metircs: top-1 accuracy = 0.436, f1 score = 0.38618905417185057, per-pair accuracy = 0.923
# Validation metircs: RMSE (overall) = 0.6716673970222473, MAE (overall) = 0.41187354922294617
# Validation metircs: RMSE (per class) = tensor([0.5572, 0.6346, 0.6930, 0.7259, 0.6659, 0.7368]), MAE (per class) = tensor([0.3439, 0.3735, 0.3880, 0.4930, 0.3865, 0.4863])
# Epoch 21: Average training loss = 1.549023777880567
# Validation average training loss: 1.7257976531982422
# Validation metircs: top-1 accuracy = 0.443, f1 score = 0.3810742565958616, per-pair accuracy = 0.944
# Validation metircs: RMSE (overall) = 0.653689980506897, MAE (overall) = 0.3982665240764618
# Validation metircs: RMSE (per class) = tensor([0.5532, 0.5824, 0.6510, 0.6830, 0.6912, 0.7420]), MAE (per class) = tensor([0.3204, 0.3517, 0.3760, 0.4476, 0.4053, 0.4886])
# Epoch 22: Average training loss = 1.4921391982558772
# Validation average training loss: 1.7720528841018677
# Validation metircs: top-1 accuracy = 0.423, f1 score = 0.3846819992331776, per-pair accuracy = 0.928
# Validation metircs: RMSE (overall) = 0.6754506230354309, MAE (overall) = 0.4070813059806824
# Validation metircs: RMSE (per class) = tensor([0.5374, 0.6826, 0.6803, 0.6992, 0.7395, 0.6958]), MAE (per class) = tensor([0.3047, 0.4341, 0.3860, 0.4494, 0.4091, 0.4592])
# Epoch 23: Average training loss = 1.4847920177676153
# Validation average training loss: 1.7528345584869385
# Validation metircs: top-1 accuracy = 0.421, f1 score = 0.38052415810181256, per-pair accuracy = 0.927
# Validation metircs: RMSE (overall) = 0.6547008752822876, MAE (overall) = 0.3891337215900421
# Validation metircs: RMSE (per class) = tensor([0.5504, 0.5506, 0.7174, 0.7006, 0.6639, 0.7207]), MAE (per class) = tensor([0.3285, 0.3233, 0.3940, 0.4622, 0.3731, 0.4537])
# Epoch 24: Average training loss = 1.440863089358553
# Validation average training loss: 1.6674658060073853
# Validation metircs: top-1 accuracy = 0.466, f1 score = 0.4202992390613766, per-pair accuracy = 0.942
# Validation metircs: RMSE (overall) = 0.6297126412391663, MAE (overall) = 0.37777888774871826
# Validation metircs: RMSE (per class) = tensor([0.5198, 0.5656, 0.6403, 0.6720, 0.6696, 0.6924]), MAE (per class) = tensor([0.3079, 0.3239, 0.3729, 0.4330, 0.3854, 0.4437])

# %%
# Experiment 2
test_histories["classification"] = run_training(mode="classification", n_epochs=100) # 43,4 w 50### 45 w 35epoce### 45,5 w 33
# Out:
# Epoch 1: Average training loss = 4.775612864933961
# Validation average training loss: 4.696201324462891
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0001885902876001886, per-pair accuracy = 0.071
# Validation metircs: RMSE (overall) = 3.1225290298461914, MAE (overall) = 1.7440874576568604
# Validation metircs: RMSE (per class) = tensor([3.0780, 3.0593, 3.2943, 3.2498, 3.0833, 2.9577]), MAE (per class) = tensor([1.6632, 1.6837, 1.9434, 1.8237, 1.6606, 1.6901])
# Epoch 2: Average training loss = 4.696332627154411
# Validation average training loss: 4.669124603271484
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.0002444413105814883, per-pair accuracy = 0.067
# Validation metircs: RMSE (overall) = 3.1248979568481445, MAE (overall) = 1.7464585304260254
# Validation metircs: RMSE (per class) = tensor([3.0599, 3.0544, 3.2791, 3.2708, 3.0868, 2.9863]), MAE (per class) = tensor([1.6753, 1.6863, 1.9175, 1.8608, 1.6670, 1.6717])
# Epoch 3: Average training loss = 4.683130751264856
# Validation average training loss: 4.664646148681641
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.0001698994761432819, per-pair accuracy = 0.064
# Validation metircs: RMSE (overall) = 3.124396562576294, MAE (overall) = 1.7340686321258545
# Validation metircs: RMSE (per class) = tensor([3.0874, 3.0692, 3.2757, 3.2458, 3.0840, 2.9735]), MAE (per class) = tensor([1.6570, 1.6770, 1.9117, 1.8166, 1.6621, 1.6800])
# Epoch 4: Average training loss = 4.675103586616245
# Validation average training loss: 4.661620140075684
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.00013240648791790796, per-pair accuracy = 0.064
# Validation metircs: RMSE (overall) = 3.1230835914611816, MAE (overall) = 1.743295431137085
# Validation metircs: RMSE (per class) = tensor([3.0691, 3.0607, 3.2787, 3.2638, 3.0833, 2.9709]), MAE (per class) = tensor([1.6692, 1.6827, 1.9170, 1.8485, 1.6608, 1.6815])
# Epoch 5: Average training loss = 4.671044211015634
# Validation average training loss: 4.660250186920166
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.00023205221174764322, per-pair accuracy = 0.075
# Validation metircs: RMSE (overall) = 3.1178700923919678, MAE (overall) = 1.7316231727600098
# Validation metircs: RMSE (per class) = tensor([3.0829, 3.0584, 3.2602, 3.2443, 3.0830, 2.9681]), MAE (per class) = tensor([1.6606, 1.6845, 1.8861, 1.8147, 1.6605, 1.6834])
# Epoch 6: Average training loss = 4.643919511889735
# Validation average training loss: 4.377048015594482
# Validation metircs: top-1 accuracy = 0.024, f1 score = 0.0035911942772112225, per-pair accuracy = 0.156
# Validation metircs: RMSE (overall) = 3.1101534366607666, MAE (overall) = 1.7729299068450928
# Validation metircs: RMSE (per class) = tensor([3.1162, 3.0222, 3.2459, 3.2909, 3.0427, 2.9275]), MAE (per class) = tensor([1.7319, 1.7234, 1.9106, 1.8401, 1.7000, 1.7316])
# Epoch 7: Average training loss = 3.8776127649537213
# Validation average training loss: 3.2701940536499023
# Validation metircs: top-1 accuracy = 0.079, f1 score = 0.03258790982677831, per-pair accuracy = 0.368
# Validation metircs: RMSE (overall) = 3.122037172317505, MAE (overall) = 1.8105040788650513
# Validation metircs: RMSE (per class) = tensor([3.0665, 3.0227, 3.1809, 3.3262, 3.1086, 3.0161]), MAE (per class) = tensor([1.7419, 1.7451, 1.9110, 1.9479, 1.7446, 1.7726])
# Epoch 8: Average training loss = 3.2247677965367094
# Validation average training loss: 2.7829110622406006
# Validation metircs: top-1 accuracy = 0.178, f1 score = 0.1178113751378165, per-pair accuracy = 0.542
# Validation metircs: RMSE (overall) = 3.148898124694824, MAE (overall) = 1.8515864610671997
# Validation metircs: RMSE (per class) = tensor([3.0782, 3.0610, 3.1917, 3.2819, 3.1567, 3.1186]), MAE (per class) = tensor([1.8049, 1.7730, 1.9410, 1.9344, 1.7855, 1.8707])
# Epoch 9: Average training loss = 2.7513757343833327
# Validation average training loss: 2.2769556045532227
# Validation metircs: top-1 accuracy = 0.241, f1 score = 0.1645935259474765, per-pair accuracy = 0.743
# Validation metircs: RMSE (overall) = 3.164543867111206, MAE (overall) = 1.9195151329040527
# Validation metircs: RMSE (per class) = tensor([3.0259, 3.1106, 3.1735, 3.2540, 3.1690, 3.2483]), MAE (per class) = tensor([1.8091, 1.8899, 1.9894, 1.9765, 1.8270, 2.0252])
# Epoch 10: Average training loss = 2.3283362304065243
# Validation average training loss: 1.952373743057251
# Validation metircs: top-1 accuracy = 0.29, f1 score = 0.22339359962829453, per-pair accuracy = 0.802
# Validation metircs: RMSE (overall) = 3.1686925888061523, MAE (overall) = 1.939725637435913
# Validation metircs: RMSE (per class) = tensor([2.9822, 3.1296, 3.1971, 3.2481, 3.1844, 3.2624]), MAE (per class) = tensor([1.8327, 1.9131, 2.0288, 1.9825, 1.8298, 2.0515])
# Epoch 11: Average training loss = 2.0485065127095434
# Validation average training loss: 1.8354648351669312
# Validation metircs: top-1 accuracy = 0.292, f1 score = 0.24379555156092755, per-pair accuracy = 0.837
# Validation metircs: RMSE (overall) = 3.132871150970459, MAE (overall) = 1.9114726781845093
# Validation metircs: RMSE (per class) = tensor([2.9927, 3.0262, 3.0664, 3.2942, 3.1975, 3.2087]), MAE (per class) = tensor([1.8237, 1.8495, 1.8644, 2.0026, 1.8631, 2.0656])
# Epoch 12: Average training loss = 1.8959387532362701
# Validation average training loss: 1.6427381038665771
# Validation metircs: top-1 accuracy = 0.345, f1 score = 0.29985944510866314, per-pair accuracy = 0.889
# Validation metircs: RMSE (overall) = 3.1573879718780518, MAE (overall) = 1.9398056268692017
# Validation metircs: RMSE (per class) = tensor([3.0009, 3.0730, 3.1111, 3.2823, 3.2323, 3.2351]), MAE (per class) = tensor([1.8565, 1.8958, 1.9196, 2.0049, 1.8843, 2.0777])
# Epoch 13: Average training loss = 1.7921375797149983
# Validation average training loss: 1.609355092048645
# Validation metircs: top-1 accuracy = 0.356, f1 score = 0.29322670041863036, per-pair accuracy = 0.903
# Validation metircs: RMSE (overall) = 3.1554770469665527, MAE (overall) = 1.9324674606323242
# Validation metircs: RMSE (per class) = tensor([2.9822, 3.0428, 3.1265, 3.2737, 3.2329, 3.2628]), MAE (per class) = tensor([1.8398, 1.8817, 1.9069, 2.0049, 1.8735, 2.0881])
# Epoch 14: Average training loss = 1.7186727870440652
# Validation average training loss: 1.6027575731277466
# Validation metircs: top-1 accuracy = 0.388, f1 score = 0.3199920913594871, per-pair accuracy = 0.89
# Validation metircs: RMSE (overall) = 3.149568796157837, MAE (overall) = 1.9298512935638428
# Validation metircs: RMSE (per class) = tensor([2.9636, 3.0433, 3.0952, 3.2625, 3.2640, 3.2552]), MAE (per class) = tensor([1.8475, 1.8787, 1.8868, 2.0240, 1.8786, 2.0635])
# Epoch 15: Average training loss = 1.644781857517594
# Validation average training loss: 1.5673049688339233
# Validation metircs: top-1 accuracy = 0.348, f1 score = 0.2938940160470061, per-pair accuracy = 0.895
# Validation metircs: RMSE (overall) = 3.1442244052886963, MAE (overall) = 1.9348421096801758
# Validation metircs: RMSE (per class) = tensor([2.9376, 3.0278, 3.0834, 3.3009, 3.2292, 3.2694]), MAE (per class) = tensor([1.8344, 1.8845, 1.8770, 2.0288, 1.8764, 2.1079])
# Epoch 16: Average training loss = 1.5978644156286903
# Validation average training loss: 1.573865532875061
# Validation metircs: top-1 accuracy = 0.355, f1 score = 0.31767265728304783, per-pair accuracy = 0.907
# Validation metircs: RMSE (overall) = 3.13750958442688, MAE (overall) = 1.9355354309082031
# Validation metircs: RMSE (per class) = tensor([2.9497, 3.0250, 3.0595, 3.3429, 3.2068, 3.2240]), MAE (per class) = tensor([1.8236, 1.8909, 1.8706, 2.0757, 1.8688, 2.0836])
# Epoch 17: Average training loss = 1.5495406837328105
# Validation average training loss: 1.4915555715560913
# Validation metircs: top-1 accuracy = 0.374, f1 score = 0.3320124474977547, per-pair accuracy = 0.925
# Validation metircs: RMSE (overall) = 3.1644229888916016, MAE (overall) = 1.949330449104309
# Validation metircs: RMSE (per class) = tensor([2.9723, 3.0223, 3.0598, 3.3322, 3.2779, 3.3018]), MAE (per class) = tensor([1.8514, 1.8937, 1.8843, 2.0511, 1.8983, 2.1170])
# Epoch 18: Average training loss = 1.5183348841700994
# Validation average training loss: 1.4610575437545776
# Validation metircs: top-1 accuracy = 0.385, f1 score = 0.33909858237335755, per-pair accuracy = 0.917
# Validation metircs: RMSE (overall) = 3.1526098251342773, MAE (overall) = 1.9453222751617432
# Validation metircs: RMSE (per class) = tensor([2.9359, 3.0467, 3.0863, 3.3421, 3.2348, 3.2516]), MAE (per class) = tensor([1.8224, 1.8842, 1.9176, 2.0842, 1.8908, 2.0726])
# Epoch 19: Average training loss = 1.4517637939317851
# Validation average training loss: 1.4215631484985352
# Validation metircs: top-1 accuracy = 0.391, f1 score = 0.35346303081792185, per-pair accuracy = 0.934
# Validation metircs: RMSE (overall) = 3.1661064624786377, MAE (overall) = 1.9491910934448242
# Validation metircs: RMSE (per class) = tensor([2.9750, 3.0359, 3.0970, 3.3245, 3.2789, 3.2685]), MAE (per class) = tensor([1.8490, 1.8837, 1.9089, 2.0654, 1.8985, 2.0897])
# Epoch 20: Average training loss = 1.439941259140664
# Validation average training loss: 1.4514966011047363
# Validation metircs: top-1 accuracy = 0.404, f1 score = 0.3566150911081087, per-pair accuracy = 0.919
# Validation metircs: RMSE (overall) = 3.155893325805664, MAE (overall) = 1.9418567419052124
# Validation metircs: RMSE (per class) = tensor([2.9314, 3.0137, 3.0718, 3.3255, 3.2821, 3.2886]), MAE (per class) = tensor([1.8237, 1.8661, 1.8658, 2.0740, 1.9111, 2.1105])
# Epoch 21: Average training loss = 1.4210201983756208
# Validation average training loss: 1.405326008796692
# Validation metircs: top-1 accuracy = 0.411, f1 score = 0.37036831506236434, per-pair accuracy = 0.932
# Validation metircs: RMSE (overall) = 3.1585798263549805, MAE (overall) = 1.9455852508544922
# Validation metircs: RMSE (per class) = tensor([2.9687, 3.0520, 3.0921, 3.3207, 3.2321, 3.2706]), MAE (per class) = tensor([1.8392, 1.8967, 1.9092, 2.0373, 1.8913, 2.0999])
# Epoch 22: Average training loss = 1.3750677869675008
# Validation average training loss: 1.3789359331130981
# Validation metircs: top-1 accuracy = 0.407, f1 score = 0.3717003635014733, per-pair accuracy = 0.937
# Validation metircs: RMSE (overall) = 3.1555702686309814, MAE (overall) = 1.944139838218689
# Validation metircs: RMSE (per class) = tensor([2.9342, 3.0553, 3.1062, 3.3087, 3.2536, 3.2589]), MAE (per class) = tensor([1.8261, 1.8931, 1.9175, 2.0567, 1.8901, 2.0814])
# Epoch 23: Average training loss = 1.3447026741420123
# Validation average training loss: 1.4030424356460571
# Validation metircs: top-1 accuracy = 0.418, f1 score = 0.3806000038073513, per-pair accuracy = 0.929
# Validation metircs: RMSE (overall) = 3.158292293548584, MAE (overall) = 1.9466012716293335
# Validation metircs: RMSE (per class) = tensor([2.9454, 3.0608, 3.1080, 3.3060, 3.2444, 3.2696]), MAE (per class) = tensor([1.8344, 1.9000, 1.9360, 2.0492, 1.8831, 2.0769])
# Epoch 24: Average training loss = 1.3011193600952202
# Validation average training loss: 1.4199455976486206
# Validation metircs: top-1 accuracy = 0.407, f1 score = 0.352216505597747, per-pair accuracy = 0.922
# Validation metircs: RMSE (overall) = 3.164323568344116, MAE (overall) = 1.9459686279296875
# Validation metircs: RMSE (per class) = tensor([2.9462, 3.0661, 3.1000, 3.3000, 3.2643, 3.2925]), MAE (per class) = tensor([1.8350, 1.8998, 1.9170, 2.0336, 1.8879, 2.1024])
# Epoch 25: Average training loss = 1.2921036566402895
# Validation average training loss: 1.3998963832855225
# Validation metircs: top-1 accuracy = 0.417, f1 score = 0.3756071377284633, per-pair accuracy = 0.934
# Validation metircs: RMSE (overall) = 3.1620712280273438, MAE (overall) = 1.94813871383667
# Validation metircs: RMSE (per class) = tensor([2.9398, 3.0327, 3.0862, 3.3355, 3.2815, 3.2763]), MAE (per class) = tensor([1.8289, 1.8835, 1.8903, 2.0716, 1.9190, 2.0956])
# Epoch 26: Average training loss = 1.2720011946157361
# Validation average training loss: 1.4058603048324585
# Validation metircs: top-1 accuracy = 0.433, f1 score = 0.3937120999538783, per-pair accuracy = 0.935
# Validation metircs: RMSE (overall) = 3.1608424186706543, MAE (overall) = 1.9349430799484253
# Validation metircs: RMSE (per class) = tensor([2.9271, 3.0423, 3.0897, 3.3535, 3.2731, 3.2583]), MAE (per class) = tensor([1.8016, 1.8738, 1.8882, 2.0663, 1.9013, 2.0786])
# Epoch 27: Average training loss = 1.230046735587695
# Validation average training loss: 1.4617465734481812
# Validation metircs: top-1 accuracy = 0.404, f1 score = 0.37570641634295654, per-pair accuracy = 0.925
# Validation metircs: RMSE (overall) = 3.1528234481811523, MAE (overall) = 1.9291435480117798
# Validation metircs: RMSE (per class) = tensor([2.9562, 3.0382, 3.0920, 3.3069, 3.2649, 3.2429]), MAE (per class) = tensor([1.8330, 1.8646, 1.8808, 2.0346, 1.8961, 2.0657])
# Epoch 28: Average training loss = 1.1977033137429691
# Validation average training loss: 1.398755669593811
# Validation metircs: top-1 accuracy = 0.43, f1 score = 0.3988658027256201, per-pair accuracy = 0.935
# Validation metircs: RMSE (overall) = 3.158059597015381, MAE (overall) = 1.939357876777649
# Validation metircs: RMSE (per class) = tensor([2.9297, 3.0518, 3.0843, 3.3355, 3.2661, 3.2614]), MAE (per class) = tensor([1.8234, 1.8757, 1.8912, 2.0580, 1.8989, 2.0889])
# Epoch 29: Average training loss = 1.1821064403716555
# Validation average training loss: 1.3883835077285767
# Validation metircs: top-1 accuracy = 0.452, f1 score = 0.41420893734279923, per-pair accuracy = 0.936
# Validation metircs: RMSE (overall) = 3.1589622497558594, MAE (overall) = 1.9400361776351929
# Validation metircs: RMSE (per class) = tensor([2.9282, 3.0601, 3.1124, 3.3130, 3.2461, 3.2764]), MAE (per class) = tensor([1.8159, 1.8961, 1.9128, 2.0429, 1.8885, 2.0840])

# %%
# Experiment 3
test_histories["regression"] = run_training(mode="regression", n_epochs=100) #
# Out:
# Epoch 1: Average training loss = 1.4117596107171781
# Validation average training loss: 1.3331981897354126
# Validation metircs: top-1 accuracy = 0.006, f1 score = 0.0009575307782703647, per-pair accuracy = 0.036
# Validation metircs: RMSE (overall) = 2.7052202224731445, MAE (overall) = 1.706407070159912
# Validation metircs: RMSE (per class) = tensor([2.7539, 2.8911, 2.8304, 2.9436, 2.6886, 2.0155]), MAE (per class) = tensor([1.7368, 1.8112, 1.7073, 1.8605, 1.6879, 1.4347])
# Epoch 2: Average training loss = 1.0610360135423376
# Validation average training loss: 0.7624160051345825
# Validation metircs: top-1 accuracy = 0.0, f1 score = 0.0, per-pair accuracy = 0.01
# Validation metircs: RMSE (overall) = 1.8568845987319946, MAE (overall) = 1.0966953039169312
# Validation metircs: RMSE (per class) = tensor([1.0456, 2.8332, 1.0073, 2.5942, 1.5721, 1.1627]), MAE (per class) = tensor([0.7612, 1.7944, 0.6970, 1.5801, 0.9724, 0.7751])
# Epoch 3: Average training loss = 0.5851461528040839
# Validation average training loss: 0.48202651739120483
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.0005785602115877345, per-pair accuracy = 0.026
# Validation metircs: RMSE (overall) = 1.3518792390823364, MAE (overall) = 0.7878736853599548
# Validation metircs: RMSE (per class) = tensor([0.8654, 2.5448, 0.8928, 0.9593, 0.9938, 1.0177]), MAE (per class) = tensor([0.6210, 1.5692, 0.5906, 0.6546, 0.6269, 0.6649])
# Epoch 4: Average training loss = 0.3935983045726803
# Validation average training loss: 0.3291877210140228
# Validation metircs: top-1 accuracy = 0.0, f1 score = 0.0, per-pair accuracy = 0.035
# Validation metircs: RMSE (overall) = 0.9269213676452637, MAE (overall) = 0.6310796141624451
# Validation metircs: RMSE (per class) = tensor([0.7774, 1.0234, 0.8463, 0.9742, 0.9980, 0.9176]), MAE (per class) = tensor([0.5092, 0.7977, 0.5648, 0.6968, 0.6220, 0.5960])
# Epoch 5: Average training loss = 0.2890942530006382
# Validation average training loss: 0.28687044978141785
# Validation metircs: top-1 accuracy = 0.001, f1 score = 0.00010214504596527068, per-pair accuracy = 0.035
# Validation metircs: RMSE (overall) = 0.8519238233566284, MAE (overall) = 0.5815051794052124
# Validation metircs: RMSE (per class) = tensor([0.7124, 0.9060, 0.8129, 0.8594, 0.8706, 0.9323]), MAE (per class) = tensor([0.4715, 0.6979, 0.5239, 0.5968, 0.5487, 0.6503])
# Epoch 6: Average training loss = 0.2519757351342668
# Validation average training loss: 0.24986179172992706
# Validation metircs: top-1 accuracy = 0.003, f1 score = 0.0004899194372878584, per-pair accuracy = 0.042
# Validation metircs: RMSE (overall) = 0.7910670042037964, MAE (overall) = 0.52750164270401
# Validation metircs: RMSE (per class) = tensor([0.6538, 0.8254, 0.7423, 0.8245, 0.8454, 0.8371]), MAE (per class) = tensor([0.4504, 0.6245, 0.4819, 0.5472, 0.5230, 0.5381])
# Epoch 7: Average training loss = 0.22518833288064238
# Validation average training loss: 0.24774517118930817
# Validation metircs: top-1 accuracy = 0.005, f1 score = 0.0011082251082251081, per-pair accuracy = 0.045
# Validation metircs: RMSE (overall) = 0.7834118008613586, MAE (overall) = 0.5186249613761902
# Validation metircs: RMSE (per class) = tensor([0.6820, 0.7901, 0.7318, 0.8766, 0.7938, 0.8117]), MAE (per class) = tensor([0.4342, 0.5810, 0.4709, 0.6212, 0.4987, 0.5058])
# Epoch 8: Average training loss = 0.21318619217432982
# Validation average training loss: 0.25940173864364624
# Validation metircs: top-1 accuracy = 0.003, f1 score = 0.0010232947997066322, per-pair accuracy = 0.035
# Validation metircs: RMSE (overall) = 0.8110030889511108, MAE (overall) = 0.5362799763679504
# Validation metircs: RMSE (per class) = tensor([0.6535, 0.7772, 0.7806, 0.7758, 0.9829, 0.8590]), MAE (per class) = tensor([0.4466, 0.5751, 0.5416, 0.5337, 0.6124, 0.5082])
# Epoch 9: Average training loss = 0.20006359638051785
# Validation average training loss: 0.21476583182811737
# Validation metircs: top-1 accuracy = 0.005, f1 score = 0.0015070189065760089, per-pair accuracy = 0.041
# Validation metircs: RMSE (overall) = 0.7284894585609436, MAE (overall) = 0.46697932481765747
# Validation metircs: RMSE (per class) = tensor([0.6130, 0.7118, 0.6900, 0.7299, 0.7587, 0.8469]), MAE (per class) = tensor([0.3860, 0.5162, 0.4403, 0.4763, 0.4671, 0.5160])
# Epoch 10: Average training loss = 0.1808812972290296
# Validation average training loss: 0.2074362337589264
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.002331199491122391, per-pair accuracy = 0.05
# Validation metircs: RMSE (overall) = 0.7134135961532593, MAE (overall) = 0.4589848220348358
# Validation metircs: RMSE (per class) = tensor([0.6228, 0.6940, 0.6854, 0.7311, 0.7430, 0.7924]), MAE (per class) = tensor([0.4176, 0.4919, 0.4391, 0.4724, 0.4690, 0.4639])
# Epoch 11: Average training loss = 0.16706801443657976
# Validation average training loss: 0.2198951244354248
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.0033830038121082898, per-pair accuracy = 0.063
# Validation metircs: RMSE (overall) = 0.7322954535484314, MAE (overall) = 0.4814271628856659
# Validation metircs: RMSE (per class) = tensor([0.5783, 0.7908, 0.6783, 0.8032, 0.7423, 0.7755]), MAE (per class) = tensor([0.3722, 0.6210, 0.4316, 0.5074, 0.4958, 0.4605])
# Epoch 12: Average training loss = 0.15857306656473918
# Validation average training loss: 0.2053120881319046
# Validation metircs: top-1 accuracy = 0.008, f1 score = 0.0006500403239533673, per-pair accuracy = 0.046
# Validation metircs: RMSE (overall) = 0.7101696133613586, MAE (overall) = 0.4511722922325134
# Validation metircs: RMSE (per class) = tensor([0.5712, 0.6809, 0.6942, 0.7143, 0.7166, 0.8547]), MAE (per class) = tensor([0.3612, 0.4716, 0.4560, 0.4622, 0.4649, 0.4912])
# Epoch 13: Average training loss = 0.15066623296720763
# Validation average training loss: 0.2021062970161438
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0022992949351135937, per-pair accuracy = 0.061
# Validation metircs: RMSE (overall) = 0.7045150995254517, MAE (overall) = 0.44688278436660767
# Validation metircs: RMSE (per class) = tensor([0.5739, 0.6735, 0.7392, 0.7347, 0.7406, 0.7485]), MAE (per class) = tensor([0.3754, 0.4770, 0.4840, 0.4486, 0.4702, 0.4261])
# Epoch 14: Average training loss = 0.14140040237218776
# Validation average training loss: 0.18331904709339142
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.001489695519212871, per-pair accuracy = 0.051
# Validation metircs: RMSE (overall) = 0.6659442186355591, MAE (overall) = 0.41765400767326355
# Validation metircs: RMSE (per class) = tensor([0.5539, 0.6356, 0.6729, 0.6794, 0.6942, 0.7443]), MAE (per class) = tensor([0.3463, 0.4442, 0.4238, 0.4174, 0.4391, 0.4352])
# Epoch 15: Average training loss = 0.13717714121155705
# Validation average training loss: 0.19106364250183105
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.0016355702161289214, per-pair accuracy = 0.048
# Validation metircs: RMSE (overall) = 0.6783158779144287, MAE (overall) = 0.4320746958255768
# Validation metircs: RMSE (per class) = tensor([0.5613, 0.6300, 0.7178, 0.7195, 0.6942, 0.7306]), MAE (per class) = tensor([0.3459, 0.4354, 0.4657, 0.4821, 0.4426, 0.4208])
# Epoch 16: Average training loss = 0.12795191934556827
# Validation average training loss: 0.1796322762966156
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0023593903312859946, per-pair accuracy = 0.055
# Validation metircs: RMSE (overall) = 0.6540387868881226, MAE (overall) = 0.41288068890571594
# Validation metircs: RMSE (per class) = tensor([0.5755, 0.6320, 0.6595, 0.6580, 0.6897, 0.7018]), MAE (per class) = tensor([0.3724, 0.4459, 0.4027, 0.3958, 0.4382, 0.4223])
# Epoch 17: Average training loss = 0.12202997590210421
# Validation average training loss: 0.17893430590629578
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.001695726999775603, per-pair accuracy = 0.051
# Validation metircs: RMSE (overall) = 0.6584264636039734, MAE (overall) = 0.40732795000076294
# Validation metircs: RMSE (per class) = tensor([0.5653, 0.6198, 0.6476, 0.6763, 0.6924, 0.7357]), MAE (per class) = tensor([0.3377, 0.4333, 0.3910, 0.3966, 0.4570, 0.4283])
# Epoch 18: Average training loss = 0.11926600226062409
# Validation average training loss: 0.19184720516204834
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.002972877095920809, per-pair accuracy = 0.059
# Validation metircs: RMSE (overall) = 0.6843394041061401, MAE (overall) = 0.42668840289115906
# Validation metircs: RMSE (per class) = tensor([0.5475, 0.6761, 0.6735, 0.6692, 0.7148, 0.8004]), MAE (per class) = tensor([0.3488, 0.4699, 0.4179, 0.4037, 0.4430, 0.4768])
# Epoch 19: Average training loss = 0.10614030253379902
# Validation average training loss: 0.18225088715553284
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.0028018521933329235, per-pair accuracy = 0.048
# Validation metircs: RMSE (overall) = 0.6671099066734314, MAE (overall) = 0.40968334674835205
# Validation metircs: RMSE (per class) = tensor([0.5475, 0.6147, 0.6560, 0.6525, 0.7801, 0.7267]), MAE (per class) = tensor([0.3348, 0.4283, 0.4024, 0.3833, 0.4902, 0.4191])
# Epoch 20: Average training loss = 0.10347588291616304
# Validation average training loss: 0.17522574961185455
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.0012395771024164546, per-pair accuracy = 0.046
# Validation metircs: RMSE (overall) = 0.6474325656890869, MAE (overall) = 0.40370020270347595
# Validation metircs: RMSE (per class) = tensor([0.5350, 0.6128, 0.6634, 0.6664, 0.6788, 0.7130]), MAE (per class) = tensor([0.3266, 0.4211, 0.4170, 0.3999, 0.4393, 0.4183])
# Epoch 21: Average training loss = 0.09915669029908823
# Validation average training loss: 0.17399585247039795
# Validation metircs: top-1 accuracy = 0.014, f1 score = 0.0027427276025319158, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.648979663848877, MAE (overall) = 0.399952232837677
# Validation metircs: RMSE (per class) = tensor([0.5252, 0.6084, 0.6402, 0.7042, 0.6744, 0.7215]), MAE (per class) = tensor([0.3251, 0.4302, 0.3876, 0.4000, 0.4484, 0.4084])
# Epoch 22: Average training loss = 0.09309689362421103
# Validation average training loss: 0.16986773908138275
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.0022470416168062757, per-pair accuracy = 0.058
# Validation metircs: RMSE (overall) = 0.637896716594696, MAE (overall) = 0.39208635687828064
# Validation metircs: RMSE (per class) = tensor([0.5340, 0.5904, 0.6279, 0.6507, 0.6845, 0.7222]), MAE (per class) = tensor([0.3260, 0.4068, 0.3868, 0.3745, 0.4352, 0.4231])
# Epoch 23: Average training loss = 0.09028207574118959
# Validation average training loss: 0.16959933936595917
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.0021311817210535, per-pair accuracy = 0.047
# Validation metircs: RMSE (overall) = 0.6377333998680115, MAE (overall) = 0.39210355281829834
# Validation metircs: RMSE (per class) = tensor([0.5391, 0.5909, 0.6237, 0.6603, 0.6809, 0.7154]), MAE (per class) = tensor([0.3380, 0.4062, 0.3840, 0.3812, 0.4337, 0.4095])
# Epoch 24: Average training loss = 0.08625858858333411
# Validation average training loss: 0.1804284304380417
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0023318776785645123, per-pair accuracy = 0.047
# Validation metircs: RMSE (overall) = 0.6575226783752441, MAE (overall) = 0.4083920419216156
# Validation metircs: RMSE (per class) = tensor([0.5549, 0.6047, 0.6904, 0.6614, 0.7011, 0.7175]), MAE (per class) = tensor([0.3537, 0.4114, 0.4266, 0.3992, 0.4473, 0.4122])
# Epoch 25: Average training loss = 0.0806394859567179
# Validation average training loss: 0.17231164872646332
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.0018315130220705785, per-pair accuracy = 0.055
# Validation metircs: RMSE (overall) = 0.6453732848167419, MAE (overall) = 0.3891485333442688
# Validation metircs: RMSE (per class) = tensor([0.5281, 0.5939, 0.6363, 0.6547, 0.7138, 0.7241]), MAE (per class) = tensor([0.3171, 0.3996, 0.3862, 0.3758, 0.4443, 0.4119])
# Epoch 26: Average training loss = 0.07455347171911957
# Validation average training loss: 0.16681504249572754
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.0023335904009091934, per-pair accuracy = 0.06
# Validation metircs: RMSE (overall) = 0.6353461742401123, MAE (overall) = 0.3847423195838928
# Validation metircs: RMSE (per class) = tensor([0.5260, 0.5823, 0.6270, 0.6584, 0.6577, 0.7396]), MAE (per class) = tensor([0.3184, 0.3990, 0.3852, 0.3856, 0.4146, 0.4055])
# Epoch 27: Average training loss = 0.0727477438008109
# Validation average training loss: 0.17091107368469238
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.003249191765614518, per-pair accuracy = 0.062
# Validation metircs: RMSE (overall) = 0.6425175070762634, MAE (overall) = 0.38978350162506104
# Validation metircs: RMSE (per class) = tensor([0.5342, 0.5973, 0.6193, 0.6867, 0.6645, 0.7336]), MAE (per class) = tensor([0.3247, 0.4131, 0.3731, 0.3968, 0.4193, 0.4117])
# Epoch 28: Average training loss = 0.06833192204118621
# Validation average training loss: 0.17025204002857208
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.002996657256956153, per-pair accuracy = 0.056
# Validation metircs: RMSE (overall) = 0.6406664252281189, MAE (overall) = 0.3866244852542877
# Validation metircs: RMSE (per class) = tensor([0.5289, 0.5872, 0.6197, 0.6621, 0.6982, 0.7269]), MAE (per class) = tensor([0.3157, 0.3956, 0.3768, 0.3839, 0.4369, 0.4110])
# Epoch 29: Average training loss = 0.0659006416322069
# Validation average training loss: 0.16872960329055786
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.001996282774276577, per-pair accuracy = 0.043
# Validation metircs: RMSE (overall) = 0.6365708112716675, MAE (overall) = 0.38843896985054016
# Validation metircs: RMSE (per class) = tensor([0.5329, 0.6313, 0.6106, 0.6601, 0.6544, 0.7155]), MAE (per class) = tensor([0.3326, 0.4160, 0.3688, 0.3891, 0.4209, 0.4031])
# Epoch 30: Average training loss = 0.06275066482365554
# Validation average training loss: 0.18155965209007263
# Validation metircs: top-1 accuracy = 0.009, f1 score = 0.001792431544938479, per-pair accuracy = 0.046
# Validation metircs: RMSE (overall) = 0.6655767560005188, MAE (overall) = 0.40480583906173706
# Validation metircs: RMSE (per class) = tensor([0.5827, 0.6051, 0.6733, 0.6711, 0.6715, 0.7731]), MAE (per class) = tensor([0.3549, 0.4031, 0.4170, 0.4001, 0.4365, 0.4171])
# Epoch 31: Average training loss = 0.06002542424075147
# Validation average training loss: 0.1754407286643982
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.0017040135055401378, per-pair accuracy = 0.05
# Validation metircs: RMSE (overall) = 0.651606023311615, MAE (overall) = 0.3948118984699249
# Validation metircs: RMSE (per class) = tensor([0.5493, 0.6189, 0.6184, 0.6544, 0.7111, 0.7392]), MAE (per class) = tensor([0.3326, 0.4123, 0.3756, 0.3792, 0.4486, 0.4205])
# Epoch 32: Average training loss = 0.05536391852912328
# Validation average training loss: 0.16273850202560425
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.0018702861272427548, per-pair accuracy = 0.054
# Validation metircs: RMSE (overall) = 0.6277056932449341, MAE (overall) = 0.37654149532318115
# Validation metircs: RMSE (per class) = tensor([0.5315, 0.5696, 0.6110, 0.6692, 0.6463, 0.7199]), MAE (per class) = tensor([0.3183, 0.3814, 0.3574, 0.3709, 0.4210, 0.4102])
# Epoch 33: Average training loss = 0.05459327298275968
# Validation average training loss: 0.1719202697277069
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0020219987879359458, per-pair accuracy = 0.04
# Validation metircs: RMSE (overall) = 0.6456509232521057, MAE (overall) = 0.389211505651474
# Validation metircs: RMSE (per class) = tensor([0.5495, 0.6202, 0.6343, 0.6407, 0.6673, 0.7459]), MAE (per class) = tensor([0.3236, 0.4211, 0.3840, 0.3665, 0.4244, 0.4156])
# Epoch 34: Average training loss = 0.05156789120313124
# Validation average training loss: 0.16628924012184143
# Validation metircs: top-1 accuracy = 0.008, f1 score = 0.0017600482757246854, per-pair accuracy = 0.04
# Validation metircs: RMSE (overall) = 0.6323001980781555, MAE (overall) = 0.3807670772075653
# Validation metircs: RMSE (per class) = tensor([0.5296, 0.5733, 0.6264, 0.6324, 0.6879, 0.7241]), MAE (per class) = tensor([0.3106, 0.3917, 0.3800, 0.3613, 0.4361, 0.4050])
# Epoch 35: Average training loss = 0.04615707280682334
# Validation average training loss: 0.16319653391838074
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.0026626077165286094, per-pair accuracy = 0.058
# Validation metircs: RMSE (overall) = 0.6278403401374817, MAE (overall) = 0.374432772397995
# Validation metircs: RMSE (per class) = tensor([0.5143, 0.5753, 0.6188, 0.6354, 0.6663, 0.7341]), MAE (per class) = tensor([0.3032, 0.3917, 0.3660, 0.3601, 0.4276, 0.3981])
# Epoch 36: Average training loss = 0.0453714833508992
# Validation average training loss: 0.16314224898815155
# Validation metircs: top-1 accuracy = 0.014, f1 score = 0.002407345306406339, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.6258922219276428, MAE (overall) = 0.3759208917617798
# Validation metircs: RMSE (per class) = tensor([0.5128, 0.5774, 0.6104, 0.6507, 0.6642, 0.7189]), MAE (per class) = tensor([0.3017, 0.3953, 0.3601, 0.3602, 0.4226, 0.4156])
# Epoch 37: Average training loss = 0.044314667556091404
# Validation average training loss: 0.16823825240135193
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.002511168001360507, per-pair accuracy = 0.053
# Validation metircs: RMSE (overall) = 0.6376813650131226, MAE (overall) = 0.3811804950237274
# Validation metircs: RMSE (per class) = tensor([0.5374, 0.5794, 0.6248, 0.6593, 0.6821, 0.7245]), MAE (per class) = tensor([0.3090, 0.3943, 0.3721, 0.3770, 0.4319, 0.4029])
# Epoch 38: Average training loss = 0.04247103576013382
# Validation average training loss: 0.16104954481124878
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.002241234271993845, per-pair accuracy = 0.056
# Validation metircs: RMSE (overall) = 0.6226694583892822, MAE (overall) = 0.37038111686706543
# Validation metircs: RMSE (per class) = tensor([0.5202, 0.5720, 0.6155, 0.6534, 0.6616, 0.6965]), MAE (per class) = tensor([0.3008, 0.3883, 0.3610, 0.3664, 0.4167, 0.3891])
# Epoch 39: Average training loss = 0.039247915994191
# Validation average training loss: 0.16584612429141998
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0014759788229989548, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.6320676207542419, MAE (overall) = 0.3766314387321472
# Validation metircs: RMSE (per class) = tensor([0.5251, 0.5760, 0.6231, 0.6431, 0.6780, 0.7267]), MAE (per class) = tensor([0.3062, 0.3848, 0.3796, 0.3682, 0.4269, 0.3940])
# Epoch 40: Average training loss = 0.03982995533721244
# Validation average training loss: 0.17107883095741272
# Validation metircs: top-1 accuracy = 0.013, f1 score = 0.0018911198321983947, per-pair accuracy = 0.066
# Validation metircs: RMSE (overall) = 0.6432672142982483, MAE (overall) = 0.38751423358917236
# Validation metircs: RMSE (per class) = tensor([0.5579, 0.5864, 0.6261, 0.6556, 0.6935, 0.7244]), MAE (per class) = tensor([0.3442, 0.3927, 0.3646, 0.3842, 0.4336, 0.4059])
# Epoch 41: Average training loss = 0.03792718025122551
# Validation average training loss: 0.16354218125343323
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.001938205361642992, per-pair accuracy = 0.072
# Validation metircs: RMSE (overall) = 0.6273514628410339, MAE (overall) = 0.37340474128723145
# Validation metircs: RMSE (per class) = tensor([0.5221, 0.5737, 0.6293, 0.6463, 0.6679, 0.7070]), MAE (per class) = tensor([0.3107, 0.3788, 0.3746, 0.3662, 0.4186, 0.3916])
# Epoch 42: Average training loss = 0.03562175417781299
# Validation average training loss: 0.16588754951953888
# Validation metircs: top-1 accuracy = 0.012, f1 score = 0.0014832721520876234, per-pair accuracy = 0.066
# Validation metircs: RMSE (overall) = 0.6344907283782959, MAE (overall) = 0.375082790851593
# Validation metircs: RMSE (per class) = tensor([0.5719, 0.5784, 0.6166, 0.6451, 0.6697, 0.7134]), MAE (per class) = tensor([0.3226, 0.3888, 0.3645, 0.3624, 0.4246, 0.3875])
# Epoch 43: Average training loss = 0.03669895410062151
# Validation average training loss: 0.1709384322166443
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0016780699219423618, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.6433423757553101, MAE (overall) = 0.38427481055259705
# Validation metircs: RMSE (per class) = tensor([0.5394, 0.5966, 0.6243, 0.6537, 0.6716, 0.7539]), MAE (per class) = tensor([0.3119, 0.3950, 0.3748, 0.3660, 0.4272, 0.4308])
# Epoch 44: Average training loss = 0.03452318370447937
# Validation average training loss: 0.17061232030391693
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.001653829171368297, per-pair accuracy = 0.064
# Validation metircs: RMSE (overall) = 0.6416888236999512, MAE (overall) = 0.38346806168556213
# Validation metircs: RMSE (per class) = tensor([0.5261, 0.5970, 0.6184, 0.6516, 0.6813, 0.7525]), MAE (per class) = tensor([0.3070, 0.4000, 0.3734, 0.3656, 0.4262, 0.4288])
# Epoch 45: Average training loss = 0.03226196948201098
# Validation average training loss: 0.17433536052703857
# Validation metircs: top-1 accuracy = 0.008, f1 score = 0.0013147234761977965, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.6476526856422424, MAE (overall) = 0.38660648465156555
# Validation metircs: RMSE (per class) = tensor([0.5293, 0.6162, 0.6253, 0.6689, 0.6925, 0.7341]), MAE (per class) = tensor([0.3023, 0.4193, 0.3658, 0.3763, 0.4388, 0.4170])
# Epoch 46: Average training loss = 0.03185678243055834
# Validation average training loss: 0.16255776584148407
# Validation metircs: top-1 accuracy = 0.01, f1 score = 0.0019315643896221021, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.623317539691925, MAE (overall) = 0.36988019943237305
# Validation metircs: RMSE (per class) = tensor([0.5164, 0.5813, 0.6130, 0.6363, 0.6693, 0.7057]), MAE (per class) = tensor([0.3017, 0.3831, 0.3560, 0.3631, 0.4263, 0.3890])
# Epoch 47: Average training loss = 0.02778605917957446
# Validation average training loss: 0.16196520626544952
# Validation metircs: top-1 accuracy = 0.007, f1 score = 0.0005546445840729938, per-pair accuracy = 0.056
# Validation metircs: RMSE (overall) = 0.622866690158844, MAE (overall) = 0.3699052035808563
# Validation metircs: RMSE (per class) = tensor([0.5194, 0.5801, 0.6070, 0.6279, 0.6621, 0.7213]), MAE (per class) = tensor([0.3015, 0.3885, 0.3637, 0.3518, 0.4201, 0.3939])
# Epoch 48: Average training loss = 0.027402480212139323
# Validation average training loss: 0.16105398535728455
# Validation metircs: top-1 accuracy = 0.011, f1 score = 0.001581239217642535, per-pair accuracy = 0.057
# Validation metircs: RMSE (overall) = 0.6203484535217285, MAE (overall) = 0.3696659207344055
# Validation metircs: RMSE (per class) = tensor([0.5219, 0.5852, 0.6049, 0.6278, 0.6625, 0.7037]), MAE (per class) = tensor([0.3051, 0.3915, 0.3521, 0.3454, 0.4236, 0.4003])

# %% [markdown]
# ## **7. Plot section**
# ---
# This section consists of functions, which will be used for vizualziation and analysis purposes:
# 1.  ***plot_results:*** creates plots for single model, which will vizualize the dynamics of metrics during training.
# 2.  ***plot_comparison:*** shows comparison of metrics throughout training for three models developed in pevious section.
# 3. ***plot_confusion_matrix:*** generatesconfusion matrix dor certain model.

# %%
# plots function for generating plots for single model

def plot_results(history):
  total_epochs = len(history['avg_train_loss'])
  x_axis = range(1, total_epochs + 1)

  # Plot 1 (Average training and validation loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['avg_train_loss'], label = "Average training loss")
  plt.plot(x_axis, history['avg_validation_loss'], label = "Average validation loss")
  plt.title("Average training loss vs. Average validation loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 2 (Total training loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['total_train_loss'], label = "Total training loss")
  plt.title("Total training loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 3 (Total validation loss)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['total_validation_loss'], color = "tab:orange", label = "Total validation loss")
  plt.title("Total validation loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 4 (Validation accuracy)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_accuracy'], color = "tab:orange", label = "Validation accuracy")
  plt.title("Validation accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 5 (Validation f1 score)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_f1_score'], color = "tab:orange", label = "Validation F1-score")
  plt.title("Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 6 (Validation per-pair accuracy)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_per_pair_accuracy'], color = "tab:orange", label = "Validation per-pair accuracy")
  plt.title("Validation per-pair accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Per-pair accuracy")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 7 (Validation RMSE)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_rmse'], color = "tab:orange", label = "Validation RMSE")
  plt.title("Validation RMSE")
  plt.xlabel("Epoch")
  plt.ylabel("RMSE")
  plt.legend()
  plt.grid(True)
  plt.show()

  # Plot 8 (Validation MAE)
  plt.figure(figsize = (10, 6))
  plt.plot(x_axis, history['validation_mae'], color = "tab:orange", label = "Validation MAE")
  plt.title("Validation MAE")
  plt.xlabel("Epoch")
  plt.ylabel("MAE")
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
plot_results(test_histories['multitask'])
plot_results(test_histories['classification'])
plot_results(test_histories['regression'])

# %%
# plots function for generating comparison plots for different models

def plot_comparison(histories):
    x_axis_multitask = range(1, len(histories['multitask']['avg_train_loss']) + 1)
    x_axis_classification = range(1, len(histories['classification']['avg_train_loss']) + 1)
    x_axis_regression = range(1, len(histories['regression']['avg_train_loss']) + 1)

    # Plot 1 (Accuracy)
    accuracy_multitask = histories['multitask']['validation_accuracy']
    accuracy_classification = histories['classification']['validation_accuracy']
    accuracy_regression = histories['regression']['validation_accuracy']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, accuracy_multitask, label = f"Multitask (Max = {max(accuracy_multitask):.2%})")
    plt.plot(x_axis_classification, accuracy_classification, label = f"Classification (Max = {max(accuracy_classification):.2%})")
    plt.plot(x_axis_regression, accuracy_regression, label = f"Regression (Max = {max(accuracy_regression):.2%})")
    plt.title("Model comparison: Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 2 (f1-score)
    f1_multitask = histories['multitask']['validation_f1_score']
    f1_classification = histories['classification']['validation_f1_score']
    f1_regression = histories['regression']['validation_f1_score']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, f1_multitask, label = f"Multitask (Max = {max(f1_multitask):.2%})")
    plt.plot(x_axis_classification, f1_classification, label = f"Classification (Max = {max(f1_classification):.2%})")
    plt.plot(x_axis_regression, f1_regression, label = f"Regression (Max = {max(f1_regression):.2%})")
    plt.title("Model comparison: F1-score")
    plt.xlabel("Epoch")
    plt.ylabel("F1-score")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 3 (per-pair accuracy)
    per_pair_accuracy_multitask = histories['multitask']['validation_per_pair_accuracy']
    per_pair_accuracy_classification = histories['classification']['validation_per_pair_accuracy']
    per_pair_accuracy_regression = histories['regression']['validation_per_pair_accuracy']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, per_pair_accuracy_multitask, label = f"Multitask (Max = {max(per_pair_accuracy_multitask):.2%})")
    plt.plot(x_axis_classification, per_pair_accuracy_classification, label = f"Classification (Max = {max(per_pair_accuracy_classification):.2%})")
    plt.plot(x_axis_regression, per_pair_accuracy_regression, label = f"Regression (Max = {max(per_pair_accuracy_regression):.2%})")
    plt.title("Model comparison: per-pair accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Per-pair accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 4 (RMSE)
    rmse_multitask = histories['multitask']['validation_rmse']
    rmse_classification = histories['classification']['validation_rmse']
    rmse_regression = histories['regression']['validation_rmse']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, rmse_multitask, label = f"Multitask (Min = {min(rmse_multitask):.2%})")
    plt.plot(x_axis_classification, rmse_classification, label = f"Classification (Min = {min(rmse_classification):.2%})")
    plt.plot(x_axis_regression, rmse_regression, label = f"Regression (Min = {min(rmse_regression):.2%})")
    plt.title("Model comparison: RMSE")
    plt.xlabel("Epoch")
    plt.ylabel("RMSE")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 5 (MAE)
    mae_multitask = histories['multitask']['validation_mae']
    mae_classification = histories['classification']['validation_mae']
    mae_regression = histories['regression']['validation_mae']

    plt.figure(figsize = (10, 6))
    plt.plot(x_axis_multitask, mae_multitask, label = f"Multitask (Min = {min(mae_multitask):.2%})")
    plt.plot(x_axis_classification, mae_classification, label = f"Classification (Min = {min(mae_classification):.2%})")
    plt.plot(x_axis_regression, mae_regression, label = f"Regression (Min = {min(mae_regression):.2%})")
    plt.title("Model comparison: MAE")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_comparison(test_histories)

# %%
def plot_confusion_matrix(model, loader, device):

    # setting evaluation mode
    model.eval()

    all_prediction_labels = []
    all_true_labels = []

    with torch.no_grad():
        for images, counts, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            output_cls, output_cnt = model(images)
            prediction_labels = output_cls.argmax(dim=1)

            all_prediction_labels.extend(prediction_labels.cpu().numpy())
            all_true_labels.extend(labels.cpu().numpy())

    # vizualizing for 135 distinct classes would be too cluttered, so we want to showcase less objects in our confusion matrix
    # converting classes to class groups
    true_pairs = np.array(all_true_labels) // 9
    prediction_pairs = np.array(all_prediction_labels) // 9

    # preparing labels for confusion matrix
    shape_names = ['square', 'circle', 'up', 'right', 'down', 'left']
    pairs = sorted([(i, j) for i in range(6) for j in range(i + 1, 6)])
    pair_labels = [f"{shape_names[p[0]]}+{shape_names[p[1]]}" for p in pairs]

    # computing confusion matrix
    cm = confusion_matrix(true_pairs, prediction_pairs)

    # plotting heatmap
    plt.figure(figsize=(10, 6))
    sns.heatmap(cm, annot=True, xticklabels=pair_labels, yticklabels=pair_labels)
    plt.title('Confusion Matrix')
    plt.ylabel('True pair')
    plt.xlabel('Prediction pair')
    #plt.xticks(rotation=45)
    #plt.tight_layout()
    plt.show()

# %%
def load_model(save_path):
    model = Model()

    # loading model
    model.load_state_dict(torch.load(save_path))
    model.to(device)

    # setting evaluation mode
    model.eval()

    return model

# %%
# loading models
multitask_model = load_model("model_multitask.pth")
classification_model = load_model("model_classification.pth")
regression_model = load_model("model_regression.pth")

# plotting confusion matrices
plot_confusion_matrix(multitask_model, validation_dataloader, device)
plot_confusion_matrix(classification_model, validation_dataloader, device)
plot_confusion_matrix(regression_model, validation_dataloader, device)
