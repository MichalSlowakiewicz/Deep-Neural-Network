# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSlowakiewicz/Deep-Neural-Network/blob/master/LAB_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# Code based on https://github.com/pytorch/examples/blob/master/mnist/main.py
#
# In this exercise, we are using high-level abstractions from torch.nn like nn.Linear.
# Note: during the next lab session we will go one level deeper and implement more things
# with bare hands.
#
# Tasks:
#
#  1. Read the code.
#
#  2. Check that the given implementation reaches 95% test accuracy for architecture input-128-128-10 after few epochs.
#
#  3. Add the option to use SGD with momentum instead of ADAM.
#
#  4. Experiment with different learning rates. Use the provided TrainingVisualizer
#  to plot the learning curves and gradient-to-weight ratios. Compare visualizations
#  for different learning rates for both ADAM and SGD with momentum.
#
#  5. Parameterize the constructor by a list of sizes of hidden layers of the MLP.
#  Note that this requires creating a list of layers as an attribute of the Net class,
#  and one can't use a standard Python list containing nn.Modules (why?).
#  Check torch.nn.ModuleList.
#
# If you run this notebook locally then you may need to install some packages.
# It may be achieved by adding the following code cell to the notebook and running it:
# ```
# !pip install torch torchvision plotly ipywidgets
# ```
# This notebook can also utilize Colab GPU. However, remember to kill your GPU session after classes as otherwise, you may use all your free GPU time for this week.

# %%
import math
import sysParameterize the constructor by a list of sizes of hidden layers of the MLP. Note that this requires creating a list of layers as an attribute of the Net class, and one can't use a standard Python list containing nn.Modules (why?). Check torch.nn.ModuleList.

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import plotly.graph_objects as go
from torch import Tensor
from torchvision import datasets, transforms

# Allow custom (non-ipywidget) widgets.
if "google.colab" in sys.modules:
    from google.colab import output

    output.enable_custom_widget_manager()

# For reproducibility.
torch.manual_seed(1)

# %% [markdown]
# ## Tensors
# In ML, *tensor* is just a short name for an n-dimensional array.
#
# In other areas like physics, it might mean a multilinear operation that can be represented, after a choice of basis, by an ndarray; this is where we would see all the extra stuff (like covariance/contravariance), like for example on the Wikipedia article for "tensor". For us, it's usually just a bunch of numbers.
#
# torch.Tensor is can be thought of as a wrapper around numpy ndarray, but:
# * the interface is slightly different (like `np.expand_dims(x, dim=n-1)` vs `torch.unsqueeze(x, axis=-1)`);
# * the data can be stored in GPU memory (or others);
# * it can be part of a computation graph: a computed Tensor has pointers to other Tensors it was computed from, and to functions computing partial derivatives.
#
# All the operations defined on for a torch.Tensor (`@`, `.arctan`, `.unsqueeze`, and a hundred others) can also run on a GPU and

# %%
x_np = np.array([[0, 1, 2], [3, 4, 5]])
x = torch.tensor([[0, 1, 2], [3, 4, 5]])  # Also: torch.rand, ones, zeros, rand_like, ...
display(x_np, x)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])
# tensor([[0, 1, 2],
#         [3, 4, 5]])

# %%
torch.from_numpy(x_np).equal(x), np.array_equal(x_np, x.numpy())
# Out:
# (True, True)

# %%
x.shape, x.dtype, x.device, x.requires_grad
# Out:
# (torch.Size([2, 3]), torch.int64, device(type='cpu'), False)

# %% [markdown]
# Most operations have an in-place variant with the same name, but with an underscore.
# This forgets the original value, making the computation of gradients impossible, so most of the time we don't use in-place operations.

# %%
x.add_(2)
display(x)
# Out:
# tensor([[2, 3, 4],
#         [5, 6, 7]])

# %% [markdown]
# ## Autograd
# Operations on torch tensors remember the computation graph.
# This allows to compute the gradient of e.g. a loss node over all other nodes with loss.backward().

# %%
x = torch.tensor([[0., 1., 2.], [3., 4., 5.]], requires_grad=True)
y = torch.sigmoid(x)
loss = (((y - 1) ** 2).mean())
print("x", x.grad_fn, ", y", y.grad_fn, ", loss", loss.grad_fn)
print(loss.grad_fn.next_functions)  # type: ignore
print(loss.grad_fn.next_functions[0][0].next_functions)  # type: ignore
# Out:
# x None , y <SigmoidBackward0 object at 0x78e30035f100> , loss <MeanBackward0 object at 0x78e3001dd1e0>
# ((<PowBackward0 object at 0x78e30035f100>, 0),)
# ((<SubBackward0 object at 0x78e30035f100>, 0),)

# %% [markdown]
# The method Tensor.backward():
# * for each node with `requires_grad`: computes the gradients from each .grad_fn and propagates it using the chain rule.
# * for each leaf node (`requires_grad` with no predecessors that `requires_grad`): accumulates the gradient into the tensor’s `.grad` attribute.

# %%
loss.backward()
x.grad
# Out:
# tensor([[-4.1667e-02, -1.7626e-02, -4.1719e-03],
#         [-7.1418e-04, -1.0590e-04, -1.4831e-05]])

# %% [markdown]
# We say *accumulates* not *stores*, because if .grad already exists, `backward()` adds to it, instead of replacing it.

# %%
loss2 = ((x * 0).mean())
loss2.backward()
x.grad
# Out:
# tensor([[-4.1667e-02, -1.7626e-02, -4.1719e-03],
#         [-7.1418e-04, -1.0590e-04, -1.4831e-05]])

# %% [markdown]
# During (for example) evaluation, you don't need to store the computational graph, so you can disable it:

# %%
with torch.no_grad():
    y = x * x

print(y.grad_fn)
# Out:
# None

# %% [markdown]
# In some situations you may need more fine-grained control.
# You can detach a tensor from the graph, to treat it like a constant tensor.

# %%
y = x * x
print(y.grad_fn, y.requires_grad)
y = y.detach()  # Not in-place, returns a new tensor with the same data.
print(y.grad_fn, y.requires_grad)
# Out:
# <MulBackward0 object at 0x78e30035f9a0> True
# None False

# %% [markdown]
# ## Modules
# A torch **module** (not *model*) is essentially just an object with a `forward()` method, usually `forward(x: Tensor) -> Tensor`.
# A network (model) is built as a large module that contains and calls smaller modules, which themselves contain even smaller modules.
#
# Basically any callable could be a module, but subclassing `nn.Module` adds features like:
# * automatically registering and enumerating submodules and trainable parameters,
# * serializing and storing parameters into files,
# * adding hooks in the middle of existing models.

# %%
class MyLinear(nn.Module):
    """
    This is essentially the same as nn.Linear.

    Compare: https://github.com/pytorch/pytorch/blob/v2.9.0/torch/nn/modules/linear.py#L53
    """
    def __init__(self, in_features: int, out_features: int) -> None:
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features

        self.weight = nn.Parameter(torch.empty((out_features, in_features)))
        self.bias = nn.Parameter(torch.empty(out_features))

        self.reset_parameters()

    def reset_parameters(self) -> None:
        # The initialization used by PyTorch by default, including non-zero biases.
        bound = 1 / math.sqrt(self.in_features)
        nn.init.uniform_(self.weight, -bound, bound)
        nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input: Tensor) -> Tensor:
        """
        Input shape: (B*, in_features).
        Output shape: (B*, out_features).
        """
        return input @ self.weight.T + self.bias

# %% [markdown]
# We define the module behaviour in the **`forward()`** method, not in the special `__call__()`.<br>
# However, we then use the module directly as a callable, `module()`.<br>
# This will call `module.forward()`, but can also calls hooks, if any are defined.

# %%
module = MyLinear(2, 3)
x = torch.rand((7, 5, 2))
y = module(x)
y.shape
# Out:
# torch.Size([7, 5, 3])

# %% [markdown]
# The class **nn.Parameter** just wraps a tensor to indicate that this is a trainable parameter, and changes the default `requires_grad`.<br>
# When an nn.Parameter is assigned to a field of an nn.Module, it automatically registers it,
# so that all parameters of this modules and its submodules can be easily accessed.

# %%
for i, (name, param) in enumerate(module.named_parameters()):
    print(f'{i}. "{name}":\t{param}\n')
# Out:
# 0. "weight":	Parameter containing:
# tensor([[ 0.3643, -0.3121],
#         [-0.1371,  0.3319],
#         [-0.6657,  0.4241]], requires_grad=True)
#
# 1. "bias":	Parameter containing:
# tensor([-0.1455,  0.3597,  0.0983], requires_grad=True)

# %% [markdown]
# ## A basic Net

# %%
class Net(nn.Module):
    def __init__(self, hidden_layer_sizes = [128, 128]):
        super().__init__()
        layer_sizes = [784] + hidden_layer_sizes + [10]
        layers = []
        for i in range(len(layer_sizes) - 1):
            layers.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))

        self.layers = nn.ModuleList(layers)

    def forward(self, x: Tensor) -> Tensor:
        """
        Input: shape (B, 28, 28).
        Output: class probabilities (after softmax), shape (B, 10).
        """
        x = torch.flatten(x, start_dim=1)  # (B, 784)
        for i, layer in enumerate(self.layers):
            x = layer(x)
            if i < len(self.layers) - 1: # Apply ReLU to all but the last layer
                x = F.relu(x)
        output = F.log_softmax(x, dim=1)
        return output

# %% [markdown]
# Assigning to a nn.Module to a field of nn.Module automatically registers it as a submodule.<br>
# You can iterate over all submodules (recursively) with `.named_modules()` or over direct children only with `.named_children()`.

# %%
net = Net(hidden_layer_sizes = [ 100,50])
for i, (name, submodule) in enumerate(net.named_modules()):
    print(f'{i}. "{name}":\t{submodule}')
# Out:
# 0. "":	Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=784, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=50, bias=True)
#     (2): Linear(in_features=50, out_features=10, bias=True)
#   )
# )
# 1. "layers":	ModuleList(
#   (0): Linear(in_features=784, out_features=100, bias=True)
#   (1): Linear(in_features=100, out_features=50, bias=True)
#   (2): Linear(in_features=50, out_features=10, bias=True)
# )
# 2. "layers.0":	Linear(in_features=784, out_features=100, bias=True)
# 3. "layers.1":	Linear(in_features=100, out_features=50, bias=True)
# 4. "layers.2":	Linear(in_features=50, out_features=10, bias=True)

# %% [markdown]
# The `.train()` and `.eval()` methods set the `training` flag of a module and all its submodules.<br>
# This changes the behaviour of certain modules like BatchNorm and Dropout (see next labs).
#
# Forgetting to switch the training mode is a common bug that can cause weird behaviour.

# %%
net.train()
print(net.fc1.training)
net.eval()
print(net.fc1.training)
# Out:
# True
# False

# %% [markdown]
# Note that operations on a module (`.train()`, `.eval()`, `.to(dtype)`, `.to(device)`) modify it in-place.<br>
# Operations on a tensor without a trailing underscore (including `.to(dtype)`, `.to(device)`) return a new tensor and leave the original unchanged

# %% [markdown]
# ## Train and test code

# %%
# @title <small>Helper class: TrainingVisualizer</small>

class TrainingVisualizer:
    def __init__(self, log_interval: int = 10):
        self.log_interval = log_interval
        self.train_loss_fig = self.init_line_plot(
            title="Training loss", xaxis_title="Step"
        )
        self.grad_to_weight_fig = self.init_line_plot(
            title="Gradient standard deviation to weight standard deviation ratio at 1st layer",
            xaxis_title="Step",
            yaxis_title="Gradient to weight ratio (log scale)",
            yaxis_type="log",
        )
        self.test_acc_fig = self.init_line_plot(
            title="Test accuracy", x=[], xaxis_title="Epoch", mode="lines+markers"
        )

        # Parameters related to current tracked model and its training
        self.first_linear_layer = None
        self.lr = None
        self.trace_idx = -1

    def init_line_plot(
        self,
        title: str,
        x=None,
        xaxis_title: str | None = None,
        yaxis_title: str | None = None,
        yaxis_type: str = "linear",
        mode: str = "lines",
    ) -> go.FigureWidget:
        fig = go.Figure()
        fig.update_layout(
            title=title,
            title_x=0.5,
            xaxis_title=xaxis_title,
            yaxis_title=yaxis_title,
            height=400,
            width=1500,
            margin=dict(b=10, t=60),
        )
        fig.update_yaxes(type=yaxis_type)
        # We cannot add new traces dynamically because Colab has a problem with widgets
        # from plotly (traces added dynamically are rendered twice).
        # As an ugly workaround we create a lot of empty traces and update them later
        # with actual data. Empty traces are not plotted.
        for _ in range(25):
            fig.add_trace(go.Scatter(x=x, y=[], showlegend=True, mode=mode))

        fig_widget = go.FigureWidget(fig)
        display(fig_widget)
        return fig_widget

    def track_model(
        self, model: torch.nn.Module, optimizer: torch.optim.Optimizer, lr: float
    ) -> None:
        """
        Start tracking training metrics for a new model.
        """

        for field in model.__dict__["_modules"].values():
            if isinstance(field, nn.Linear):
                self.first_linear_layer = field
                break
            elif isinstance(field, nn.ModuleList):
                self.first_linear_layer = field[0]
                break

        self.lr = lr
        self.trace_idx += 1

        optim_name = type(optimizer).__name__
        self.train_loss_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"
        self.grad_to_weight_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"
        self.test_acc_fig.data[self.trace_idx].name = f"{optim_name}, {lr}"

    def plot_gradients_and_loss(self, batch_idx: int, loss: float) -> None:
        if batch_idx % self.log_interval == 0:
            self.train_loss_fig.data[self.trace_idx].y += (loss,)

            layer = self.first_linear_layer
            grad_to_weight_ratio = (
                self.lr * layer.weight.grad.std() / layer.weight.std()
            ).item()

            self.grad_to_weight_fig.data[self.trace_idx].y += (grad_to_weight_ratio,)

    def plot_accuracy(self, epoch: int, accuracy: float) -> None:
        self.test_acc_fig.data[self.trace_idx].x += (epoch,)
        self.test_acc_fig.data[self.trace_idx].y += (accuracy,)

# %%
def train_epoch(
    model: torch.nn.Module,
    device: torch.device,
    train_loader: torch.utils.data.DataLoader,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    log_interval: int,
    visualizer: TrainingVisualizer,
    verbose: bool = False,
) -> None:
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # Move data to the device (e.g. GPU #0) where model parameters are.
        data, target = data.to(device), target.to(device)

        # Since `backward()` will accumuate gradients, remember to reset them.
        optimizer.zero_grad()

        # Forward pass.
        output = model(data)  # Logs of class probabilites, shape (B, 10)
        loss = F.nll_loss(output, target)  # Shape (1,)

        # Backward pass.
        loss.backward()

        visualizer.plot_gradients_and_loss(batch_idx, loss.item())

        # For each parameter, updates the tensor's value using its .grad.
        optimizer.step()

        if batch_idx % log_interval == 0:
            if verbose:
                done, total = batch_idx * len(data), len(train_loader.dataset)
                print(
                    f"Train Epoch: {epoch} [{done}/{total} images ({done / total:.0%})]\t"
                    + f"Loss: {loss.item():.6f}"
                )

# %%
def test(
    model: torch.nn.Module,
    device: torch.device,
    test_loader: torch.utils.data.DataLoader,
    epoch: int,
    visualizer: TrainingVisualizer,
    verbose: bool = False,
) -> None:
    model.eval()
    test_loss = 0
    n_correct = 0
    n_total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            # Accumulate sum of dataitem losses and only divide by n_total at the end.
            test_loss += F.nll_loss(output, target, reduction="sum").item()
            pred = output.argmax(dim=1)
            n_correct += (pred == target).sum().item()
            n_total += len(target)

    test_loss /= n_total

    if verbose:
        print(f"\nTest loss: {test_loss:.4f}, Accuracy: {n_correct}/{n_total} ({n_correct/n_total:.0%})\n")
    visualizer.plot_accuracy(epoch, 100.0 * n_correct / n_total)

# %% [markdown]
# ## Hyperparameters

# %%
# Training uses more memory than test (due to gradient computations),
# so we can set test_batch_size to be larger.
epochs = 5
batch_size = 256
test_batch_size = 1000
lr = 1e-2
log_interval = 10

# Use CUDA if a CUDA GPU is available, otherwise we'll run on CPU.
# You could also use "mps" for Apple Silicon, and some others,
# though support for less common operations may vary.
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ## Dataset and dataloader
# Any sequence of dataitems (and even some iterables) can be used as a ***dataset***.<br>
# A dataitem can be for example an (input image, output label) pair.<br>
# Torch datasets usually allow passing a transformation: it is then applied whenever you retrieve an item with `dataset[i]`.
#
# A ***dataloader*** manages parallel loading (it can create worker threads that call `dataset[i]` in parallel), batching, shuffling, sometimes moving data between devices.

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean=(0.1307,), std=(0.3081,))]
)
train_dataset = datasets.MNIST("../data", train=True, download=True, transform=transform)
test_dataset = datasets.MNIST("../data", train=False, transform=transform)
len(train_dataset), len(test_dataset)
# Out:
# (60000, 10000)

# %%
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, **kwargs)

# %% [markdown]
# ## Running it all

# %%
model = Net().to(device)

optimizer_type = "ADAGRAD"
momentum = 0.1

if optimizer_type == "ADAM":
  optimizer = optim.Adam(model.parameters(), lr=lr)
if optimizer_type == "SGD":
  optimizer = optim.SGD(model.parameters(), lr = lr, momentum = momentum)
if optimizer_type == "ADAGRAD":
  optimizer = optim.Adagrad(model.parameters(), lr=lr)


visualizer = TrainingVisualizer(log_interval=log_interval)
visualizer.track_model(model, optimizer, lr)

for epoch in range(1, epochs + 1):
    train_epoch(
        model,
        device,
        train_loader,
        optimizer,
        epoch,
        log_interval,
        visualizer,
        verbose=True,
    )
    test(model, device, test_loader, epoch, visualizer, verbose=True)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'bd9c84da-beae-4679-836d-fbd64be97902',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '08d13ee9-64b2-4152-99b5-979a43e588e5',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ade0e987-9af1-46b2-b0ea-7329412ba78d',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e0bbab8e-0940-48f8-bc9b-461ebc21d39f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e707ae20-de89-463b-b5e9-74f78dbae71e',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e77c07b4-8d95-4186-941e-583be03caf44',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '58508126-842e-4442-958a-64e92946beb8',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f47361ab-99a3-4580-a608-9184fec09e4f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e2feede6-d891-4bec-8129-eafbdfac9e68',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '39fb8a0d-bca8-4b64-8ba9-937d977ffd61',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e6982613-c301-4149-b0db-216f7b2ef164',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'faa8efd7-222d-4b6c-8f0d-9a370e54a190',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'da407062-26a0-42ee-aee5-d1dcdb43301d',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2041d749-e96c-4e34-88dd-8ba3be26eb03',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '507b4c6a-3b1f-4182-a30f-e8613ce1c520',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8deaef25-3bc8-4c21-92c6-8449ad801a6a',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b76deb6f-a8a0-4a77-9e25-3117b9e04fb3',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9c055182-fab0-42e0-9670-192e94fe5b3b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5d0aa166-dc3a-49f3-9495-c648138f5503',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fe331f23-2d9d-406d-b06e-be6632b49f84',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '968d83c9-16c3-48a4-9acc-f74ab0eae6f4',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f98e1ccd-f5a6-4387-9ae5-7344eb0e370c',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd9d0ad8d-6e84-420a-b2f7-8e19dd7702bf',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd52d7337-f187-4299-9b15-66d75fc22425',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '145d2fe6-bb0e-439b-8b8d-099c61ceabae',
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Training loss', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Step'}},
#                'yaxis': {'type': 'linear'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6095aa0a-3b28-4785-b613-062d6ffed752',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '00c22e9b-c971-4bd2-8157-8427c3018c30',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '18fe0378-4932-4bc1-af90-903fbac1a3f2',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4c72a30d-d373-4949-9410-904efa3842da',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '71d4b2f3-3239-4f6f-9c17-51b4c216496a',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ec550fd8-948b-4cb4-b57e-ddb0e96c8506',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9a74f478-10d8-499e-b7d2-3af2ab871ed0',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '518493a4-1eca-4446-95ad-ec870cc9386b',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1f35362b-de56-42d8-9f23-e62dbb0d1ec5',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '764dc8a9-8e67-4890-bca9-b8de0b6c7490',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f0eab712-f473-49aa-af4d-9633565bde42',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e62e757b-fd47-4253-9379-6fe376d59376',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3533c52a-5586-4cac-bff4-0c4eaa16607c',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9c299da2-9c7b-4840-bccb-45d3330f85cd',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd477e394-30aa-4077-88e1-0322ddba6497',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5ef0477c-a9c8-4b9e-a873-3ca1afb13e2f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '134eb997-27e9-4fbb-94a1-06e39c406774',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '92c81c33-2ef1-4410-817f-361c7d3f3e09',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '82d83f12-e7f1-45c0-9c5d-6379cfcb3a5f',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '72b972cd-cf94-4abf-a46e-4237b23a3092',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd0bf8139-80bf-4706-952c-832f75649cf1',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fafe9208-647a-4b48-b8ae-4369358a4d9d',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4bfca9c9-5a4d-4ad3-8269-7bfe634b39b7',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '25098232-1423-4bf3-b3be-079b2c471975',
#               'y': []},
#              {'mode': 'lines',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8d2872c8-8070-405d-a7b5-19c606bb4c25',
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient standard deviation to weight standard deviation ratio at 1st layer', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Step'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2347c665-3f6d-4ece-a4d5-5614c1339fbb',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '27b6ffd1-20c0-42aa-b10e-ed26d4eaede2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '53013712-ea7e-4356-93a5-a5143506946a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '97427c6e-2852-443b-9ec7-17134c5f854d',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '036b27a9-f2d0-49a5-be04-140b70a517eb',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c818b897-e84a-4c77-8bfd-14b69a6409aa',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'cab2d6ce-cce8-43c9-a74c-cb5ae92d87aa',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '61c01ca7-bd9f-47c0-8cd7-6fb1e7487221',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '89de0533-fcfb-4916-823a-15830fe35add',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '30762432-1de9-44ad-9bde-1e59f4abb2bc',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ff43011e-6f1e-4c67-915e-939d6b73cdf4',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '750cebc0-df44-4b2b-9f7a-c732d1da5dcc',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '764e1598-2613-479c-a387-5d8a2077bdc2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3166018b-4864-484d-8d4d-9adfe2208fde',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8fe030b0-55d3-47aa-aa9c-ff564187eb1f',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '30e6a8d1-a271-4fdf-84bb-b84cb1ece232',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8705bfab-07b2-47b9-b792-c33cf4b0f6f9',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '885d97c5-bb89-43e4-a17d-8cb08439e249',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '00125340-7e57-447a-9a6e-baa872624f2a',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2aa303e3-38fb-422c-b811-5e6462fa9cf8',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '2e5dc4aa-6eb0-4163-a078-cc4bf9327b73',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8d3fe22b-91f3-4691-ad1c-fe6abb57cb2e',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fdb6af01-99c6-4807-8432-e89524593a8c',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'dc395c2d-2906-4972-83c1-bace16dcee88',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '472eebc6-7e8b-4a3e-bccb-13eef0e0a491',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Test accuracy', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'type': 'linear'}}
# })
# Train Epoch: 1 [0/60000 images (0%)]	Loss: 2.314949
# Train Epoch: 1 [2560/60000 images (4%)]	Loss: 1.091509
# Train Epoch: 1 [5120/60000 images (9%)]	Loss: 0.473015
# Train Epoch: 1 [7680/60000 images (13%)]	Loss: 0.360089
# Train Epoch: 1 [10240/60000 images (17%)]	Loss: 0.336622
# Train Epoch: 1 [12800/60000 images (21%)]	Loss: 0.239020
# Train Epoch: 1 [15360/60000 images (26%)]	Loss: 0.359654
# Train Epoch: 1 [17920/60000 images (30%)]	Loss: 0.219574
# Train Epoch: 1 [20480/60000 images (34%)]	Loss: 0.211814
# Train Epoch: 1 [23040/60000 images (38%)]	Loss: 0.238522
# Train Epoch: 1 [25600/60000 images (43%)]	Loss: 0.138326
# Train Epoch: 1 [28160/60000 images (47%)]	Loss: 0.186006
# Train Epoch: 1 [30720/60000 images (51%)]	Loss: 0.189223
# Train Epoch: 1 [33280/60000 images (55%)]	Loss: 0.230418
# Train Epoch: 1 [35840/60000 images (60%)]	Loss: 0.174516
# Train Epoch: 1 [38400/60000 images (64%)]	Loss: 0.208824
# Train Epoch: 1 [40960/60000 images (68%)]	Loss: 0.215887
# Train Epoch: 1 [43520/60000 images (73%)]	Loss: 0.209315
# Train Epoch: 1 [46080/60000 images (77%)]	Loss: 0.279780
# Train Epoch: 1 [48640/60000 images (81%)]	Loss: 0.205117
# Train Epoch: 1 [51200/60000 images (85%)]	Loss: 0.138906
# Train Epoch: 1 [53760/60000 images (90%)]	Loss: 0.180588
# Train Epoch: 1 [56320/60000 images (94%)]	Loss: 0.145293
# Train Epoch: 1 [58880/60000 images (98%)]	Loss: 0.184268
#
# Test loss: 0.1449, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 2 [0/60000 images (0%)]	Loss: 0.096691
# Train Epoch: 2 [2560/60000 images (4%)]	Loss: 0.080983
# Train Epoch: 2 [5120/60000 images (9%)]	Loss: 0.179313
# Train Epoch: 2 [7680/60000 images (13%)]	Loss: 0.098847
# Train Epoch: 2 [10240/60000 images (17%)]	Loss: 0.126809
# Train Epoch: 2 [12800/60000 images (21%)]	Loss: 0.099810
# Train Epoch: 2 [15360/60000 images (26%)]	Loss: 0.100766
# Train Epoch: 2 [17920/60000 images (30%)]	Loss: 0.140492
# Train Epoch: 2 [20480/60000 images (34%)]	Loss: 0.095005
# Train Epoch: 2 [23040/60000 images (38%)]	Loss: 0.194347
# Train Epoch: 2 [25600/60000 images (43%)]	Loss: 0.062899
# Train Epoch: 2 [28160/60000 images (47%)]	Loss: 0.099279
# Train Epoch: 2 [30720/60000 images (51%)]	Loss: 0.098347
# Train Epoch: 2 [33280/60000 images (55%)]	Loss: 0.114857
# Train Epoch: 2 [35840/60000 images (60%)]	Loss: 0.111572
# Train Epoch: 2 [38400/60000 images (64%)]	Loss: 0.081474
# Train Epoch: 2 [40960/60000 images (68%)]	Loss: 0.058335
# Train Epoch: 2 [43520/60000 images (73%)]	Loss: 0.059348
# Train Epoch: 2 [46080/60000 images (77%)]	Loss: 0.143063
# Train Epoch: 2 [48640/60000 images (81%)]	Loss: 0.141965
# Train Epoch: 2 [51200/60000 images (85%)]	Loss: 0.102142
# Train Epoch: 2 [53760/60000 images (90%)]	Loss: 0.090178
# Train Epoch: 2 [56320/60000 images (94%)]	Loss: 0.084774
# Train Epoch: 2 [58880/60000 images (98%)]	Loss: 0.113690
#
# Test loss: 0.1148, Accuracy: 9630/10000 (96%)
#
# Train Epoch: 3 [0/60000 images (0%)]	Loss: 0.119104
# Train Epoch: 3 [2560/60000 images (4%)]	Loss: 0.124060
# Train Epoch: 3 [5120/60000 images (9%)]	Loss: 0.145263
# Train Epoch: 3 [7680/60000 images (13%)]	Loss: 0.074752
# Train Epoch: 3 [10240/60000 images (17%)]	Loss: 0.075168
# Train Epoch: 3 [12800/60000 images (21%)]	Loss: 0.116700
# Train Epoch: 3 [15360/60000 images (26%)]	Loss: 0.101889
# Train Epoch: 3 [17920/60000 images (30%)]	Loss: 0.094985
# Train Epoch: 3 [20480/60000 images (34%)]	Loss: 0.108920
# Train Epoch: 3 [23040/60000 images (38%)]	Loss: 0.140558
# Train Epoch: 3 [25600/60000 images (43%)]	Loss: 0.059273
# Train Epoch: 3 [28160/60000 images (47%)]	Loss: 0.060352
# Train Epoch: 3 [30720/60000 images (51%)]	Loss: 0.112981
# Train Epoch: 3 [33280/60000 images (55%)]	Loss: 0.111389
# Train Epoch: 3 [35840/60000 images (60%)]	Loss: 0.120838
# Train Epoch: 3 [38400/60000 images (64%)]	Loss: 0.092739
# Train Epoch: 3 [40960/60000 images (68%)]	Loss: 0.058166
# Train Epoch: 3 [43520/60000 images (73%)]	Loss: 0.104959
# Train Epoch: 3 [46080/60000 images (77%)]	Loss: 0.059466
# Train Epoch: 3 [48640/60000 images (81%)]	Loss: 0.110424
# Train Epoch: 3 [51200/60000 images (85%)]	Loss: 0.090721
# Train Epoch: 3 [53760/60000 images (90%)]	Loss: 0.026838
# Train Epoch: 3 [56320/60000 images (94%)]	Loss: 0.093529
# Train Epoch: 3 [58880/60000 images (98%)]	Loss: 0.089977
#
# Test loss: 0.0998, Accuracy: 9691/10000 (97%)
#
# Train Epoch: 4 [0/60000 images (0%)]	Loss: 0.069888
# Train Epoch: 4 [2560/60000 images (4%)]	Loss: 0.049101
# Train Epoch: 4 [5120/60000 images (9%)]	Loss: 0.077566
# Train Epoch: 4 [7680/60000 images (13%)]	Loss: 0.078211
# Train Epoch: 4 [10240/60000 images (17%)]	Loss: 0.071082
# Train Epoch: 4 [12800/60000 images (21%)]	Loss: 0.087682
# Train Epoch: 4 [15360/60000 images (26%)]	Loss: 0.048967
# Train Epoch: 4 [17920/60000 images (30%)]	Loss: 0.050756
# Train Epoch: 4 [20480/60000 images (34%)]	Loss: 0.059987
# Train Epoch: 4 [23040/60000 images (38%)]	Loss: 0.116947
# Train Epoch: 4 [25600/60000 images (43%)]	Loss: 0.073485
# Train Epoch: 4 [28160/60000 images (47%)]	Loss: 0.066756
# Train Epoch: 4 [30720/60000 images (51%)]	Loss: 0.041762
# Train Epoch: 4 [33280/60000 images (55%)]	Loss: 0.074149
# Train Epoch: 4 [35840/60000 images (60%)]	Loss: 0.031629
# Train Epoch: 4 [38400/60000 images (64%)]	Loss: 0.090400
# Train Epoch: 4 [40960/60000 images (68%)]	Loss: 0.071046
# Train Epoch: 4 [43520/60000 images (73%)]	Loss: 0.036707
# Train Epoch: 4 [46080/60000 images (77%)]	Loss: 0.068350
# Train Epoch: 4 [48640/60000 images (81%)]	Loss: 0.031040
# Train Epoch: 4 [51200/60000 images (85%)]	Loss: 0.069328
# Train Epoch: 4 [53760/60000 images (90%)]	Loss: 0.107146
# Train Epoch: 4 [56320/60000 images (94%)]	Loss: 0.102535
# Train Epoch: 4 [58880/60000 images (98%)]	Loss: 0.071170
#
# Test loss: 0.0777, Accuracy: 9761/10000 (98%)
#
# Train Epoch: 5 [0/60000 images (0%)]	Loss: 0.031893
# Train Epoch: 5 [2560/60000 images (4%)]	Loss: 0.075772
# Train Epoch: 5 [5120/60000 images (9%)]	Loss: 0.075610
# Train Epoch: 5 [7680/60000 images (13%)]	Loss: 0.067887
# Train Epoch: 5 [10240/60000 images (17%)]	Loss: 0.031558
# Train Epoch: 5 [12800/60000 images (21%)]	Loss: 0.038148
# Train Epoch: 5 [15360/60000 images (26%)]	Loss: 0.066255
# Train Epoch: 5 [17920/60000 images (30%)]	Loss: 0.095049
# Train Epoch: 5 [20480/60000 images (34%)]	Loss: 0.034884
# Train Epoch: 5 [23040/60000 images (38%)]	Loss: 0.030881
# Train Epoch: 5 [25600/60000 images (43%)]	Loss: 0.043212
# Train Epoch: 5 [28160/60000 images (47%)]	Loss: 0.049132
# Train Epoch: 5 [30720/60000 images (51%)]	Loss: 0.032837
# Train Epoch: 5 [33280/60000 images (55%)]	Loss: 0.065603
# Train Epoch: 5 [35840/60000 images (60%)]	Loss: 0.049372
# Train Epoch: 5 [38400/60000 images (64%)]	Loss: 0.023948
# Train Epoch: 5 [40960/60000 images (68%)]	Loss: 0.040442
# Train Epoch: 5 [43520/60000 images (73%)]	Loss: 0.067863
# Train Epoch: 5 [46080/60000 images (77%)]	Loss: 0.051737
# Train Epoch: 5 [48640/60000 images (81%)]	Loss: 0.060177
# Train Epoch: 5 [51200/60000 images (85%)]	Loss: 0.040664
# Train Epoch: 5 [53760/60000 images (90%)]	Loss: 0.048161
# Train Epoch: 5 [56320/60000 images (94%)]	Loss: 0.029820
# Train Epoch: 5 [58880/60000 images (98%)]	Loss: 0.054980
#
# Test loss: 0.0784, Accuracy: 9750/10000 (98%)
